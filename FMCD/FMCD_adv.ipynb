# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from typing import List, Tuple


class FactorModel(nn.Module):
    def __init__(self, N: int, K: List[int], d: int):
        super(FactorModel, self).__init__()
        self.N = N  # Number of questions
        self.K = K  # List of number of categorical answers for each question
        self.d = d  # Latent dimension
        self.W = nn.ModuleList([nn.Linear(d, K[i] - 1, bias=False) for i in range(N)])
        self.biases = nn.ParameterList(
            [nn.Parameter(torch.randn(K[i] - 1)) for i in range(N)]
        )

    def forward(self, v: torch.Tensor) -> List[torch.Tensor]:
        logits = [self.W[n](v) + self.biases[n] for n in range(self.N)]
        # Append zero logits for the last category to each question's logits
        logits = [
            torch.cat((logit, torch.zeros(logit.size(0), 1).to(logit.device)), dim=1)
            for logit in logits
        ]
        return logits

    def predict_proba(self, v: torch.Tensor) -> List[torch.Tensor]:
        logits = self.forward(v)  # List of logits for each question
        probabilities = [torch.softmax(logit, dim=-1) for logit in logits]
        return probabilities


def loss_function(
    model: FactorModel,
    v: torch.Tensor,
    answers: torch.Tensor,
    lambda1: float,
    lambda2: float,
) -> torch.Tensor:

    criterion = nn.NLLLoss(reduction="sum")
    logits = model.forward(v)

    total_loss = 0
    for n in range(model.N):
        log_probs = nn.functional.log_softmax(logits[n], dim=1)
        total_loss += criterion(log_probs, answers[:, n])

    # L2 Regularization
    l2_reg = sum(torch.norm(W.weight, 2) ** 2 for W in model.W)
    total_loss += lambda1 * l2_reg
    total_loss += lambda2 * torch.norm(v, 2) ** 2
    return total_loss


def train_model(
    model: FactorModel,
    answers: torch.Tensor,
    epochs: int = 1000,
    lr: float = 0.01,
    lambda1: float = 0.01,
    lambda2: float = 0.01,
) -> Tuple[FactorModel, torch.Tensor]:
    optimizer = optim.Adam(model.parameters(), lr=lr)
    v = torch.randn(len(answers), model.d, requires_grad=True)
    for epoch in range(epochs):
        optimizer.zero_grad()
        loss = loss_function(model, v, answers, lambda1, lambda2)
        loss.backward()
        optimizer.step()
        if epoch % 100 == 0:
            print(f"Epoch {epoch}, Loss: {loss.item()}")
    return model, v

# %%
import json

N = 22  # number of questions
M = 100  # number of articles

with open("../CA/Alignment_eng_Territorial_disputes_in_the_South_China_Sea.json") as f:
    data = json.load(f)

# Initialize a list to store the extracted values
llm_zho = []

# Iterate through the JSON objects to extract `post_LLM_answer`
for item in data:
    if "QnA" in item:
        for qna in item["QnA"]:
            if "post_LLM_answer" in qna:
                llm_zho.append(qna["post_LLM_answer"])

# reshape the list to a MxN matrix
llm_zho = np.array(llm_zho).reshape(-1, 1)
llm_zho = np.array(llm_zho).reshape(M, N)

# replace A with  number 0, B with 1, C with 2, D with 3
llm_zho = np.where(llm_zho == "A", 0, llm_zho)
llm_zho = np.where(llm_zho == "B", 1, llm_zho)
llm_zho = np.where(llm_zho == "C", 2, llm_zho)
llm_zho = np.where(llm_zho == "D", 3, llm_zho)
llm_zho = np.where(llm_zho == "E", 4, llm_zho)
llm_zho = llm_zho.astype(int)
# convert llm_zho to numpy array
llm_zho = np.array(llm_zho)

# %%
llm_zho
# Out:
# array([[0, 1, 0, ..., 1, 0, 1],
#        [1, 1, 0, ..., 0, 2, 0],
#        [0, 1, 0, ..., 1, 3, 0],
#        ...,
#        [0, 1, 0, ..., 0, 4, 4],
#        [0, 1, 0, ..., 0, 4, 4],
#        [0, 1, 0, ..., 1, 0, 1]])

# %%
import json

N = 22  # number of questions
M = 100  # number of articles

with open("../CA/Alignment_eng_Territorial_disputes_in_the_South_China_Sea.json") as f:
    data = json.load(f)

# Initialize a list to store the extracted values
llm_eng = []

# Iterate through the JSON objects to extract `post_LLM_answer`
for item in data:
    if "QnA" in item:
        for qna in item["QnA"]:
            if "post_LLM_answer" in qna:
                llm_eng.append(qna["post_LLM_answer"])

# reshape the list to a MxN matrix
llm_eng = np.array(llm_eng).reshape(-1, 1)
llm_eng = np.array(llm_eng).reshape(M, N)

# replace A with  number 0, B with 1, C with 2, D with 3
llm_eng = np.where(llm_eng == "A", 0, llm_eng)
llm_eng = np.where(llm_eng == "B", 1, llm_eng)
llm_eng = np.where(llm_eng == "C", 2, llm_eng)
llm_eng = np.where(llm_eng == "D", 3, llm_eng)
llm_eng = np.where(llm_eng == "E", 4, llm_eng)
llm_eng = llm_zho.astype(int)
# convert llm_zho to numpy array
llm_eng = np.array(llm_eng)

# %%
N = 1  # Number of questions
d = 2  # Latent dimension
# list of number of categorical answers for each question
# K = [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 5]
K = [5]
model = FactorModel(N, K, d)

# Prepare Data
M = 200  # Number of articles
# merge the two languages
data = np.concatenate((llm_eng, llm_zho), axis=0)
# select the first M articles and firt 4 and last questions
data = data[:M, [21]]

# convert data to torch tensor long
answers = torch.tensor(data, dtype=torch.long)

# %%
data.min(), data.max(), data.mean(axis=0)
# Out:
# (0, 4, array([1.78]))

# %%
data[-1]
# Out:
# array([1])

# %%
answers
# Out:
# tensor([[1],
#         [0],
#         [0],
#         [0],
#         [4],
#         [1],
#         [2],
#         [2],
#         [1],
#         [1],
#         [4],
#         [1],
#         [1],
#         [1],
#         [2],
#         [1],
#         [0],
#         [1],
#         [2],
#         [4],
#         [1],
#         [4],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [2],
#         [4],
#         [1],
#         [1],
#         [1],
#         [1],
#         [2],
#         [1],
#         [1],
#         [2],
#         [1],
#         [1],
#         [1],
#         [1],
#         [4],
#         [2],
#         [0],
#         [2],
#         [2],
#         [2],
#         [4],
#         [4],
#         [4],
#         [0],
#         [3],
#         [0],
#         [0],
#         [1],
#         [2],
#         [0],
#         [4],
#         [2],
#         [2],
#         [4],
#         [2],
#         [2],
#         [2],
#         [4],
#         [2],
#         [2],
#         [4],
#         [2],
#         [4],
#         [2],
#         [4],
#         [2],
#         [0],
#         [0],
#         [2],
#         [2],
#         [2],
#         [2],
#         [2],
#         [2],
#         [2],
#         [1],
#         [2],
#         [1],
#         [4],
#         [0],
#         [0],
#         [1],
#         [2],
#         [1],
#         [4],
#         [2],
#         [4],
#         [4],
#         [1],
#         [1],
#         [0],
#         [0],
#         [0],
#         [4],
#         [1],
#         [2],
#         [2],
#         [1],
#         [1],
#         [4],
#         [1],
#         [1],
#         [1],
#         [2],
#         [1],
#         [0],
#         [1],
#         [2],
#         [4],
#         [1],
#         [4],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [2],
#         [4],
#         [1],
#         [1],
#         [1],
#         [1],
#         [2],
#         [1],
#         [1],
#         [2],
#         [1],
#         [1],
#         [1],
#         [1],
#         [4],
#         [2],
#         [0],
#         [2],
#         [2],
#         [2],
#         [4],
#         [4],
#         [4],
#         [0],
#         [3],
#         [0],
#         [0],
#         [1],
#         [2],
#         [0],
#         [4],
#         [2],
#         [2],
#         [4],
#         [2],
#         [2],
#         [2],
#         [4],
#         [2],
#         [2],
#         [4],
#         [2],
#         [4],
#         [2],
#         [4],
#         [2],
#         [0],
#         [0],
#         [2],
#         [2],
#         [2],
#         [2],
#         [2],
#         [2],
#         [2],
#         [1],
#         [2],
#         [1],
#         [4],
#         [0],
#         [0],
#         [1],
#         [2],
#         [1],
#         [4],
#         [2],
#         [4],
#         [4],
#         [1]])

# %%
epo = 1000 + 500 * d
trained_model, v = train_model(
    model, answers, epochs=epo, lr=0.01, lambda1=0.0, lambda2=0.01
)
# Out:
# /Users/minlingzhou/miniconda3/envs/my-env/lib/python3.11/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# Epoch 0, Loss: 426.87786865234375
# Epoch 100, Loss: 299.6422424316406
# Epoch 200, Loss: 280.0522155761719
# Epoch 300, Loss: 276.1971130371094
# Epoch 400, Loss: 274.8180236816406
# Epoch 500, Loss: 274.1210021972656
# Epoch 600, Loss: 273.6759948730469
# Epoch 700, Loss: 273.355712890625
# Epoch 800, Loss: 273.1148681640625
# Epoch 900, Loss: 272.9305725097656
# Epoch 1000, Loss: 272.7880859375
# Epoch 1100, Loss: 272.6769104003906
# Epoch 1200, Loss: 272.589599609375
# Epoch 1300, Loss: 272.52056884765625
# Epoch 1400, Loss: 272.4658203125
# Epoch 1500, Loss: 272.42236328125
# Epoch 1600, Loss: 272.38775634765625
# Epoch 1700, Loss: 272.3603515625
# Epoch 1800, Loss: 272.3385314941406
# Epoch 1900, Loss: 272.3213195800781

# %%
print(trained_model.W[0].weight)
# Out:
# Parameter containing:
# tensor([[ 0.0147, -0.0066],
#         [ 0.0330, -0.2238],
#         [ 0.1483,  0.0041],
#         [ 1.3841, -0.8799]], requires_grad=True)

# %%
v[0]
# Out:
# tensor([-1.3375,  0.4989], grad_fn=<SelectBackward0>)

# %%
trained_model.predict_proba(v[0].unsqueeze(0)), answers[0]
# Out:
# ([tensor([[0.1449, 0.3411, 0.2985, 0.0005, 0.2150]], grad_fn=<SoftmaxBackward0>)],
#  tensor([1]))

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler


# Extract the latent vectors v
latent_vectors = v.detach().numpy()

# Normalize the latent vectors
# scaler = StandardScaler()
# latent_vectors_normalized = scaler.fit_transform(latent_vectors)

# Apply t-SNE to reduce dimensionality to 2D
tsne = TSNE(n_components=2, random_state=42)
# v_2d = tsne.fit_transform(latent_vectors)
v_2d = tsne.fit_transform(latent_vectors)

# Plot the 2D embeddings with the inedx of each point
plt.figure(figsize=(10, 8))
# split the two languages
v_2d_eng = v_2d[:100]
v_2d_zho = v_2d[100:]
for index, (x, y) in enumerate(v_2d_eng):
    plt.scatter(
        x, y, alpha=0.4, color="blue", s=2, label="English" if index == 0 else ""
    )
    plt.text(x, y, str(index), fontsize=9, color="blue")

for index, (x, y) in enumerate(v_2d_zho):
    plt.scatter(
        x, y, alpha=0.4, color="red", s=2, label="Chinese" if index == 0 else ""
    )
    plt.text(x, y, str(index), fontsize=9, color="red")
plt.title(
    f"t-SNE visualization of document embeddings \n {d} dimensions, {N} questions, {M} articles, {epo} epochs"
)

plt.xlabel("t-SNE component 1")
plt.ylabel("t-SNE component 2")
plt.legend()
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors
from kneed import KneeLocator

# Compute k-nearest neighbors (k is set to min_samples)
min_samples = 5
neigh = NearestNeighbors(n_neighbors=min_samples)
nbrs = neigh.fit(v_2d)
distances, indices = nbrs.kneighbors(v_2d)

# Sort distances to the k-th nearest neighbor
distances = np.sort(distances[:, min_samples - 1])

x = np.arange(len(distances))
kneedle = KneeLocator(x, distances, curve="convex", direction="increasing")

# Plot the results
plt.plot(x, distances, label="K-Distance Graph")
plt.axvline(x=kneedle.knee, color="r", linestyle="--", label="Elbow Point")
plt.xlabel("Points sorted by distance")
plt.ylabel("Distance to k-th nearest neighbor")
plt.title("K-Distance Graph with Elbow Point")
plt.legend()
plt.show()

# Print the knee point
print(
    f"Elbow point (knee) is at index: {kneedle.knee}, distance: {distances[kneedle.knee]}"
)
# Out:
# Elbow point (knee) is at index: 179, distance: 1.6455957805589407

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=distances[kneedle.knee], min_samples=min_samples)
labels = dbscan.fit_predict(v_2d)

# %%
plt.figure(figsize=(10, 8))
for y in np.unique(labels):
    plt.scatter(
        v_2d[labels == y, 0], v_2d[labels == y, 1], label=f"{y}", s=10, marker="o"
    )

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title(
    f"t-SNE visualization of document embeddings \n {d} dimensions, {N} questions, {M} articles, {epo} epochs"
)
plt.legend(title="Label", loc="upper left", bbox_to_anchor=(1, 1), ncol=1)
plt.tight_layout()
plt.show()

# %%
# get the index of cluster -1
cluster_1 = np.where(labels == labels.max())
# convert the tuple to list
cluster_1 = list(cluster_1[0])

with open("../CA/combined_Territorial_disputes_in_the_South_China_Sea.json") as f:
    data = json.load(f)
for i in cluster_1:
    print(data[i]["title"])
# Out:
# AFP denies BRP Sierra Madre crew pointed guns at CCG
# Zelenskyy, Marcos meet after two leaders slammed China at summit
# Zelenskiy Meets Marcos in Manila as Ukraine Seeks Asia Support - BNN Bloomberg
# 山东省农村信用社联合社原党委副书记、纪委书记展西亮接受纪律审查和监察调查
# 就亚太安全提"三个不允许"！中方"香会"表态引热议

# %%
# get the index of cluster -1
cluster_1 = np.where(labels == labels.min())
# convert the tuple to list
cluster_1 = list(cluster_1[0])

with open("../CA/combined_Territorial_disputes_in_the_South_China_Sea.json") as f:
    data = json.load(f)
for i in cluster_1:
    print(data[i]["title"])
# Out:
# 中国官媒释仁爱礁冲突影片　指菲方用枪指中国海警 | 国际

# %%
# get the index of cluster -1
cluster_1 = np.where(labels == 0)
# convert the tuple to list
cluster_1 = list(cluster_1[0])

with open("../CA/combined_Territorial_disputes_in_the_South_China_Sea.json") as f:
    data = json.load(f)
for i in cluster_1:
    print(data[i]["title"])
# Out:
# World News | Philippines Says China Coast Guard Seized Food Dropped by Plane for Filipino Forces in Disputed Sea | LatestLY
# Philippines says China coast guard seized food dropped by plane for Filipino forces in disputed sea
# Philippines says China coast guard seized food dropped by plane for Filipino forces in disputed sea
# Philippines says China coast guard seized food dropped by plane for Filipino forces in disputed sea
# US Defense Secretary Lloyd Austin Confirms Restoration of US-Cambodia Ties, Joint Military Drills | CamboJA News
# Philippines says troops held weapons but did not point at Chinese coast guard
# Qualcomm Deepens Taiwan Ties with Kaohsiung Innovation Center for NASDAQ:QCOM by signalmastermind
# Tensions Rise in South China Sea: A Standoff at Second Thomas Shoal | Law-Order
# WATCH: Chinese agents seize supplies in BRP Sierra Madre airdrop mission
# China says Philippines' actions towards Chinese coast guard illegal
# Philippines says troops held weapons but did not point at Chinese coast guard
# 'We have the right': Philippines rejects China's gun-pointing allegations
# ​Ministry calls for 'balanced solution' to South China Sea issue​
# Philippines rejects Chinese allegation that troops point guns at its coast guard
# Philippines rejects Chinese allegation that troops point guns at its coast guard
# Philippines denies troops pointed guns at China Coast Guard
# Philippine military says troops acted professionally in South China Sea
# AFP says troops acted professionally in South China Sea
# Statement of Senate President Pro Tempore Jinggoy Ejercito Estrada on China Coast Guard's alleged seizure of PH supplies for BRP Sierra Madre
# What will China do next in PH waters? - Manila Standard
# Zelenskyy, Marcos to boost ties after slamming China at summit
# Philippines to join peace summit on Ukraine war after surprise Zelensky visit
# Facing up to China's Hybrid Warfare in the Pacific
# China warns of 'limits' to its restraint on US provocation in South China Sea
# China: Marcos' Shangri-La remarks on WPS sovereignty disregard 'history,' 'facts'
# China accuses US of escalating tension in South China Sea
# World News | Finance and Equity Should Be the Core of COP29 Talks | LatestLY
# Finance and equity should be the core of COP29 talks
# Philippines to join peace summit on Ukraine war after surprise Zelensky visit
# China says U.S. plays 'dishonourable role' supporting Philippines in South China Sea
# Australia seeks military talks with China, ties with Philippines
# US says it could act against China firms, banks over Russian war support
# Vietnam and Cambodia Clash Over New Mekong Canal
# Asia-Pacific region in era of turmoil, says Defence Minister - Khmer Times
# More FDIs should be tapped - Manila Standard
# 槍指中國海警？ 北京要求菲律賓莫再製造事端 | 聯合新聞網
# 与泽连斯基见过一面后，马科斯被警告：别让菲律宾成为"乌克兰"
# 菲律宾"既要又要"：我们还可以跟中国做生意
# 中国防长强调的"三个不允许"点明亚太问题的症结
# 中国防长董军的"香会"时刻
# 中国全球安全观在香格里拉对话会上引发共鸣
# 环球时报记者现场感受"香会"的"两面性"：既用中国"吸睛"，又为中国"设套
# 中国全球安全观在香格里拉对话会上引发共鸣
# 外交部发言人就菲律宾总统马科斯在香格里拉对话会发表涉南海问题演讲答记者问
# 中美防长香会交锋，美方颜面扫地_中国海_菲律宾_中方
# 外交部发言人就菲律宾总统马科斯在香格里拉对话会发表涉南海问题演讲答记者问
# 小馬可仕香會強硬捍衛菲南海主權 陸外交部提6主張嗆「罔顧歷史事實」
# 中方回应菲总统涉南海问题演讲：有关表态罔顾历史和事实
# 莫将滥诉当善意，远交近攻非友邻
# 和评理 | 菲方不要错上加错 祸乱南海破坏稳定
# 外交部发言人就菲律宾总统马科斯在香格里拉对话会发表涉南海问题演讲答记者问
# 外交部发言人就菲律宾总统马科斯在香格里拉对话会发表涉南海问题演讲答记者问
# 菲律宾总统马科斯在"香会"发表涉南海问题演讲，外交部发言人阐明中方立场
# 菲总统发表涉南海问题演讲，外交部驳斥
# 香格里拉對話︱董軍暗評菲律賓   在美煽動下仁愛礁「碰瓷」
# ﻿中國海警仁愛礁執法 菲方竟槍指挑釁
# 分析香會發言！專家指陸比以往尖銳：把台、美、菲描繪成「麻煩製造者」 | 聯合新聞網
# 现场画面曝光！菲非法坐滩军舰人员枪指中国海警
#                 2024-06-02 18:02
# 菲律賓硬起來！南海軍人持槍瞄準中國海警 小粉紅崩潰 - 國際 - 自由時報電子報
# 中国防长：个别国家在南海挑衅，中方的克制是有限度的
# 南海问题上交锋 菲律宾总统怼中共少将战狼 - 大纪元
#
# 中方参会专家批驳菲总统香会发言：菲方破坏规则、颠倒黑白、倒打一耙
# 玉渊谭天丨细节披露：中美防长谈了什么
# 我中将表态"台独"等于战争，奥斯汀对我防长承诺，会接紧急电话_美国_台湾_中美
# 细节披露：中美防长谈了什么
# 中美两轮高层交锋，在24小时内打响，中方有2句重话第一次见

# %%
# get the index of cluster -1
cluster_1 = np.where(labels == 1)
# convert the tuple to list
cluster_1 = list(cluster_1[0])

with open("../CA/combined_Territorial_disputes_in_the_South_China_Sea.json") as f:
    data = json.load(f)
for i in cluster_1:
    print(data[i]["title"])
# Out:
# Turkey's Top Diplomat Visits China, Planning Stops in Uyghur Genocide Region
# Phl, U.S., Japan coast guards vow to keep SCS safe, free
# Philippines denies its troops pointed guns at Chinese coast guard personnel
# Speaker says China's behavior won't improve ties
# PBBM 'calm, not combative' in Shangri-La dialogue -- Jinggoy
# Philippine Troops Defend Against Chinese Coast Guard Provocation | Law-Order
# Philippine military says troops acted professionally in South China Sea
# Philippine Military Rebuts Chinese Claims of Armed Confrontation | Law-Order
# China warns of America's 'geopolitical self-interest' in region - Washington Examiner
# "Geopolitical Risk Is Everywhere"
# 'The King's Speech'
# Zelenskyy, Marcos to boost ties after slamming China at summit
# Beijing warns neighbours of US 'geopolitical self-interest' in South China Sea
# China's approach to global security elaborated at Shangri-La Dialogue
# Cui Tiankai: External forces hyping up territorial disputes in South China Sea
# China says US plays 'dishonourable role' supporting the Philippines in South China Sea
# China says US plays 'dishonorable role' supporting PH in SCS
# China says US plays 'dishonorable role' supporting Philippines in S.China Sea
# China says US plays 'dishonourable role' supporting Philippines in S.China Sea
# Guns 'pointed at Chinese coast guards'
# China warns SCS patience wearing thin
# Learning from OFAC sanctions violations
# China warns of limits to its 'restraint' in South China Sea
# 中國觀察：台海與南海成焦點   香格里拉對話會火藥味十足？
# 记者现场感受香会的两面性：既用中国"吸睛"，又为中国"设套"
# 中方批菲总统歪曲南海事态
# 美防长奥斯汀急赴柬埔寨 重续两国关系 - 大纪元
# 中方香会代表团成员：我向菲海岸警卫队司令提出问题，他也表示认同
# 中方香格里拉对话会表态引关注 国际媒体纷纷发声_杭州网
# 45国代表面前，董军防长对台军的称呼变了，最后送给他们8个字
# 外交部回应菲总统涉南海问题表态
# 外交部驳马科斯涉南海问题演讲：罔顾历史和事实，宣扬其涉海错误立场，歪曲渲染海上事态
# 外交部回应菲总统涉南海问题演讲：菲方有关表态罔顾历史和事实
# 外交部发言人就菲律宾总统马科斯在香格里拉对话会发表涉南海问题演讲答记者问
# 10:37
#                   外交部发言人就菲律宾总统马科斯在香格里拉对话会发表涉南海问题演讲答记者问
# ﻿中方：不允許任何勢力在亞太地區生戰生亂
# 【翻墙必看】大陆普通人生活遭围剿 - 大纪元
# 专家谈中国防长"香会"发言：有理有据、务实坦诚
# 菲方人员拿枪指中国海警，当年越南开枪的后果，看来马科斯不清楚
# 国际锐评丨起底美国搅局南海的"航行自由"真相
# 央视：中美两军关系止跌企稳来之不易，美方应言行一致
# 台媒：胡萝卜对美国 大棒挥向台湾？
# 中共"登陆艇"入侵台湾海域 专家：动乱轴心要祸乱世界(图)  -  评析 - 诸葛名郎
# 美防长：中美须保持沟通，承诺接中方紧急电话
# 外交部副部长马朝旭同美国常务副国务卿坎贝尔举行磋商
# 無主權爭端北京斷金援 美承諾菲高科技投資
