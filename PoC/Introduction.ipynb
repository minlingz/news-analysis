# %% [markdown]
# # Introduction to Event Registry Python SDK
#
# This page will give you an introduction on how to use the [Python SDK](https://github.com/EventRegistry/event-registry-python) that will allow you to search for articles and events provided by NewsApi.ai. It describes how to install it, import it and how to use the most relevant classes in order to search for news articles or events.
#
# Please also note that you can interactively try and modify this Jupyter notebook [here](https://github.com/EventRegistry/event-registry-python-intro).
#
#
# ## Registering for a free account
#
# In order to use the SDK you'll need your own API key. To get it, please [register for a free account](https://newsapi.ai/register). The free account will give you access to 2.000  [tokens](https://newsapi.ai/tokens) for  free. After you use them, you'll need to [subscribe to a paid plan](https://newsapi.ai/plans) to continue using the service. You'll be able to monitor your token usage on your [dashboard](https://newsapi.ai/dashboard?tab=home).
#
# ## Importing Event Registry module
#
# In order to use Event Registry, you have to import the module called `eventregistry`.
# To install the module open the command line prompt and call
#
# ```
# >>> pip install eventregistry
# ```

# %% [markdown]
# To start using the module, you then first need to import it:

# %%
from eventregistry import *
import json, os, sys

# %% [markdown]
# There is one main class that interacts with Event Registry service and it is called `EventRegistry`. The class accepts an input parameter `apiKey`, which you will need to provide in order to make more than a trivial number of requests.

# %%
# er = EventRegistry(apiKey = "YOUR_API_KEY", allowUseOfArchive=False)
from dotenv import load_dotenv
import os
from eventregistry import EventRegistry

load_dotenv()  # This loads the environment variables from .env file
api_key = os.getenv("EVENT_REGISTRY_API_KEY")
er = EventRegistry(apiKey=api_key, allowUseOfArchive=False)

# %% [markdown]
# The additional parameter that I've provided in the constructor is the `allowUseOfArchive`, which I use to state that I only want to perform the searches on the data published less than 1 month ago. If you need to search older content too, please remove that parameter (note that free users don't have access to archive, regardless of this parameter value).

# %% [markdown]
# ## A few example queries

# %% [markdown]
# To show some examples, we are providing here a small list of example queries. All the details about the queries and different properties used will be described in the individual sections below.
#
# **Ex 1: Getting the most relevant articles about Donald Trump or Boris Johnson written by New York Times on the topic of Business:**

# %%
q = QueryArticlesIter(
    keywords=QueryItems.OR(["Donald Trump", "Boris Johnson"]),
    sourceUri=er.getSourceUri("New York Times"),
    categoryUri=er.getCategoryUri("Business"),
)

print("Number of results: %d" % q.count(er))

for art in q.execQuery(er, sortBy="rel", maxItems=2):
    print(json.dumps(art, indent=4))
# Out:
# Number of results: 23
# {
#     "uri": "8096064555",
#     "lang": "eng",
#     "isDuplicate": false,
#     "date": "2024-04-25",
#     "time": "05:20:08",
#     "dateTime": "2024-04-25T05:20:08Z",
#     "dateTimePub": "2024-04-25T05:20:00Z",
#     "dataType": "news",
#     "sim": 0,
#     "url": "https://www.nytimes.com/2024/04/25/arts/television/jimmy-kimmel-trump-stock-bonus.html",
#     "title": "Jimmy Kimmel Dunks on Trump's Billion-Dollar Stock Bonus",
#     "body": "\"Donald Trump somehow made a lot of money from a company that makes none,\" Kimmel said.\n\nWelcome to Best of Late Night, a rundown of the previous night's highlights that lets you sleep -- and lets us get paid to watch comedy. Here are the 50 best movies on Netflix right now.\n\nTaking Stock\n\nFormer President Donald Trump is set to receive an additional stake in his social media company after Truth Social's stock price stayed high and hit certain benchmarks. The additional shares were valued at about $1.3 billion.\n\n\"It's nice when good things happen to good people, isn't it?\" Jimmy Kimmel joked on Wednesday.\n\n\"Donald Trump somehow made a lot of money from a company that makes none.\" -- JIMMY KIMMEL\n\n\"Honestly, how can this farting dementia patient be making a billion dollars on a company that has $4 million total in revenue? What kind of con artist Wall Street wizardry is this?\" -- JIMMY KIMMEL\n\nThe Punchiest Punchlines (World Peace Edition)\n\n\"Yes, Taiwan. Now, they're not at war yet, but you've got to make a reservation in advance just to save your spot.\" -- JORDAN KLEPPER, referring to President Joe Biden signing an aid package for Ukraine, Israel and Taiwan, calling it \"a good day for world peace\"\n\n\"A good day for world peace? I've wanted one of those!\" -- JORDAN KLEPPER\n\n\"I wonder what happened -- did the nations of the world finally band together to outlaw war? Did they finally buy everyone a Coke? Is there finally peace between Kendrick and Drake? \" -- JORDAN KLEPPER\n\n\"Oh, 'world peace.' OK, is peace the one with the tanks?\" -- JORDAN KLEPPER\n\nThe Bits Worth Watching\n\nThe Mexican singer-songwriter Christian Nodal performed \"La Mitad\" on Wednesday's \"Jimmy Kimmel Live.\"\n\nWhat We're Excited About on Thursday Night\n\nKyle Chayka, a writer for The New Yorker, will discuss his book \"Filterworld: How Algorithms Flattened Culture\" on Thursday's \"Daily Show.\"\n\nAlso, Check This Out\n\nThe filmmakers Baz Luhrmann, Stephen Daldry, Gus Van Sant, Jane Campion and Karyn Kusama discuss what makes Nicole Kidman a dream actor for any director ahead of her life achievement award from the American Film Institute.",
#     "source": {
#         "uri": "nytimes.com",
#         "dataType": "news",
#         "title": "The New York Times"
#     },
#     "authors": [],
#     "image": "https://static01.nyt.com/images/2024/04/25/arts/25latenight/25latenight-videoSixteenByNineJumbo1600.jpg",
#     "eventUri": null,
#     "sentiment": 0.3803921568627451,
#     "wgt": 29,
#     "relevance": 29
# }
# {
#     "uri": "8119540398",
#     "lang": "eng",
#     "isDuplicate": false,
#     "date": "2024-05-09",
#     "time": "17:18:39",
#     "dateTime": "2024-05-09T17:18:39Z",
#     "dateTimePub": "2024-05-09T17:17:44Z",
#     "dataType": "news",
#     "sim": 0,
#     "url": "https://www.nytimes.com/2024/05/09/business/dwac-trump-media-insider-trading-trial.html",
#     "title": "Financier Found Guilty in Trump Media Insider Trading Trial",
#     "body": "Bruce Garelick was convicted of securities fraud for leaking confidential information about a merger involving the parent company of Truth Social, Donald Trump's social media site.\n\nA federal jury in Manhattan on Thursday convicted a financial executive on securities fraud charges arising from a multimillion-dollar insider trading scheme that involved the merger of former President Donald J. Trump's social media company with a publicly traded shell company.\n\nFederal prosecutors had charged Bruce Garelick with five counts of securities fraud and conspiracy. Authorities claimed Mr. Garelick leaked confidential information to to his boss and at least one other person that Trump Media & Technology Group, the parent company of Truth Social, was getting close to announcing a merger in October 2021 with Digital World Acquisition Group, the shell company.\n\nThe information helped two brothers -- Michael Shvartsman and Gerald Shvartsman -- make nearly $23 million in illegal trading profits by buying Digital World securities in advance of the announcement, which sent the stock soaring. Mr. Garelick, who worked for Michael Shvartsman at a small Miami-based venture capital firm called Rocket One, made about $50,000 by trading off what authorities said was nonpublic information.\n\nLast month, the Shvartsman brothers decided to forgo a trial and pleaded guilty to securities fraud charges. In their plea agreements, prosecutors have recommended a sentence of roughly four to five years for Michael Shvartsman; and three to four years for his younger brother.\n\nAuthorities said Michael Shvartsman used some of the proceeds from the scheme to buy a $14 million luxury yacht that he named Provocateur.\n\nIn court filings, prosecutors identified several other people who made profitable trades around the time of the merger announcement but none of them were charged with wrongdoing.",
#     "source": {
#         "uri": "nytimes.com",
#         "dataType": "news",
#         "title": "The New York Times"
#     },
#     "authors": [],
#     "image": "https://static01.nyt.com/images/2024/05/09/multimedia/trumptrading-garelick-bzhj/trumptrading-garelick-bzhj-videoSixteenByNine3000.jpg",
#     "eventUri": null,
#     "sentiment": -0.192156862745098,
#     "wgt": 27,
#     "relevance": 27
# }

# %% [markdown]
# **Ex 2: The list of latest articles in Chinese or Arabic articles about Apple:**

# %%
q = QueryArticlesIter(
    conceptUri=er.getConceptUri("Apple"), lang=QueryItems.OR(["ara", "zho"])
)

for art in q.execQuery(er, sortBy="date", maxItems=2):
    print(json.dumps(art, indent=4))
# Out:
# {
#     "uri": "1244491882",
#     "lang": "ara",
#     "isDuplicate": false,
#     "date": "2019-09-08",
#     "time": "18:12:00",
#     "dateTime": "2019-09-08T18:12:00Z",
#     "dataType": "news",
#     "sim": 0,
#     "url": "https://www.youm7.com/story/2019/9/8/\u0645\u0633\u062a\u062e\u062f\u0645\u0648-\u0647\u0630\u0647-\u0627\u0644\u0647\u0648\u0627\u062a\u0641-\u0623\u0643\u062b\u0631-\u0627\u0644\u0645\u062a\u0636\u0631\u0631\u064a\u0646-\u0645\u0646-\u0625\u0637\u0644\u0627\u0642-\u0623\u064a\u0641\u0648\u0646-11-\u0627\u0644\u062c\u062f\u064a\u062f/4408241",
#     "title": "\u0645\u0633\u062a\u062e\u062f\u0645\u0648 \u0647\u0630\u0647 \u0627\u0644\u0647\u0648\u0627\u062a\u0641 \u0623\u0643\u062b\u0631 \u0627\u0644\u0645\u062a\u0636\u0631\u0631\u064a\u0646 \u0645\u0646 \u0625\u0637\u0644\u0627\u0642 \u0623\u064a\u0641\u0648\u0646 11 \u0627\u0644\u062c\u062f\u064a\u062f.. \u0627\u0639\u0631\u0641\u0647\u0645 - \u0627\u0644\u064a\u0648\u0645 \u0627\u0644\u0633\u0627\u0628\u0639",
#     "body": "\u0627\u0636\u0641 \u062a\u0639\u0644\u064a\u0642\u0627\u064b \u0648\u0627\u0642\u0631\u0623 \u062a\u0639\u0644\u064a\u0642\u0627\u062a \u0627\u0644\u0642\u0631\u0627\u0621\n\n\u064a\u0639\u062f \u0633\u0628\u062a\u0645\u0628\u0631 \u0647\u0648 \u0627\u0644\u0634\u0647\u0631 \u0627\u0644\u0645\u0646\u062a\u0638\u0631 \u0644\u0639\u0634\u0627\u0642 \u0623\u0628\u0644 \u0644\u0623\u0646\u0647 \u0639\u0627\u062f\u0629\u064b \u0645\u0627 \u064a\u0634\u0647\u062f \u0625\u0635\u062f\u0627\u0631 \u0647\u0627\u062a\u0641 \u0623\u064a\u0641\u0648\u0646 \u062c\u062f\u064a\u062f\u060c \u0644\u0643\u0646\u0647 \u0633\u064a\u0643\u0648\u0646 \u0647\u0630\u0627 \u0627\u0644\u0639\u0627\u0645 \u0628\u0645\u062b\u0627\u0628\u0629 \u0634\u0647\u0631 \u0633\u0649\u0621 \u0644\u0628\u0639\u0636 \u0627\u0644\u0623\u0634\u062e\u0627\u0635 \u0627\u0644\u0630\u064a\u0646 \u0633\u062a\u0635\u0628\u062d \u0647\u0648\u0627\u062a\u0641\u0647\u0645 \u0627\u0644\u0642\u062f\u064a\u0645\u0629 \u0628\u0644\u0627 \u0641\u0627\u0626\u062f\u0629\u060c \u0641\u0628\u062d\u0644\u0648\u0644 10 \u0633\u0628\u062a\u0645\u0628\u0631 \u0633\u062a\u0637\u0644\u0642 \u0623\u0628\u0644 \u0647\u0627\u062a\u0641\u0647\u0627 \u0627\u0644\u062c\u062f\u064a\u062f \u0623\u064a\u0641\u0648\u0646 11\u060c \u062c\u0646\u0628\u0627 \u0625\u0644\u0649 \u062c\u0646\u0628 \u0646\u0638\u0627\u0645 \u0627\u0644\u062a\u0634\u063a\u064a\u0644 \u0627\u0644\u062c\u062f\u064a\u062f iOS 13\u060c \u0648\u0627\u0644\u0630\u0649 \u0644\u0646 \u064a\u0639\u0645\u0644 \u0639\u0644\u0649 \u0643\u0627\u0641\u0629 \u0627\u0644\u0647\u0648\u0627\u062a\u0641 \u0627\u0644\u0642\u062f\u064a\u0645\u0629.\n\n\u0641\u0642\u0648\u0641\u0642\u0627 \u0644\u0645\u0648\u0642\u0639 \"\u0645\u062a\u0631\u0648\" \u0627\u0644\u0628\u0631\u064a\u0637\u0627\u0646\u0649\u060c \u0625\u0630\u0627 \u0643\u0646\u062a \u062a\u0645\u062a\u0644\u0643 \u062c\u0647\u0627\u0632 \u0623\u064a\u0641\u0648\u0646 6 \u0623\u0648 \u0623\u0649 \u062c\u0647\u0627\u0632 \u0623\u0642\u062f\u0645 \u0645\u0646 \u0630\u0644\u0643\u060c \u0641\u0644\u0646 \u062a\u062a\u0645\u0643\u0646 \u0645\u0646 \u0627\u0644\u0627\u0633\u062a\u0645\u062a\u0627\u0639 \u0628\u0646\u0638\u0627\u0645 \u0627\u0644\u062a\u0634\u063a\u064a\u0644 \u0627\u0644\u0623\u062d\u062f\u062b \u0645\u0646 \u0623\u0628\u0644\u060c \u0643\u0645\u0627 \u0623\u0646 \u0647\u0627\u062a\u0641 \u0623\u064a\u0641\u0648\u0646 6 \u0628\u0644\u0633 \u0644\u0646 \u064a\u062a\u0648\u0627\u0641\u0642 \u0647\u0648 \u0627\u0644\u0623\u062e\u0631 \u0645\u0639 \u0627\u0644\u0646\u0638\u0627\u0645\u060c \u0631\u063a\u0645 \u0648\u062c\u0648\u062f \u0646\u062d\u0648 200 \u0645\u0644\u064a\u0648\u0646 \u0645\u0633\u062a\u062e\u062f\u0645 \u0644\u0644\u0647\u0627\u062a\u0641\u064a\u0646.\n\n\u0648\u0639\u0646\u062f \u0625\u0635\u062f\u0627\u0631 iOS 13\u060c \u0633\u064a\u0638\u0644 \u062c\u0647\u0627\u0632 \u0623\u064a\u0641\u0648\u0646 \u0627\u0644\u0642\u062f\u064a\u0645 \u064a\u0639\u0645\u0644\u060c \u0644\u0643\u0646\u0647 \u0644\u0646 \u064a\u062a\u0644\u0642\u0649 \u062c\u0645\u064a\u0639 \u062a\u062d\u062f\u064a\u062b\u0627\u062a \u0627\u0644\u0623\u0645\u0627\u0646 \u0645\u0646 \u0623\u0628\u0644\u060c \u0645\u0645\u0627 \u064a\u062c\u0639\u0644\u0647 \u0623\u0643\u062b\u0631 \u0639\u0631\u0636\u0629 \u0644\u0647\u062c\u0645\u0627\u062a \u0627\u0644\u0627\u062e\u062a\u0631\u0627\u0642.\n\n\u0648\u0641\u064a\u0645\u0627 \u064a\u0644\u0649 \u0647\u0648\u0627\u062a\u0641 \u0623\u064a\u0641\u0648\u0646 \u0627\u0644\u062a\u0649 \u0633\u062a\u062a\u0648\u0627\u0641\u0642 \u0645\u0639 \u0646\u0638\u0627\u0645 \u0627\u0644\u062a\u0634\u063a\u064a\u0644\u060c \u0648\u064a\u0645\u0643\u0646\u0647\u0627 \u0627\u0644\u0627\u0633\u062a\u0641\u0627\u062f\u0629 \u0645\u0646 \u0645\u0632\u0627\u064a\u0627\u0647:",
#     "source": {
#         "uri": "youm7.com",
#         "dataType": "news",
#         "title": "Youm7"
#     },
#     "authors": [],
#     "image": "https://img.youm7.com/large/201906021242484248.jpg",
#     "eventUri": null,
#     "sentiment": null,
#     "wgt": 305662320
# }
# {
#     "uri": "1244490961",
#     "lang": "ara",
#     "isDuplicate": false,
#     "date": "2019-09-08",
#     "time": "18:11:00",
#     "dateTime": "2019-09-08T18:11:00Z",
#     "dataType": "news",
#     "sim": 0,
#     "url": "https://www.dostor.org/2817577",
#     "title": "\u0645\u0648\u0627\u0635\u0641\u0627\u062a \u0627\u0644\u062c\u064a\u0644 \u0627\u0644\u062b\u0627\u0644\u062b \u0644\u0633\u0645\u0627\u0639\u0627\u062a \u0647\u0648\u0627\u0648\u064a",
#     "body": "\u0627\u0644\u0633\u0645\u0627\u0639\u0629 \u0627\u0644\u062c\u062f\u064a\u062f\u0629 \u062a\u0634\u0628\u0647 \u0644\u062d\u062f \u0643\u0628\u064a\u0631 \u0633\u0645\u0627\u0639\u0627\u062a \u0623\u0628\u0644\u060c \u0648\u062a\u062a\u0645\u064a\u0632 \u0628\u0648\u062c\u0648\u062f \u0645\u0639\u0627\u0644\u062c A1 \u0627\u0644\u0630\u064a \u064a\u0642\u0644\u0644 \u0645\u0646 \u0627\u0633\u062a\u0647\u0644\u0627\u0643 \u0627\u0644\u0628\u0637\u0627\u0631\u064a\u0629 \u0623\u062b\u0646\u0627\u0621 \u0627\u0644\u0627\u0633\u062a\u062e\u062f\u0627\u0645 \u0627\u0644\u0645\u062a\u0648\u0627\u0635\u0644.\n\n\u0648\u062a\u0623\u062a\u064a \u0633\u0645\u0627\u0639\u0627\u062a \u0647\u0648\u0627\u0648\u064a \u0628\u0628\u0637\u0627\u0631\u064a\u0629 \u0642\u0648\u064a\u0629 \u0633\u0639\u062a\u0647\u0627 410 \u0645\u0644\u0644\u064a \u0623\u0645\u0628\u064a\u0631\u060c \u0648\u064a\u0645\u0643\u0646 \u0627\u0633\u062a\u062e\u062f\u0627\u0645\u0647\u0627 \u0644\u0645\u062f\u0629 4 \u0633\u0627\u0639\u0627\u062a \u0645\u062a\u0648\u0627\u0635\u0644\u0629 \u062b\u0645 \u0634\u062d\u0646\u0647\u0627 \u0628\u0627\u0644\u0639\u0644\u0628\u0629 \u0627\u0644\u062a\u064a \u062a\u0648\u0641\u0631 \u0637\u0627\u0642\u0629 \u0644\u0645\u062f\u0629 20 \u0633\u0627\u0639\u0629 \u0628\u0639\u062f \u0634\u062d\u0646 \u0627\u0644\u0639\u0644\u0628\u0629 \u0628\u0634\u0643\u0644 \u0643\u0627\u0645\u0644.\n\n\u0627\u0644\u0633\u0645\u0627\u0639\u0627\u062a \u0628\u062f\u0639\u0645 \u062a\u0642\u0646\u064a\u0629 \u0627\u0644\u0628\u0644\u0648\u062a\u0648\u062b 5.1\u060c \u0641\u0636\u0644\u064b\u0627 \u0639\u0646 \u0642\u062f\u0648\u0645 \u0627\u0644\u0633\u0645\u0627\u0639\u062a\u064a\u0646 \u0628\u0628\u0631\u0646\u0627\u0645\u062c \u062a\u0634\u063a\u064a\u0644 \u062f\u064a\u0646\u0627\u0645\u064a\u0643\u064a \u0639\u0627\u0644\u064a \u0627\u0644\u062d\u0633\u0627\u0633\u064a\u0629 \u0628\u062d\u062c\u0645 14 \u0645\u0644\u0645.\n\n\u0623\u0628\u0631\u0632 \u0645\u0627 \u064a\u0645\u064a\u0632 \u0627\u0644\u0633\u0645\u0627\u0639\u0629 \u0645\u064a\u0632\u0629 \u0627\u0644\u0639\u0632\u0644 \u0648\u0625\u0644\u063a\u0627\u0621 \u0627\u0644\u0636\u0648\u0636\u0627\u0621\u060c \u0648\u064a\u0645\u0643\u0646 \u0627\u0644\u062a\u062d\u0643\u0645 \u0628\u0645\u0633\u062a\u0648\u0649 \u0627\u0644\u0636\u0648\u0636\u0627\u0621 \u0645\u0646 \u062e\u0644\u0627\u0644 \u062a\u0637\u0628\u064a\u0642 \u0641\u064a \u0627\u0644\u0647\u0627\u062a\u0641 \u0627\u0644\u0630\u0643\u064a.\n\n\u062a\u0633\u0627\u0639\u062f \u0647\u0630\u0647 \u0627\u0644\u0645\u064a\u0632\u0629 \u0639\u0644\u0649 \u0625\u0644\u063a\u0627\u0621 \u0627\u0644\u0636\u0648\u0636\u0627\u0621 \u0648\u062a\u0642\u0644\u064a\u0644 \u0635\u0648\u062a \u0627\u0644\u0645\u062d\u064a\u0637\u060c \u0648\u062a\u062d\u0633\u064a\u0646 \u0627\u0644\u0635\u0648\u062a \u0623\u062b\u0646\u0627\u0621 \u0627\u0644\u0645\u0643\u0627\u0644\u0645\u0627\u062a \u0623\u0648 \u0627\u0644\u0627\u0633\u062a\u0645\u0627\u0639 \u0644\u0644\u0645\u0648\u0633\u064a\u0642\u0649\u060c \u064a\u0645\u0643\u0646 \u0623\u064a\u0636\u0627 \u0627\u0644\u062a\u062d\u0643\u0645 \u0641\u064a \u0625\u0644\u063a\u0627\u0621 \u0627\u0644\u0636\u0648\u0636\u0627\u0621 \u0627\u0644\u0646\u0634\u0637\u0629 (ANC) \u0639\u0646 \u0637\u0631\u064a\u0642 \u0627\u0644\u0646\u0642\u0631 \u0627\u0644\u0645\u0632\u062f\u0648\u062c \u0639\u0644\u0649 \u0633\u0645\u0627\u0639\u0629 \u0627\u0644\u0623\u0630\u0646 \u0627\u0644\u064a\u0633\u0631\u0649.\n\n\u064a\u0645\u0643\u0646 \u0634\u062d\u0646 \u0639\u0644\u0628\u0629 \u0627\u0644\u0633\u0645\u0627\u0639\u0629 \u0628\u0627\u0633\u062a\u062e\u062f\u0627\u0645 \u0643\u0627\u0628\u0644 \u0645\u0646 \u0646\u0648\u0639 USB Type-C\u060c \u0623\u0648 \u0644\u0627\u0633\u0644\u0643\u064a\u0627 \u0645\u0646 \u062e\u0644\u0627\u0644 \u0634\u0627\u062d\u0646 \u0644\u0627\u0633\u0644\u0643\u064a \u0623\u0648 \u0628\u0627\u0633\u062a\u062e\u062f\u0627\u0645 \u0627\u0644\u0647\u0627\u062a\u0641 \u ...
#     "source": {
#         "uri": "dostor.org",
#         "dataType": "news",
#         "title": "Dostor"
#     },
#     "authors": [],
#     "image": "https://www.dostor.org/upload/photo/news/281/7/500x282o/577.jpg?q=2",
#     "eventUri": null,
#     "sentiment": null,
#     "wgt": 305662260
# }

# %% [markdown]
# **Ex 3: Largest recent events on the topic of Brexit:**

# %%
q = QueryEventsIter(keywords="Brexit")

for event in q.execQuery(er, sortBy="size", maxItems=1):
    print(json.dumps(event, indent=4))
# Out:
# {
#     "uri": "eng-5028293",
#     "concepts": [
#         {
#             "uri": "http://en.wikipedia.org/wiki/Boris_Johnson",
#             "type": "person",
#             "score": 100,
#             "label": {
#                 "eng": "Boris Johnson"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Brexit",
#             "type": "wiki",
#             "score": 86,
#             "label": {
#                 "eng": "Brexit"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Parliament",
#             "type": "wiki",
#             "score": 79,
#             "label": {
#                 "eng": "Parliament"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_Kingdom",
#             "type": "loc",
#             "score": 71,
#             "label": {
#                 "eng": "United Kingdom"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "United Kingdom"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/European_Union",
#             "type": "loc",
#             "score": 66,
#             "label": {
#                 "eng": "European Union"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Prime_Minister_of_the_United_Kingdom",
#             "type": "wiki",
#             "score": 65,
#             "label": {
#                 "eng": "Prime Minister of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Elizabeth_II",
#             "type": "person",
#             "score": 55,
#             "label": {
#                 "eng": "Elizabeth II"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Parliament_of_the_United_Kingdom",
#             "type": "org",
#             "score": 50,
#             "label": {
#                 "eng": "Parliament of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Labour_Party_(UK)",
#             "type": "org",
#             "score": 39,
#             "label": {
#                 "eng": "Labour Party (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Democracy",
#             "type": "wiki",
#             "score": 33,
#             "label": {
#                 "eng": "Democracy"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/London",
#             "type": "loc",
#             "score": 33,
#             "label": {
#                 "eng": "London"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "London"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Jeremy_Corbyn",
#             "type": "person",
#             "score": 31,
#             "label": {
#                 "eng": "Jeremy Corbyn"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Prime_minister",
#             "type": "wiki",
#             "score": 30,
#             "label": {
#                 "eng": "Prime minister"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Motion_of_no_confidence",
#             "type": "wiki",
#             "score": 29,
#             "label": {
#                 "eng": "Motion of no confidence"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Conservative_Party_(UK)",
#             "type": "org",
#             "score": 25,
#             "label": {
#                 "eng": "Conservative Party (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/House_of_Commons_of_the_United_Kingdom",
#             "type": "org",
#             "score": 24,
#             "label": {
#                 "eng": "House of Commons of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Scotland",
#             "type": "loc",
#             "score": 24,
#             "label": {
#                 "eng": "Scotland"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Scotland"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Deputy_(legislator)",
#             "type": "wiki",
#             "score": 22,
#             "label": {
#                 "eng": "Deputy (legislator)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/John_Bercow",
#             "type": "person",
#             "score": 21,
#             "label": {
#                 "eng": "John Bercow"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Brexit_negotiations",
#             "type": "wiki",
#             "score": 19,
#             "label": {
#                 "eng": "Brexit negotiations"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Legislative_session",
#             "type": "wiki",
#             "score": 19,
#             "label": {
#                 "eng": "Legislative session"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Pound_sterling",
#             "type": "wiki",
#             "score": 19,
#             "label": {
#                 "eng": "Pound sterling"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/BBC",
#             "type": "org",
#             "score": 19,
#             "label": {
#                 "eng": "BBC"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Theresa_May",
#             "type": "person",
#             "score": 18,
#             "label": {
#                 "eng": "Theresa May"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Brussels",
#             "type": "loc",
#             "score": 17,
#             "label": {
#                 "eng": "Brussels"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Brussels"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Belgium"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Speech_from_the_throne",
#             "type": "wiki",
#             "score": 16,
#             "label": {
#                 "eng": "Speech from the throne"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Conservatism",
#             "type": "wiki",
#             "score": 14,
#             "label": {
#                 "eng": "Conservatism"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Coup_d'\u00e9tat",
#             "type": "wiki",
#             "score": 14,
#             "label": {
#                 "eng": "Coup d'\u00e9tat"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Twitter",
#             "type": "org",
#             "score": 14,
#             "label": {
#                 "eng": "Twitter"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Government",
#             "type": "wiki",
#             "score": 13,
#             "label": {
#                 "eng": "Government"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Member_of_parliament",
#             "type": "wiki",
#             "score": 12,
#             "label": {
#                 "eng": "Member of parliament"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Opposition_(politics)",
#             "type": "wiki",
#             "score": 12,
#             "label": {
#                 "eng": "Opposition (politics)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Government_of_the_United_Kingdom",
#             "type": "org",
#             "score": 12,
#             "label": {
#                 "eng": "Government of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_Kingdom_European_Union_membership_referendum,_2016",
#             "type": "wiki",
#             "score": 11,
#             "label": {
#                 "eng": "United Kingdom European Union membership referendum, 2016"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Constitution",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "Constitution"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Referendum",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "Referendum"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Liberal_Democrats_(UK)",
#             "type": "org",
#             "score": 9,
#             "label": {
#                 "eng": "Liberal Democrats (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/European_Council",
#             "type": "wiki",
#             "score": 9,
#             "label": {
#                 "eng": "European Council"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Northern_Ireland",
#             "type": "loc",
#             "score": 9,
#             "label": {
#                 "eng": "Northern Ireland"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Northern Ireland"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Europe",
#             "type": "loc",
#             "score": 8,
#             "label": {
#                 "eng": "Europe"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Donald_Trump",
#             "type": "person",
#             "score": 8,
#             "label": {
#                 "eng": "Donald Trump"
#             }
#         },
#         {
#             "uri": "http://zh.wikipedia.org/wiki/\u82f1\u56fd\u56fd\u4f1a",
#             "type": "org",
#             "score": 7,
#             "label": {
#                 "eng": "\u82f1\u56fd\u56fd\u4f1a"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Ireland",
#             "type": "loc",
#             "score": 7,
#             "label": {
#                 "eng": "Ireland"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Ireland"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Jo_Swinson",
#             "type": "person",
#             "score": 6,
#             "label": {
#                 "eng": "Jo Swinson"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Nicola_Sturgeon",
#             "type": "person",
#             "score": 6,
#             "label": {
#                 "eng": "Nicola Sturgeon"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Scottish_National_Party",
#             "type": "org",
#             "score": 6,
#             "label": {
#                 "eng": "Scottish National Party"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Philip_Hammond",
#             "type": "person",
#             "score": 6,
#             "label": {
#                 "eng": "Philip Hammond"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Edinburgh",
#             "type": "loc",
#             "score": 6,
#             "label": {
#                 "eng": "Edinburgh"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Edinburgh"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Dominic_Grieve",
#             "type": "person",
#             "score": 5,
#             "label": {
#                 "eng": "Dominic Grieve"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/England",
#             "type": "loc",
#             "score": 5,
#             "label": {
#                 "eng": "England"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "England"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         }
#     ],
#     "eventDate": "2019-08-27",
#     "totalArticleCount": 2800,
#     "title": {
#         "eng": "Government asks Queen to suspend Parliament",
#         "fra": "Brexit: Hugh Grant \u00e9trille Boris Johnson et lui demande d'aller \" se faire foutre \"",
#         "zho": "\u82f1\u56fd\u8131\u6b27\uff1a\u8bae\u4f1a\u88ab\u505c\u6446\u5982\u4f55\u963b\u6b62\u65e0\u534f\u8bae\u786c\u8131",
#         "por": "Brexit a f\u00f3rceps - 30/08/2019 - Opini\u00e3o - Folha",
#         "spa": "Boris Johnson planea pedir a la Reina que suspenda el Parlamento",
#         "deu": "Selbst Strassensperren sind m\u00f6glich",
#         "ara": "\u062a\u0631\u0627\u0645\u0628: \"\u0628\u0648\u0631\u064a\u0633 \u0627\u0644\u0639\u0638\u064a\u0645\" \u0647\u0648 \u0645\u0627 \u0643\u0627\u0646\u062a \u062a\u0628\u062d\u062b \u0639\u0646\u0647 \u0628\u0631\u064a\u0637\u0627\u0646\u064a\u0627",
#         "rus": "\u0411\u0438\u0442\u0432\u0430 \u0437\u0430 Brexit: \u043a\u043e\u0440\u043e\u043b\u0435\u0432\u0430 \u043f\u043e\u0434\u0434\u0435\u0440\u0436\u0430\u043b\u0430 \u0411\u043e\u0440\u0438\u0441\u0430 \u0414\u0436\u043e\u043d\u0441\u043e\u043d\u0430",
#         "tur": "Parlamentoyu tatil karar\u0131na kar\u015f\u0131 imza say\u0131s\u0131 milyonu a\u015ft\u0131",
#         "ita": "Boris Johnson ha chiesto alla Regina di sospendere il parlamento",
#         "nld": "Britse regering wil parlement in aanloop naar brexit schorsen, oppositie woedend ",
#         "cat": "L'ensurt definitiu pel Brexit? - Editorial Vicent Partal",
#         "dan": "Boris Johnson beder dronning Elizabeth suspendere parlamentet",
#         "ron": "UE, prima reac\u0163ie dup\u0103 ce regina a aprobat suspendarea Parlamentului britanic | Romania Libera",
#         "hrv": "Velika Britanija: Kraljica je odobrila suspenziju parlamenta",
#         "ukr": "\u0414\u0436\u043e\u043d\u0441\u043e\u043d \u043f\u0440\u0438\u0437\u0443\u043f\u0438\u043d\u0438\u0442\u044c \u0440\u043e\u0431\u043e\u0442\u0443 \u043f\u0430\u0440\u043b\u0430\u043c\u0435\u043d\u0442\u0443 \u043f\u0435\u0440\u0435\u0434 Brexit",
#         "srp": "\u040f\u043e\u043d\u0441\u043e\u043d \u0441\u0430\u043c\u043e\u0443\u0432\u0435\u0440\u0435\u043d, \u041c\u0430\u043a\u0440\u043e\u043d \u043d\u0435 \u043e\u0434\u0441\u0442\u0443\u043f\u0430",
#         "slv": "Britanska opozicija namerava prepre\u010diti brexit brez dogovora"
#     },
#     "summary": {
#         "eng": "The government has asked the Queen to suspend Parliament just days after MPs return to work in September - and only a few weeks before the Brexit deadline.\n\nBoris Johnson said a Queen's Speech would take place after the suspension, on 14 October, to outline his \"very exciting agenda\".\n\nBut it means the time MPs have to pass laws to stop a no-deal Brexit on 31 October would be cut.\n\nHouse of Commons Speaker John Bercow said it was a \"constitutional outrage\".\n\nThe speaker, who does not traditionall",
#         "fra": "L'acteur britannique a vivement r\u00e9agi sur Twitter \u00e0 la d\u00e9cision du Premier ministre de suspendre le Parlement jusqu'au 14 octobre.\n\nL'acteur Hugh Grant, connu pour ses r\u00f4les dans des com\u00e9dies romantiques comme Coup de foudre \u00e0 Notting Hill, s'en est violemment pris au Premier ministre britannique Boris Johnson et \u00e0 sa d\u00e9cision de suspendre le Parlement jusqu'au 14 octobre.\n\n\"Vous ne fouterez pas en l'air le futur de mes enfants\", a \u00e9crit sur son compte Twitter le com\u00e9dien. \"Vous ne d\u00e9t",
#         "zho": "\u8fd9\u662f\u5916\u90e8\u94fe\u63a5\uff0c\u6d4f\u89c8\u5668\u5c06\u6253\u5f00\u53e6\u4e00\u4e2a\u7a97\u53e3\n\n\u79bb10\u670831\u65e5\u82f1\u56fd\u8131\u6b27\u6700\u540e\u671f\u9650\u53ea\u6709\u77ed\u77ed\u4e24\u4e2a\u591a\u6708\u4e86\u3002\u8fd9\u4e00\u56f0\u6270\u82f1\u56fd3\u5e74\u591a\u7684\u653f\u6cbb\u5927\u51b3\u5b9a\uff0c\u81f3\u4eca\u4ecd\u7136\u6ca1\u6709\u6e05\u6670\u7684\u8d70\u5411\u3002\u82f1\u56fd\u80fd\u4e0e\u6b27\u76df\u8fbe\u6210\u8131\u6b27\u534f\u8bae\u5417\uff1f\u5982\u679c\u6ca1\u6709\u534f\u8bae\uff0c\u82f1\u56fd\u662f\u5426\u5c31\u6b64\u5f3a\u884c\u786c\u5206\u624b\u3002\n\n\u6b63\u662f\u5728\u5982\u6b64\u5c40\u52bf\u4e0d\u660e\u6717\u7684\u5173\u952e\u65f6\u523b\uff0c\u9996\u76f8\u9c8d\u91cc\u65af\u00b7\u7ea6\u7ff0\u900a\u4e3b\u5bfc\u7684\u653f\u5e9c\u62ff\u51fa\u4e86\u4e00\u4e2a\u9707\u60ca\u82f1\u56fd\u4e0a\u4e0b\u4e43\u81f3\u6d77\u5185\u5916\u7684\u529e\u6cd5\uff1a\u62a5\u8bf7\u5973\u738b\u4f0a\u4e3d\u838e\u767d\u4e8c\u4e16\uff0c\u8ba9\u8fc7\u5b8c\u6691",
#         "por": "Faltando apenas dois meses para o fim do prazo acordado para o brexit, a sa\u00edda do Reino Unido da Uni\u00e3o Europeia (UE), o primeiro-ministro brit\u00e2nico, Boris Johnson, deflagrou uma crise pol\u00edtica ao operar a suspens\u00e3o das atividades do Parlamento por cinco semanas.\n\nEmbora a medida esteja prevista no sistema parlamentarista do pa\u00eds, com a fun\u00e7\u00e3o de iniciar uma nova sess\u00e3o legislativa, o prazo solicitado por Johnson \u00e0 rainha -- o mais longo desde 1945 -- deixa clara a controversa inten\u00e7\u00e3o",
#         "spa": "Reino Unido. Acuerdo de la oposici\u00f3n para frenar el Brexit sin acuerdo por la v\u00eda legislativa\n\nLa Reina Isabel II podr\u00eda recibir hoy la petici\u00f3n del Gobierno de Boris Johnson de suspender el Parlamento en septiembre y hasta el pr\u00f3ximo 14 de octubre, para evitar que los diputados tengan tiempo de aprobar una pr\u00f3rroga del Brexit y lograr que la salida de la Uni\u00f3n Europea se produzca el 31 de octubre.\n\nAs\u00ed, si Johnson consigue suspender el Parlamento durante cinco semanas, bloquear\u00e1 cualqui",
#         "deu": "Einen ersten, schweren D\u00e4mpfer im Kampf gegen den kompromisslosen Kurs von Boris Johnson haben seine Gegner schon am Freitag bekommen: Das schottische Gericht, vor dem eine Gruppe von 75 Abgeordneten gegen die am Mittwoch verk\u00fcndete zeitweilige Schliessung des Parlaments geklagt hatte, hat in einer wegen Dringlichkeit vorgezogenen Anh\u00f6rung kein schnelles Urteil f\u00e4llen wollen. Der Richter sagte, er wolle erst alle Argumente h\u00f6ren; das Verfahren soll nun Mitte n\u00e4chster Woche weitergehen.\n\nDan",
#         "ara": "\u0627\u0644\u0645\u0635\u062f\u0631: \u0644\u0646\u062f\u0646 - \u0648\u0643\u0627\u0644\u0627\u062a \u0627\u0644\u062a\u0627\u0631\u064a\u062e: 29 \u0623\u063a\u0633\u0637\u0633 2019\n\n\u0641\u064a \u062e\u0637\u0648\u0629 \u062a\u0627\u0631\u064a\u062e\u064a\u0629\u060c \u0639\u0644\u0651\u0642 \u0631\u0626\u064a\u0633 \u0627\u0644\u0648\u0632\u0631\u0627\u0621 \u0627\u0644\u0628\u0631\u064a\u0637\u0627\u0646\u064a \u0628\u0648\u0631\u064a\u0633 \u062c\u0648\u0646\u0633\u0648\u0646 \u0623\u0639\u0645\u0627\u0644 \u0627\u0644\u0628\u0631\u0644\u0645\u0627\u0646 \u0645\u0646 \u0627\u0644\u0623\u0633\u0628\u0648\u0639 \u0627\u0644\u062b\u0627\u0646\u064a \u0641\u064a \u0627\u0644\u0634\u0647\u0631 \u0627\u0644\u0645\u0642\u0628\u0644 \u0648\u062d\u062a\u0649 14 \u0623\u0643\u062a\u0648\u0628\u0631\u060c \u0623\u064a \u0642\u0628\u0644 \u0623\u0633\u0628\u0648\u0639\u064a\u0646 \u0641\u0642\u0637 \u0645\u0646 \u0627\u0644\u0645\u0648\u0639\u062f \u0627\u0644\u0645\u0642\u0631\u0631 \u0644\u0628\u0631\u064a\u0643\u0633\u062a\u060c \u0648\u0647\u0648 \u0645\u0627 \u0648\u0635\u0641\u0647 \u0631\u0626\u064a\u0633 \u0645\u062c\u0644\u0633 \u0627\u0644\u0639\u0645\u0648\u0645 \u0628\u0640 \"\u0627\u0644\u0641\u0636\u064a\u062d\u0629 \u0627\u0644\u062f\u0633\u062a\u0648\u0631\u064a\u0629\"\u060c \u0641\u064a\u0645\u0627 \u0648\u0635\u0641\u0647 \u0622\u062e\u0631\u0648",
#         "rus": "\u041c\u0430\u0441\u0442\u0435\u0440\u0430 \u043d\u0430 \u0432\u0441\u0435 \u0440\u0443\u043a\u0438: \u043a\u0442\u043e \u043f\u043e\u043a\u043e\u0440\u0438\u0442 \u041a\u0430\u0437\u0430\u043d\u044c\n\n\u041f\u0440\u0435\u043c\u044c\u0435\u0440-\u043c\u0438\u043d\u0438\u0441\u0442\u0440 \u0412\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u0438 \u0411\u043e\u0440\u0438\u0441 \u0414\u0436\u043e\u043d\u0441\u043e\u043d \u0432 \u0440\u0430\u0437\u0433\u0430\u0440 \u043f\u043e\u0434\u0433\u043e\u0442\u043e\u0432\u043a\u0438 \u043a Brexit, \u043a\u043e\u0442\u043e\u0440\u044b\u0439 \u043d\u0430\u043c\u0435\u0447\u0435\u043d \u043d\u0430 31 \u043e\u043a\u0442\u044f\u0431\u0440\u044f, \u043e\u0431\u044a\u044f\u0432\u0438\u043b \u043e \u043f\u0440\u0438\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043a\u0435 \u0440\u0430\u0431\u043e\u0442\u044b \u043f\u0430\u0440\u043b\u0430\u043c\u0435\u043d\u0442\u0430 \u0434\u043e 14 \u043e\u043a\u0442\u044f\u0431\u0440\u044f.\n\n\"\u041f\u0440\u0435\u043c\u044c\u0435\u0440-\u043c\u0438\u043d\u0438\u0441\u0442\u0440 \u043f\u043e\u0433\u043e\u0432\u043e\u0440\u0438\u043b \u0441 \u0415\u0435 \u0412\u0435\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e\u043c \u043a\u043e\u0440\u043e\u043b\u0435\u0432\u043e\u0439 \u0438 \u043f\u043e\u043f\u0440\u043e\u0441\u0438\u043b \u0435\u0435 \u0437\u0430\u0432\u0435\u0440\u0448\u0438",
#         "tur": "\u0130ngiliz parlamentosunun dilek\u00e7elere ayr\u0131lm\u0131\u015f internet sitesinde, Johnson'\u0131n parlamentoyu tatil etme karar\u0131na kar\u015f\u0131 imzaya a\u00e7\u0131lan dilek\u00e7eye at\u0131lan imza say\u0131s\u0131 bir g\u00fcnden az bir s\u00fcrede 1 milyon 300 bine yakla\u015ft\u0131.\n\nDilek\u00e7ede \"50. madde s\u00fcresi yeterince uzat\u0131lmad\u0131k\u00e7a ve \u0130ngiltere'nin AB'den ayr\u0131lma karar\u0131 iptal edilmedik\u00e7e parlamento tatil edilmemeli veya da\u011f\u0131t\u0131lmamal\u0131.\" talebi yer al\u0131yor.\n\n\u0130ngiltere'de 10 bin imzay\u0131 bulan dilek\u00e7elere h\u00fck\u00fcmetin yan\u0131t vermesi ger",
#         "ita": "I partiti di opposizione, dopo una riunione tra i rispettivi leader, avevano deciso di unire le forze per trovare \"modi concreti\" con cui impedire una Brexit no-deal, scenario verso cui invece tende Johnson. Mentre i conservatori minimizzano, le opposizioni insorgono per la decisione del premier\n\nIl governo del premier britannico Boris Johnson ha chiesto a Elisabetta II di sospendere i lavori del Parlamento e ha confermato la data del 14 ottobre, come il giorno in cui \u00e8 attesto il discorso della",
#         "nld": "De Britse regering wil het parlement een aantal weken schorsen. Volgens premier Johnson is dat nodig omdat hij op 14 oktober de nieuwe plannen van zijn regering wil presenteren. De voorzitter van het Lagerhuis en de oppositie zijn woedend.\n\nJohnson zou het parlement buitenspel willen zetten om op die manier te voorkomen dat het Lagerhuis een no-deal-brexit op 31 oktober dwarsboomt. Johnson spreekt dit tegen en zegt dat er \"genoeg tijd\" overblijft om over de brexit te debatteren.\n\nAls het aan John",
#         "cat": "Ahir el nou primer ministre brit\u00e0nic, Boris Johnson, va demanar a la reina Elisabet la pr\u00f2rroga de les vacances del parlament. Fent servir arguments t\u00e8cnics, com ara la durada de les sessions la primera part de l'any, Johnson ha aconseguit que el parlament de Westminster no es puga reunir fins el 14 d'octubre. I l'eixida del Brexit sense acord, la m\u00e9s dura de totes, \u00e9s prevista el 31 del mateix mes.\n\nLa intencionalitat pol\u00edtica de la demanda \u00e9s evident: Johnson vol impedir que el parlament",
#         "dan": "Storbritanniens premierminister Boris Johnson vil g\u00e5 til dronning Elizabeth og bede hende suspendere det britiske parlament.\n\nHan \u00f8nsker, at parlamentet suspenderes i begyndelsen af september,og at dronningens \u00e5bningstale i parlementet f\u00f8rst holdes 14. oktober, bekr\u00e6fter han if\u00f8lge BBC.\n\nBoris Johnson afviser imidlertid, at han fors\u00f8ger at k\u00f8re parlamentet ud p\u00e5 et sidespor i brexit-processen, skriver nyhedsbureauet Reuters.\n\nHvis parlamentet suspenderes, vil det blive vanskeligt for bri",
#         "ron": "Guy Verhofstadt, coordonatorul Parlamentului European pe tema Brexit, a denun\u0163at, miercuri sear\u0103, decizia premierului britanic, Boris Johnson, de a suspenda Parlamentul de la Londra, afirm\u00e2nd c\u0103 este o ac\u0163iune \"sinistr\u0103\".\n\n\"Preluarea din nou a controlului asupra \u0163\u0103rii nu a p\u0103rut niciodat\u0103 mai sinistr\u0103. \u00cen calitatea de parlamentar, sunt solidar cu cei care lupt\u0103 s\u0103 le fie auzite vocile. Suprimarea dezbaterilor privind decizii profunde este improbabil s\u0103 contribuie la o rela\u0163ie viit",
#         "hrv": "Tada bi se trebao odr\u017eati kralji\u010din govor u kojemu \u0107e biti iznijeti planovi vlade za Brexit.\n\nRok za Brexit je 31. listopada.\n\nPodsjetimo, britanski premijer Boris Johnson \u017eeli ograni\u010diti mogu\u0107nost da mu parlament poremeti plan za Brexit tako \u0161to je zatra\u017eio da se skrati vrijeme zasjedanja od sada pa do planiranog izlaska iz Unije 31. listopada. To je izazvalo pomutnju me\u0111u politi\u010dkim protivnicima koji ga optu\u017euju za \"dr\u017eavni udar na britanski na\u010din\".\n\nU dosad najodva\u017enijem potezu d",
#         "ukr": "\u041f\u0440\u0435\u043c'\u0454\u0440-\u043c\u0456\u043d\u0456\u0441\u0442\u0440 \u0411\u0440\u0438\u0442\u0430\u043d\u0456\u0457 \u0411\u043e\u0440\u0438\u0441 \u0414\u0436\u043e\u043d\u0441\u043e\u043d \u043f\u0440\u0438\u0437\u0443\u043f\u0438\u043d\u0438\u0442\u044c \u0440\u043e\u0431\u043e\u0442\u0443 \u043f\u0430\u0440\u043b\u0430\u043c\u0435\u043d\u0442\u0443, \u0449\u043e\u0431 \u043d\u0435 \u0434\u0430\u0442\u0438 \u0434\u0435\u043f\u0443\u0442\u0430\u0442\u0430\u043c \u0443\u0445\u0432\u0430\u043b\u0438\u0442\u0438 \u0431\u0443\u0434\u044c-\u044f\u043a\u0456 \u0437\u0430\u043a\u043e\u043d\u0438, \u044f\u043a\u0456 \u043c\u043e\u0433\u043b\u0438 \u0431 \u043f\u0435\u0440\u0435\u0448\u043a\u043e\u0434\u0438\u0442\u0438 \u0439\u043e\u043c\u0443 \u0432\u0438\u0432\u0435\u0441\u0442\u0438 \u043a\u0440\u0430\u0457\u043d\u0443 \u0437 \u0404\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u044c\u043a\u043e\u0433\u043e \u0421\u043e\u044e\u0437\u0443 \u0431\u0435\u0437 \u0443\u0433\u043e\u0434\u0438.\n\n\u041f\u0440\u043e \u0446\u0435 \u043f\u043e\u0432\u0456\u0434\u043e\u043c\u043b\u044f\u0454 AP.\n\n\u0417\u0430\u0437\u043d\u0430\u0447\u0430\u0454\u0442\u044c\u0441\u044f, \u0449\u043e \u0432\u0456\u043d \u043c\u0430\u0454 \u043d\u0430\u043c\u0456\u0440 \u043f\u0440\u043e\u0441\u0438\u0442\u0438 \u043a\u043e\u0440\u043e\u043b\u0435\u0432\u0443 \u0404\u043b\u0438\u0437\u0430\u0432\u0435\u0442",
#         "srp": "\u041f\u0440\u0435\u043c\u0438\u0458\u0435\u0440 \u0411\u0440\u0438\u0442\u0430\u043d\u0438\u0458\u0435 \u0411\u043e\u0440\u0438\u0441 \u040f\u043e\u043d\u0441\u043e\u043d \u0438\u0437\u0433\u043b\u0435\u0434\u0430\u043e \u0458\u0435 \u0441\u0430\u043c\u043e\u0443\u0432\u0435\u0440\u0435\u043d\u043e \u043d\u0430 \u0441\u0430\u0441\u0442\u0430\u043d\u043a\u0443 \u0441\u0430 \u043f\u0440\u0435\u0434\u0441\u0435\u0434\u043d\u0438\u043a\u043e\u043c \u0424\u0440\u0430\u043d\u0446\u0443\u0441\u043a\u0435 \u0415\u043c\u0430\u043d\u0443\u0435\u043b\u043e\u043c \u041c\u0430\u043a\u0440\u043e\u043d\u043e\u043c, \u043d\u0430 \u043a\u043e\u043c \u0458\u0435 \u0437\u0430\u0442\u0440\u0430\u0436\u0438\u043e \u043d\u043e\u0432\u0435 \u043f\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u0435 \u043e \u0411\u0440\u0435\u0433\u0437\u0438\u0442\u0443.\n\n\u040f\u043e\u043d\u0441\u043e\u043d \u0458\u0435, \u043a\u0430\u043a\u043e \u043d\u0430\u0432\u043e\u0434\u0438 \u0410\u041f, \u043a\u0440\u0435\u043d\u0443\u043e \u0443 \"\u043e\u0444\u0430\u043d\u0437\u0438\u0432\u0443 \u0448\u0430\u0440\u043c\u043e\u043c\", \u043d\u0430\u0433\u043b\u0430\u0441\u0438\u0432\u0448\u0438 \u0434\u0430 \u0412\u0435\u043b\u0438\u043a\u0430 \u0411\u0440\u0438\u0442\u0430\u043d\u0438\u0458\u0430 \u0436\u0435\u043b\u0438 \u0434\u043e\u0433\u043e\u0432\u043e\u0440 \u0441\u0430 \u0415\u0432\u0440\u043e\u043f\u0441\u043a\u043e\u043c \u0443",
#         "slv": "Opozicija bo izstop brez dogovora sku\u0161ala prepre\u010diti s sprejetjem zakonodaje v parlamentu, poro\u010da britanski BBC.\n\nStranke v skupni izjavi niso pojasnile, kako in kdaj bodo sku\u0161ali po zakonodajni poti prepre\u010diti brexit brez dogovora. Poslanka zelenih Caroline Lucas je ob tem povedala, da je zakonodajna pot najvarnej\u0161a pot za odlog izstopa, ki je trenutno predviden 31. oktobra.\n\nVodja liberalnih demokratov Jo Swinson je po sre\u010danju dejala, da glasovanje o nezaupnici premierju ostaja zadnja m"
#     },
#     "location": {
#         "type": "place",
#         "label": {
#             "eng": "London"
#         },
#         "country": {
#             "type": "country",
#             "label": {
#                 "eng": "United Kingdom"
#             }
#         }
#     },
#     "categories": [
#         {
#             "uri": "dmoz/Society/Government",
#             "label": "dmoz/Society/Government",
#             "wgt": 11
#         },
#         {
#             "uri": "dmoz/Society/Politics",
#             "label": "dmoz/Society/Politics",
#             "wgt": 12
#         },
#         {
#             "uri": "dmoz/Society/Government/Parliaments_and_Legislatures",
#             "label": "dmoz/Society/Government/Parliaments and Legislatures",
#             "wgt": 24
#         },
#         {
#             "uri": "news/Politics",
#             "label": "news/Politics",
#             "wgt": 91
#         }
#     ],
#     "articleCounts": {
#         "eng": 827,
#         "fra": 341,
#         "zho": 325,
#         "por": 204,
#         "spa": 257,
#         "deu": 229,
#         "ara": 169,
#         "rus": 113,
#         "tur": 58,
#         "ita": 68,
#         "nld": 53,
#         "cat": 35,
#         "dan": 34,
#         "ron": 34,
#         "hrv": 20,
#         "ukr": 12,
#         "srp": 11,
#         "slv": 10
#     },
#     "sentiment": -0.05882352941176472,
#     "wgt": 2800
# }

# %% [markdown]
# ## Auto-suggestion methods
# Several API calls accept parameters that are unique identifiers - examples of such parameters are concepts, categories and sources. If you just know a pretty name or a label of such parameter, then you can use the auto-suggest methods to obtain the unique identifier for the parameter.
#
# If you know that there is a category for Investing, then you can get the URI for it like this:

# %%
er.getCategoryUri("investing")
# Out:
# 'dmoz/Business/Investing'

# %% [markdown]
# Similarly, if you want to filter based on the sources, then you can get the source URI by providing the source name or the domain name:

# %%
print(er.getSourceUri("new york times"))
print(er.getSourceUri("nytimes"))
# Out:
# nytimes.com
# nytimes.com

# %% [markdown]
# For concepts, the URIs are URLs of the corresponding wikipedia pages.

# %%
er.getConceptUri("Obama")
# Out:
# 'http://en.wikipedia.org/wiki/Barack_Obama'

# %% [markdown]
# The autosuggestion works even for the company tickers:

# %%
er.getConceptUri("AAPL")
# Out:
# 'http://en.wikipedia.org/wiki/Apple_Inc.'

# %% [markdown]
# ## Searching for articles
#
# There are two classes that can be used for searching for articles - `QueryArticlesIter` and `QueryArticles`. Use `QueryArticlesIter` when you simply want to download articles matching a query. `QueryArticles` can instead be used when you need to download various summaries of the results, like top concepts, top sources, top authors, etc.
#
# Both classes allow you to specify in the constructor several filters, such as:
# - `keywords` - find articles that mention the keywords or phrases
# - `conceptUri` - find articles that mention the concept(s)
# - `categoryUri` - find articles that are about category(s)
# - `sourceUri` - find articles written by the given publisher(s)
# - `sourceLocationUri` - find articles written by publishers located in the given location
# - `authorUri` - find articles written by the given author(s)
# - `locationUri` - find articles that mention the given location in the dateline
# - `lang` - find articles written in the given language
# - `dateStart` - find articles that were written on the given date or later (in the `YYYY-MM-DD` format)
# - `dateEnd` - find articles that were written before or on the given date (in the `YYYY-MM-DD` format)
# - `keywordsLoc` - if keywords are provided, where should we search for the keyword (`title` or `body` (default))
# - `minSentiment`, `maxSentiment` - min and max value of the sentiment (from -1 to 1)
# - `startSourceRankPercentile` - starting percentile of the sources to consider in the results (default: 0). Value should be in range 0-90 and divisible by 10.
# - `endSourceRankPercentile` - ending percentile of the sources to consider in the results (default: 100). Value should be in range 10-100 and divisible by 10.
# - `ignoreKeywords`, `ignoreConceptUri`, `ignoreCategoryUri`, ... - from the articles that match the rest of the conditions, exclude the articles that match any of the provided filters
# - `dataType` - which data types should be included in the results - `news` (default), `blog` or `pr`
#
# When multiple filters are specified, the results have to match **all** of the provided filters. For example, when keywords and sources are specified, the results will be articles written by these sources that mention the provided keywords.
#
# If you'll want to make a search, where **any** of the specified filtes are true, you'll have to use the [Advanced Query Language](https://github.com/EventRegistry/event-registry-python/wiki/Searching-for-articles#advanced-query-language)

# %% [markdown]
# ### Executing a search
# When you create an instance of a `QueryArticlesIter` class, you can then retrieve the resulting articles by calling the `execQuery` method.
# The `execQuery` method will iterate over the resulting articles, so you can simply use it in a `for` loop.
# In the method call you also need to provide the instance of your `EventRegistry` class since it will be used to iteratively
# download the matching articles in batches of 100 items per call.
#
# ```
# q = QueryArticlesIter(keywords="Tesla")
# for art in q.execQuery(er, sortBy = "date", maxItems = 300):
#     print(art)
# ```
#
# Please note two important parameters:
#
# - `sortBy` parameter determines how the articles should be sorted before they are retrieved. Beside the date, you can also sort by relevance, source importance, shares on social media and others.
# - `maxItems` parameter determines how many of the matching articles to retrieve before the `for` loop finishes. **It is very important that you set this parameter if you don't want to download all matching results.**
#
# Please check the [documentation page](https://github.com/EventRegistry/event-registry-python/wiki/Searching-for-articles#queryarticlesiter) to see the full list of parameters and their descriptions related to the `execQuery` method.

# %% [markdown]
# ### Using `QueryItems.AND()` and `QueryItems.OR()` when providing a list of filters of the same type
# When you want to provide several keywords, concepts, categories, etc., you have to explicitly determine whether you'd like that the results mention **all** of them, or **any** of them.
#
# To do that, you can use the `QueryItems.AND()` and `QueryItems.OR()` methods

# %%
q = QueryArticlesIter(keywords=QueryItems.OR(["Samsung", "Apple", "Google"]))
print("Count with any of the companies: %d" % q.count(er))

q = QueryArticlesIter(keywords="Samsung")
print("Count mentioning Samsung: %d" % q.count(er))
# Out:
# Count with any of the companies: 216551
# Count mentioning Samsung: 38654

# %% [markdown]
# ### Retrieving different properties about articles
# When retrieving articles, you can retrieve a lot of properties. Some properties are not returned by default, such as list of mentioned *concepts, categories, links, videos*, etc.
#
# To modify which properties to return, use specify the `returnInfo` parameter of type `ReturnInfo`. With `ReturnInfo` you can specify which parameters will be returned for all available returned objects, like articles, concepts, categories, events, ...
#
# ```QueryArticlesIter(..., returnInfo = ReturnInfo(...))```
#
# The detailed description of `ReturnInfo` and available parameters are described [here](https://github.com/EventRegistry/event-registry-python/wiki/ReturnInfo-class).

# %%
ReturnInfo(
    articleInfo=ArticleInfoFlags(),  # details about the articles to return
    eventInfo=EventInfoFlags(),  # details about the events to return
    sourceInfo=SourceInfoFlags(),  # details about the news sources to return
    categoryInfo=CategoryInfoFlags(),  # details about the categories to return
    conceptInfo=ConceptInfoFlags(),  # details about the concepts to return
    locationInfo=LocationInfoFlags(),  # details about the locations to return
    storyInfo=StoryInfoFlags(),  # details about the stories to return
    conceptClassInfo=ConceptClassInfoFlags(),  # details about the concept classes to return
    conceptFolderInfo=ConceptFolderInfoFlags(),
)  # details about the concept folders to return

# %% [markdown]
# An example query that will return list of concepts, categories, source location, and a list of potential duplicates of the article:

# %%
q = QueryArticlesIter(keywords="Trump", sourceUri="nytimes.com")
for art in q.execQuery(
    er,
    sortBy="date",
    maxItems=1,
    returnInfo=ReturnInfo(
        articleInfo=ArticleInfoFlags(
            concepts=True,
            categories=True,
            duplicateList=True,
            location=True,
            bodyLen=300,
        ),
        sourceInfo=SourceInfoFlags(location=True, image=True),
    ),
):
    print(json.dumps(art, indent=4))
# Out:
# {
#     "uri": "1253032895",
#     "lang": "eng",
#     "isDuplicate": false,
#     "date": "2019-09-11",
#     "time": "04:07:00",
#     "dateTime": "2019-09-11T04:07:00Z",
#     "dataType": "news",
#     "sim": 0,
#     "url": "https://www.nytimes.com/2019/09/10/pageoneplus/corrections-september-11-2019.html",
#     "title": "Corrections: September 11, 2019.",
#     "body": "INTERNATIONAL\n\nAn article on Sunday about an Iranian oil tanker anchored off the coast of Syria incorrectly described the release of satellite images of the Adrian Darya 1. The images were released by the space technology company Maxar Technologies, not by two companies.\n\n*\n\nAn article on Tuesday ...",
#     "source": {
#         "uri": "nytimes.com",
#         "dataType": "news",
#         "title": "The New York Times",
#         "location": {
#             "type": "place",
#             "label": {
#                 "eng": "New York City"
#             },
#             "country": {
#                 "type": "country",
#                 "label": {
#                     "eng": "United States"
#                 }
#             }
#         },
#         "locationValidated": true,
#         "image": "http://pbs.twimg.com/profile_images/758384037589348352/KB3RFwFm_bigger.jpg",
#         "thumbImage": "http://pbs.twimg.com/profile_images/758384037589348352/KB3RFwFm_mini.jpg",
#         "favicon": "https://static01.nyt.com/favicon.ico"
#     },
#     "authors": [],
#     "concepts": [
#         {
#             "uri": "http://en.wikipedia.org/wiki/Satellite_imagery",
#             "type": "wiki",
#             "score": 4,
#             "label": {
#                 "eng": "Satellite imagery"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Oil_tanker",
#             "type": "wiki",
#             "score": 4,
#             "label": {
#                 "eng": "Oil tanker"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Syria",
#             "type": "loc",
#             "score": 4,
#             "label": {
#                 "eng": "Syria"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Syria"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Nigeria",
#             "type": "loc",
#             "score": 4,
#             "label": {
#                 "eng": "Nigeria"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Nigeria"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Iran",
#             "type": "loc",
#             "score": 4,
#             "label": {
#                 "eng": "Iran"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Iran"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/2016_United_States_presidential_election",
#             "type": "wiki",
#             "score": 3,
#             "label": {
#                 "eng": "2016 United States presidential election"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Maxar_Technologies",
#             "type": "wiki",
#             "score": 3,
#             "label": {
#                 "eng": "Maxar Technologies"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Mark_Sanford",
#             "type": "person",
#             "score": 3,
#             "label": {
#                 "eng": "Mark Sanford"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Air_Peace",
#             "type": "org",
#             "score": 3,
#             "label": {
#                 "eng": "Air Peace"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Lower_Manhattan",
#             "type": "loc",
#             "score": 3,
#             "label": {
#                 "eng": "Lower Manhattan"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Bird_migration",
#             "type": "wiki",
#             "score": 3,
#             "label": {
#                 "eng": "Bird migration"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Bill_Weld",
#             "type": "person",
#             "score": 3,
#             "label": {
#                 "eng": "Bill Weld"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Libertarian_Party_(United_States)",
#             "type": "org",
#             "score": 3,
#             "label": {
#                 "eng": "Libertarian Party (United States)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Governor",
#             "type": "wiki",
#             "score": 3,
#             "label": {
#                 "eng": "Governor"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Donald_Trump",
#             "type": "person",
#             "score": 3,
#             "label": {
#                 "eng": "Donald Trump"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Airline",
#             "type": "wiki",
#             "score": 3,
#             "label": {
#                 "eng": "Airline"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/South_Carolina",
#             "type": "loc",
#             "score": 3,
#             "label": {
#                 "eng": "South Carolina"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "South Carolina"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United States"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/South_Africa",
#             "type": "loc",
#             "score": 3,
#             "label": {
#                 "eng": "South Africa"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "South Africa"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Alice_Guy-Blach\u00e9",
#             "type": "person",
#             "score": 2,
#             "label": {
#                 "eng": "Alice Guy-Blach\u00e9"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Brett_Kavanaugh",
#             "type": "person",
#             "score": 2,
#             "label": {
#                 "eng": "Brett Kavanaugh"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Flight_International",
#             "type": "wiki",
#             "score": 2,
#             "label": {
#                 "eng": "Flight International"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Consumer_Financial_Protection_Bureau",
#             "type": "org",
#             "score": 2,
#             "label": {
#                 "eng": "Consumer Financial Protection Bureau"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Yale_Law_School",
#             "type": "org",
#             "score": 2,
#             "label": {
#                 "eng": "Yale Law School"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Madonna_(entertainer)",
#             "type": "person",
#             "score": 2,
#             "label": {
#                 "eng": "Madonna (entertainer)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Supreme_Court_of_the_United_States",
#             "type": "org",
#             "score": 2,
#             "label": {
#                 "eng": "Supreme Court of the United States"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Government_agency",
#             "type": "wiki",
#             "score": 2,
#             "label": {
#                 "eng": "Government agency"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Meritocracy",
#             "type": "wiki",
#             "score": 2,
#             "label": {
#                 "eng": "Meritocracy"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Lawsuit",
#             "type": "wiki",
#             "score": 2,
#             "label": {
#                 "eng": "Lawsuit"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Financial_services",
#             "type": "wiki",
#             "score": 2,
#             "label": {
#                 "eng": "Financial services"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/New_Mexico",
#             "type": "loc",
#             "score": 2,
#             "label": {
#                 "eng": "New Mexico"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "New Mexico"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United States"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Carlsbad,_California",
#             "type": "loc",
#             "score": 2,
#             "label": {
#                 "eng": "Carlsbad, California"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Carlsbad, California"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United States"
#                     }
#                 }
#             }
#         }
#     ],
#     "categories": [
#         {
#             "uri": "dmoz/Society/Issues",
#             "label": "dmoz/Society/Issues",
#             "wgt": 17
#         },
#         {
#             "uri": "dmoz/Society/Issues/Business",
#             "label": "dmoz/Society/Issues/Business",
#             "wgt": 15
#         },
#         {
#             "uri": "dmoz/Society/Issues/Intellectual_Property",
#             "label": "dmoz/Society/Issues/Intellectual Property",
#             "wgt": 14
#         },
#         {
#             "uri": "news/Politics",
#             "label": "news/Politics",
#             "wgt": 80
#         }
#     ],
#     "image": "https://static01.nyt.com/newsgraphics/images/icons/defaultCrop.png",
#     "duplicateList": [],
#     "eventUri": null,
#     "location": null,
#     "sentiment": 0.1529411764705881,
#     "wgt": 305870820
# }

# %% [markdown]
# ### Creating complex queries
# In some cases you might want to create a query, that cannot be created using the simple QueryArticlesIter constructor. An example of such query would be:
#
# *Give me articles that are on the **topic of business** or **mention Tesla Inc**.*
#
# Keep in mind that creating a query
#
# ```
# QueryArticlesIter(
#     conceptUri = er.getConceptUri("Tesla"),
#     categoryUri = er.getCategoryUri("business"))
# ```
#
# would return articles on the topic of business **and** mention Tesla Inc.
#
# So how can we create a correct query? In such cases you have to look into the [Advanced Query Language](https://github.com/EventRegistry/event-registry-python/wiki/Searching-for-articles#advanced-query-language).
#
# Using this language, the correct above query would look like this:

# %%
qStr = """
{
    "$query": {
        "$or": [
            { "conceptUri": "%s" },
            { "categoryUri" : "%s"}
        ]
    }
}
""" % (
    er.getConceptUri("Tesla"),
    er.getCategoryUri("business"),
)

print(qStr)

q = QueryArticlesIter.initWithComplexQuery(qStr)
for art in q.execQuery(er, maxItems=1):
    print(art)
# Out:
# {
#     "$query": {
#         "$or": [
#             { "conceptUri": "http://en.wikipedia.org/wiki/Tesla,_Inc." },
#             { "categoryUri" : "dmoz/Business"}
#         ]
#     }
# }
#
# {'uri': '1231479834', 'lang': 'eng', 'isDuplicate': False, 'date': '2019-08-28', 'time': '21:02:10', 'dateTime': '2019-08-28T21:02:10Z', 'dataType': 'news', 'sim': 0.9058823585510254, 'url': 'https://www.digitaltrends.com/news/tesla-launches-car-insurance-cheaper-rates/', 'title': 'Tesla Launches Car Insurance For Its Customers, Promising 30% Cheaper Rates | Digital Trends', 'body': 'Elon Musk\'s Tesla is getting into the insurance business: the company just launched Tesla Insurance to customers in California.\n\nThe company said on Wednesday that they would offer rates that are between 20% and 30% lower than other insurance companies. Tesla said that their insurance would offer Tesla drivers "comprehensive coverage and claims management," adding that it will expand coverage to more states in the future.\n\n"Because Tesla knows its vehicles best, Tesla Insurance is able to leverage the advanced technology, safety, and serviceability of our cars to provide insurance at a lower cost. This pricing reflects the benefits of Tesla\'s active safety and advanced driver assistance features that come standard on all new Tesla vehicles," the company wrote in a blog post announcing the new venture.\n\nThe company also said that it would expand its insurance plan in the future to offer as a commercial policy for those who use their cars for ridesharing apps like Uber and Lyft.\n\nCalifornia residents who own or have already ordered a Model S, Model X, Model 3 or Roadster, can go to the Tesla Insurance website to get a free quote. Tesla said that pricing would vary based on the individual, taking into account their driving records\n\nTesla CEO Elon Musk first hinted at Tesla Insurance back in April, according to CNBC. Musk, who is active on Twitter, hasn\'t mentioned anything on the platform about the new insurance offering since it debuted.\n\nIn 2016, Tesla began to offer its InsureMyTesla program to Tesla vehicle owners in Australia and Hong Kong by partnering with larger insurance companies. Those prices were estimated to start at $900 a year for an insurance plan.\n\nTesla\'s cars offer a lot to their owners, but their advanced systems typically require specialized repair, driving up the price of insurance for most Tesla drivers. According to ValuePenguin, the annual cost of insuring some Tesla models tops out at around $3,000 per year.\n\nIt\'s not clear if Tesla might eventually offer their insurance program to owners of other kinds of cars. Digital Trends reached out to Tesla for more information on Tesla Insurance, but we have yet to receive a response.\n\nEditors\' Recommendations Walmart becomes the fourth plaintiff to sue Tesla in less than a month Study finds motorists overestimate Autopilot\'s capabilities; Tesla disagrees Teslas will soon be able to stream Netflix and Hulu, Elon Musk says Tesla owners will soon be able to play Cuphead while parked Tesla hasn\'t made a pickup, so YouTuber Simone Giertz made one out of a Model 3', 'source': {'uri': 'digitaltrends.com', 'dataType': 'news', 'title': 'Digital Trends'}, 'authors': [], 'image': 'https://icdn4.digitaltrends.com/image/digitaltrends/tesla-3-rear-510x0.jpg', 'eventUri': 'eng-5030245', 'sentiment': 0.3490196078431373, 'wgt': 125}

# %% [markdown]
# A more complex example could look something like this:

# %%
qStr = """{
    "$query": {
        "$or": [
            { "conceptUri": "http://en.wikipedia.org/wiki/Artificial_Intelligence" },
            {
                "keyword": {
                    "$and": [ "deep learning", "machine learning" ]
                }
            }
        ],
        "$not": {
            "keyword": "data mining",
            "keywordLoc": "title"
        }
    },
    "$filter": {
        "dataType": ["news", "blog"],
        "isDuplicate": "skipDuplicates",
        "startSourceRankPercentile": 0,
        "endSourceRankPercentile": 30,
        "minSentiment": 0.2
    }
}"""

q = QueryArticlesIter.initWithComplexQuery(qStr)
for art in q.execQuery(
    er,
    maxItems=1,
    sortBy="date",
    returnInfo=ReturnInfo(articleInfo=ArticleInfoFlags(bodyLen=300)),
):
    print(json.dumps(art, indent=4))
# Out:
# {
#     "uri": "1252338235",
#     "lang": "eng",
#     "isDuplicate": false,
#     "date": "2019-09-10",
#     "time": "15:26:00",
#     "dateTime": "2019-09-10T15:26:00Z",
#     "dataType": "news",
#     "sim": 0,
#     "url": "https://finance.yahoo.com/news/hpe-accelerates-artificial-intelligence-innovation-114500063.html",
#     "title": "HPE Accelerates Artificial Intelligence Innovation with Enterprise-Grade Solution for Managing Entire Machine Learning Lifecycle",
#     "body": "SAN JOSE, Calif.--(BUSINESS WIRE)--\n\nNew HPE Machine Learning (ML) Ops solution speeds time-to-value for AI from months to days and brings DevOps agility to the ML model lifecycle\n\nHewlett Packard Enterprise (HPE) today announced a container-based software solution, HPE ML Ops, to support the entire ...",
#     "source": {
#         "uri": "finance.yahoo.com",
#         "dataType": "news",
#         "title": "Yahoo Finance"
#     },
#     "authors": [],
#     "image": null,
#     "eventUri": null,
#     "sentiment": 0.2705882352941176,
#     "wgt": 305825160
# }

# %% [markdown]
# ### Retrieving summaries of search results
# The `QueryArticlesIter` class is great for obtaining the list of articles that match a certain criteria. In some cases, you want, however, to obtain a summary of search results. Examples of such summaries that can be obtained are the list of top mentioned concepts, top keywords, timeline of the results, and top news sources.
#
# We call such summaries aggregates and in order to obtain them, you have to use the `QueryArticles` class. `QueryArticles` class accepts the same arguments in the constructor, except that it also accepts an argument `requestedResult`. The `requestedResult` argument can be an instance of any of these classes:
#
# * `RequestArticlesInfo` - use to retrieve a list of articles
# * `RequestArticlesUriWgtList` - returns a long list of article uris
# * `RequestArticlesTimeAggr` - returns the time distribution of search results
# * `RequestArticlesConceptAggr` - returns the top concepts mentioned in the search results
# * `RequestArticlesKeywordAggr` - returns the top keywords matching the search results
# * `RequestArticlesCategoryAggr` - returns the top categories matching the search results
# * `RequestArticlesSourceAggr` - returns the top news sources that authored the search results
# * `RequestArticlesConceptGraph` - returns which top mentioned concepts frequently co-occur with other concepts
# * `RequestArticlesDateMentionAggr` - returns which dates are frequently mentioned in the search results
#
# In addition, to execute the search using the `QueryArticles` class, you call the `execQuery` method on the `EventRegistry` class:
#
# ```er.execQuery(q)```
#
# An example looks like this:

# %%
q = QueryArticles(
    conceptUri=er.getConceptUri("tesla"), requestedResult=RequestArticlesTimeAggr()
)
res = er.execQuery(q)
print(json.dumps(res, indent=4))
# Out:
# {
#     "timeAggr": {
#         "usedResults": 13298,
#         "totalResults": 13298,
#         "results": [
#             {
#                 "date": "2019-08-10",
#                 "count": 153
#             },
#             {
#                 "date": "2019-08-11",
#                 "count": 234
#             },
#             {
#                 "date": "2019-08-12",
#                 "count": 363
#             },
#             {
#                 "date": "2019-08-13",
#                 "count": 330
#             },
#             {
#                 "date": "2019-08-14",
#                 "count": 219
#             },
#             {
#                 "date": "2019-08-15",
#                 "count": 243
#             },
#             {
#                 "date": "2019-08-16",
#                 "count": 309
#             },
#             {
#                 "date": "2019-08-17",
#                 "count": 212
#             },
#             {
#                 "date": "2019-08-18",
#                 "count": 244
#             },
#             {
#                 "date": "2019-08-19",
#                 "count": 546
#             },
#             {
#                 "date": "2019-08-20",
#                 "count": 493
#             },
#             {
#                 "date": "2019-08-21",
#                 "count": 681
#             },
#             {
#                 "date": "2019-08-22",
#                 "count": 551
#             },
#             {
#                 "date": "2019-08-23",
#                 "count": 904
#             },
#             {
#                 "date": "2019-08-24",
#                 "count": 260
#             },
#             {
#                 "date": "2019-08-25",
#                 "count": 206
#             },
#             {
#                 "date": "2019-08-26",
#                 "count": 300
#             },
#             {
#                 "date": "2019-08-27",
#                 "count": 87
#             },
#             {
#                 "date": "2019-08-28",
#                 "count": 415
#             },
#             {
#                 "date": "2019-08-29",
#                 "count": 721
#             },
#             {
#                 "date": "2019-08-30",
#                 "count": 663
#             },
#             {
#                 "date": "2019-08-31",
#                 "count": 164
#             },
#             {
#                 "date": "2019-09-01",
#                 "count": 194
#             },
#             {
#                 "date": "2019-09-02",
#                 "count": 486
#             },
#             {
#                 "date": "2019-09-03",
#                 "count": 574
#             },
#             {
#                 "date": "2019-09-04",
#                 "count": 706
#             },
#             {
#                 "date": "2019-09-05",
#                 "count": 394
#             },
#             {
#                 "date": "2019-09-06",
#                 "count": 503
#             },
#             {
#                 "date": "2019-09-07",
#                 "count": 222
#             },
#             {
#                 "date": "2019-09-08",
#                 "count": 242
#             },
#             {
#                 "date": "2019-09-09",
#                 "count": 804
#             },
#             {
#                 "date": "2019-09-10",
#                 "count": 789
#             },
#             {
#                 "date": "2019-09-11",
#                 "count": 86
#             }
#         ]
#     }
# }

# %%
q = QueryArticles(
    conceptUri=er.getConceptUri("tesla"), requestedResult=RequestArticlesConceptAggr()
)
res = er.execQuery(q)
print(json.dumps(res, indent=4))
# Out:
# {
#     "conceptAggr": {
#         "warning": "Due to large number of results, the information was computed only on a sample of 10,000 articles",
#         "usedResults": 10000,
#         "totalResults": 13296,
#         "results": [
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Elon_Musk",
#                 "type": "person",
#                 "label": {
#                     "eng": "Elon Musk"
#                 },
#                 "score": 100
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/United_States",
#                 "type": "loc",
#                 "label": {
#                     "eng": "United States"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United States"
#                     }
#                 },
#                 "score": 72.99863387978142
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Electric_car",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Electric car"
#                 },
#                 "score": 67.48633879781421
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/China",
#                 "type": "loc",
#                 "label": {
#                     "eng": "China"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "China"
#                     }
#                 },
#                 "score": 53.07377049180328
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Chief_executive_officer",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Chief executive officer"
#                 },
#                 "score": 51.65983606557377
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Electric_vehicle",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Electric vehicle"
#                 },
#                 "score": 51.18169398907104
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Car",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Car"
#                 },
#                 "score": 43.13524590163934
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Automotive_industry",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Automotive industry"
#                 },
#                 "score": 35.44398907103825
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Tesla_Model_3",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Tesla Model 3"
#                 },
#                 "score": 34.37158469945355
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Twitter",
#                 "type": "org",
#                 "label": {
#                     "eng": "Twitter"
#                 },
#                 "score": 32.5
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Tesla_Model_S",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Tesla Model S"
#                 },
#                 "score": 31.12021857923497
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Germany",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Germany"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Germany"
#                     }
#                 },
#                 "score": 30.67622950819672
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/United_States_dollar",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "United States dollar"
#                 },
#                 "score": 29.76092896174863
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/California",
#                 "type": "loc",
#                 "label": {
#                     "eng": "California"
#                 },
#                 "location": {
#                     "type": "place",
#                     "label": {
#                         "eng": "California"
#                     },
#                     "country": {
#                         "type": "country",
#                         "label": {
#                             "eng": "United States"
#                         }
#                     }
#                 },
#                 "score": 29.70628415300547
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Shanghai",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Shanghai"
#                 },
#                 "location": {
#                     "type": "place",
#                     "label": {
#                         "eng": "Shanghai"
#                     },
#                     "country": {
#                         "type": "country",
#                         "label": {
#                             "eng": "China"
#                         }
#                     }
#                 },
#                 "score": 25.73087431693989
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Solar_panel",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Solar panel"
#                 },
#                 "score": 25.3483606557377
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Walmart",
#                 "type": "org",
#                 "label": {
#                     "eng": "Walmart"
#                 },
#                 "score": 24.93169398907104
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Artificial_intelligence",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Artificial intelligence"
#                 },
#                 "score": 24.48770491803279
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Europe",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Europe"
#                 },
#                 "location": null,
#                 "score": 24.30327868852459
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Volkswagen",
#                 "type": "org",
#                 "label": {
#                     "eng": "Volkswagen"
#                 },
#                 "score": 23.46311475409836
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Electric_battery",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Electric battery"
#                 },
#                 "score": 23.10109289617486
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Porsche",
#                 "type": "org",
#                 "label": {
#                     "eng": "Porsche"
#                 },
#                 "score": 22.53415300546448
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Autopilot",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Autopilot"
#                 },
#                 "score": 21.02459016393443
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Sport_utility_vehicle",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Sport utility vehicle"
#                 },
#                 "score": 16.45491803278689
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Euro",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Euro"
#                 },
#                 "score": 16.34562841530055
#             }
#         ]
#     }
# }

# %% [markdown]
# ## Searching for events
# Events are collections of articles for which we automatically identify that they discuss the same thing that happened. Examples of events include the launch of the new iPhone on Sept 10, 2019, Trump firing John Bolton as national security adviser, Nissan's CEO resigning, etc.
#
# Searching for events is very similar to searching for articles. There are two main classes available to do the search - `QueryEventsIter` and `QueryEvents`.
#
# You should use `QueryEventsIter` in order to retrieve the list of events that match a certain set of conditions.
#
# `QueryEvents` class should be used to obtain various kinds of summaries about the events that match the search conditions.
#
# Both classes allow you to specify in the constructor several filters, such:
# - `keywords` - find events that mention the keywords or phrases
# - `conceptUri` - find events that mention the concept(s)
# - `categoryUri` - find events that are about category(s)
# - `sourceUri` - find events covered by the given publisher(s)
# - `sourceLocationUri` - find events covered by publishers located in the given location
# - `authorUri` - find events written by the given author(s)
# - `locationUri` - find events that mention the given location in the dateline
# - `lang` - find events reported in the given language(s)
# - `dateStart` - find events that occurred on the given date or later (in the `YYYY-MM-DD` format)
# - `dateEnd` - find events that occurred before or on the given date (in the `YYYY-MM-DD` format)
# - `keywordsLoc` - if keywords are provided, where should we search for the keyword (`title` or `body` (default))
# - `minSentiment`, `maxSentiment` - min and max value of the sentiment (from -1 to 1)
# - `minArticlesInEvents`, `maxArticlesInEvent` - limit events to only those that have been covered by a certain number of articles
# - `startSourceRankPercentile` - starting percentile of the sources that should cover the event (default: 0). Value should be in range 0-90 and divisible by 10.
# - `endSourceRankPercentile` - ending percentile of the sources that should cover the event (default: 100). Value should be in range 10-100 and divisible by 10.
# - `ignoreKeywords`, `ignoreConceptUri`, `ignoreCategoryUri`, ... - from the events that match the rest of the conditions, exclude those that match any of the provided filters
#
# When multiple filters are specified, the results have to match **all** of the provided filters. For example, when keywords and sources are specified, the results will be events covered by these sources that mention the provided keywords.
#
# If you'll want to make a search, where **any** of the specified filtes are true, you'll have to use the [Advanced Query Language](https://github.com/EventRegistry/event-registry-python/wiki/Searching-for-events#advanced-query-language).
#
# An example query should look like this:

# %%
q = QueryEventsIter(conceptUri=er.getConceptUri("Apple"))
for event in q.execQuery(er, sortBy="size", maxItems=1):
    print(json.dumps(event, indent=4))
# Out:
# {
#     "uri": "eng-5059598",
#     "concepts": [
#         {
#             "uri": "http://en.wikipedia.org/wiki/IPhone",
#             "type": "wiki",
#             "score": 100,
#             "label": {
#                 "eng": "IPhone"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Apple_Inc.",
#             "type": "org",
#             "score": 92,
#             "label": {
#                 "eng": "Apple Inc."
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Smartphone",
#             "type": "wiki",
#             "score": 32,
#             "label": {
#                 "eng": "Smartphone"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Apple_Watch",
#             "type": "wiki",
#             "score": 25,
#             "label": {
#                 "eng": "Apple Watch"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_States_dollar",
#             "type": "wiki",
#             "score": 23,
#             "label": {
#                 "eng": "United States dollar"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Cupertino,_California",
#             "type": "loc",
#             "score": 23,
#             "label": {
#                 "eng": "Cupertino, California"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Cupertino, California"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United States"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/IPad",
#             "type": "wiki",
#             "score": 22,
#             "label": {
#                 "eng": "IPad"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Apple_TV",
#             "type": "wiki",
#             "score": 21,
#             "label": {
#                 "eng": "Apple TV"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/IPhone_XR",
#             "type": "wiki",
#             "score": 18,
#             "label": {
#                 "eng": "IPhone XR"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Pixel",
#             "type": "wiki",
#             "score": 18,
#             "label": {
#                 "eng": "Pixel"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Central_processing_unit",
#             "type": "wiki",
#             "score": 18,
#             "label": {
#                 "eng": "Central processing unit"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Tim_Cook",
#             "type": "person",
#             "score": 15,
#             "label": {
#                 "eng": "Tim Cook"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/IPhone_XS",
#             "type": "wiki",
#             "score": 14,
#             "label": {
#                 "eng": "IPhone XS"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Steve_Jobs",
#             "type": "person",
#             "score": 13,
#             "label": {
#                 "eng": "Steve Jobs"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Streaming_media",
#             "type": "wiki",
#             "score": 13,
#             "label": {
#                 "eng": "Streaming media"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Mobile_phone",
#             "type": "wiki",
#             "score": 12,
#             "label": {
#                 "eng": "Mobile phone"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Camera_lens",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "Camera lens"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/IOS",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "IOS"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Integrated_circuit",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "Integrated circuit"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Electric_battery",
#             "type": "wiki",
#             "score": 9,
#             "label": {
#                 "eng": "Electric battery"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/4K_resolution",
#             "type": "wiki",
#             "score": 9,
#             "label": {
#                 "eng": "4K resolution"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Sensor",
#             "type": "wiki",
#             "score": 9,
#             "label": {
#                 "eng": "Sensor"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Arcade_game",
#             "type": "wiki",
#             "score": 8,
#             "label": {
#                 "eng": "Arcade game"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Lens_(optics)",
#             "type": "wiki",
#             "score": 8,
#             "label": {
#                 "eng": "Lens (optics)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/California",
#             "type": "loc",
#             "score": 8,
#             "label": {
#                 "eng": "California"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "California"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United States"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Huawei",
#             "type": "org",
#             "score": 7,
#             "label": {
#                 "eng": "Huawei"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Samsung",
#             "type": "org",
#             "score": 6,
#             "label": {
#                 "eng": "Samsung"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Netflix",
#             "type": "org",
#             "score": 6,
#             "label": {
#                 "eng": "Netflix"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_States",
#             "type": "loc",
#             "score": 6,
#             "label": {
#                 "eng": "United States"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "United States"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Google",
#             "type": "org",
#             "score": 5,
#             "label": {
#                 "eng": "Google"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/YouTube",
#             "type": "org",
#             "score": 5,
#             "label": {
#                 "eng": "YouTube"
#             }
#         }
#     ],
#     "eventDate": "2019-09-10",
#     "totalArticleCount": 3776,
#     "title": {
#         "eng": "Tepid reaction for Apple's new iPhones in China amid tough competition",
#         "spa": "Todo lo que se sabe del nuevo iPhone 11",
#         "zho": "\u860b\u679c911\u65b0\u54c1\u767c\u8868 \u6697\u85cf\u9a5a\u559c - \u8ca1\u7d93\u8981\u805e",
#         "rus": "Apple \u0440\u0435\u0437\u043a\u043e \u0441\u043d\u0438\u0437\u0438\u043b\u0430 \u0446\u0435\u043d\u044b \u043d\u0430 iPhone",
#         "fra": "iPhone 11, iPad, Apple Watch, Apple TV+: toutes les nouveaut\u00e9s d'Apple",
#         "deu": "Wichtigste Keynote des Jahres: Apple stellt neues iPhone vor und k\u00f6nnte Netflix angreifen",
#         "por": "Tudo sobre os iPhones 11, 11 Pro e 11 Pro Max, os novos celulares da Apple",
#         "ita": "Apple: arriva il nuovo iPhone, ecco come sar\u00e0",
#         "tur": "iPhone 11 bug\u00fcn tan\u0131t\u0131lacak! \u0130\u015fte T\u00fcrkiye fiyat\u0131...",
#         "ukr": "Apple \u043f\u0440\u0435\u0437\u0435\u043d\u0442\u0443\u0454 \u043d\u043e\u0432\u0438\u0439 iPhone: \u0449\u043e \u0432\u0456\u0434\u043e\u043c\u043e"
#     },
#     "summary": {
#         "eng": "HANGZHOU/SHANGHAI (Reuters) - A lower price tag and new features may not be enough for Apple Inc (AAPL.O) to win customers for its newly-launched iPhone 11 series in China, the world's largest smartphone market that is already crowded with cheaper and feature-packed rival handsets.\n\nApple's unveiling of three new iPhones in California met with a limp reaction on Wednesday from analysts and on social media in China, where the U.S. giant has been losing ground to competitors in recent years.\n\n\"More",
#         "spa": "Filtraciones y m\u00e1s filtraciones, pero hasta la jornada previa a la presentaci\u00f3n de los nuevos iPhone nadie ha podido mostrar una fotograf\u00eda o v\u00eddeo de uno de los nuevos modelos reales que presentar\u00e1 Apple. Sin embargo, hemos visto decenas de reproducciones de c\u00f3mo ser\u00e1n los m\u00f3viles que su consejero delegado, Tim Cook descubrir\u00e1 en el Steve Jobs Theater del Apple Park, en Cupertino este martes -- 19 h en Espa\u00f1a -- . Esta presentaci\u00f3n puede ser de alta intensidad, adem\u00e1s del nuevo (los ",
#         "zho": "\u860b\u679c\u79cb\u5b63\u767c\u8868\u6703\u5c07\u5728\u53f0\u7063\u6642\u95939\u670811\u65e5\u51cc\u66681\u9ede\u767b\u5834\uff0c\u9810\u671f\u5c07\u767c\u8868\u4e09\u6b3e\u65b0iPhone\u3001\u5169\u6b3e\u65b0Apple Watch\uff0c\u904b\u6c23\u597d\u7684\u8a71\uff0c\u767c\u8868\u6703\u4e2d\u9084\u6703\u4eae\u76f8\u9810\u8a0810\u6708\u958b\u8ce3\u7684\u5165\u9580\u7d1aiPad\u8207\u9ad8\u968e\u7684iPad Pro\u3002\n\n\u860b\u679c\u79cb\u5b63\u767c\u8868\u6703\u91cd\u982d\u6232\uff0c\u7576\u7136\u662f\u65b0\u6b3eiPhone\uff0c\u53bb\u5e74\u8207\u524d\u5e74\u7684iPhone\u7684\u540d\u5b57\u5145\u6eff\u96e3\u4ee5\u767c\u97f3\u7684X\uff0c\u4f46\u6839\u64da\u5148\u524d\u5df2\u5916\u6d41\u860b\u679c\u5167\u90e8\u6587\u4ef6\u986f\u793a\uff0c\u547d\u540d\u5df2\u7d93\u7c21\u5316\u70baiPhone 11\uff0c\u5f9e\u5165\u9580\u6b3e\u5230\u9ad8\u968e\u6b3e\u547d\u540d\u5206\u5225\u70baiPhone 11\u3001iPhone 11 Pro\u8207iPhone 11 Pr",
#         "rus": "\u041d\u043e\u0432\u044b\u0439 iPhone \u043d\u0430 \u0441\u0442\u0430\u0440\u0442\u0435 \u043f\u0440\u043e\u0434\u0430\u0436 \u0431\u0443\u0434\u0435\u0442 \u0441\u0442\u043e\u0438\u0442\u044c \u0434\u0435\u0448\u0435\u0432\u043b\u0435, \u0447\u0435\u043c \u043c\u043e\u0434\u0435\u043b\u044c Xr \u0432 \u043f\u0440\u043e\u0448\u043b\u043e\u043c \u0433\u043e\u0434\u0443.\n\niPhone 11 \u0432 \u043c\u0438\u043d\u0438\u043c\u0430\u043b\u044c\u043d\u043e\u0439 \u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0442\u0430\u0446\u0438\u0438, \u043f\u0440\u0435\u0434\u0441\u0442\u0430\u0432\u043b\u0435\u043d\u043d\u044b\u0439 10 \u0441\u0435\u043d\u0442\u044f\u0431\u0440\u044f \u0432 \u041a\u0443\u043f\u0435\u0440\u0442\u0438\u043d\u043e, \u0431\u0443\u0434\u0435\u0442 \u0434\u043e\u0441\u0442\u0443\u043f\u0435\u043d \u043f\u043e \u0446\u0435\u043d\u0435 699 \u0434\u043e\u043b\u043b\u0430\u0440\u043e\u0432 (\u043e\u043a\u043e\u043b\u043e 47 \u0442\u044b\u0441\u044f\u0447 \u0440\u0443\u0431\u043b\u0435\u0439). iPhone Xr \u043d\u0430 \u0441\u0442\u0430\u0440\u0442\u0435 \u043f\u0440\u043e\u0434\u0430\u0436 \u0441\u0442\u043e\u0438\u043b 749 \u0434\u043e\u043b\u043b\u0430\u0440\u043e\u0432.\n\n\u041f\u043e\u0441\u043b\u0435 \u043f\u043e\u044f\u0432\u043b\u0435\u043d\u0438\u044f \u043d\u043e\u0432\u0438\u043d\u043a\u0438 Ap",
#         "fra": "Apple a d\u00e9voil\u00e9 en direct de la Californie ses nouveaut\u00e9s lors de son keynote: iPhone 11, iPad 7, Apple Watch Serie 5, Apple TV+.\n\nCe mardi 10 septembre se tient le rendez-vous le plus important de l'ann\u00e9e pour Apple: sur la sc\u00e8ne du Steve Jobs Theater, au sein du si\u00e8ge de Cupertino, Tim Cook pr\u00e9sente les produits phares de la marque pour les prochains mois. A commencer par trois nouveaux iPhone, succ\u00e9dant \u00e0 l'iPhone XR, l'iPhone XS et l'iPhone XS Max. Des annonces d\u00e9di\u00e9es \u00e0 l'Apple W",
#         "deu": "15.39 Uhr: Die gr\u00f6\u00dften \u00dcberraschungen d\u00fcrfte es nach den vielen iPhone-Leaks heute bei anderen Apple-Produkten geben. So k\u00f6nnte der Konzern am Abend eine neue Apple Watch 5 aus dem Hut zaubern. Das Gesch\u00e4ft mit der smarten Uhr wird f\u00fcr den iPhone-Konzern nicht zuletzt wegen nachlassender iPhone-Verk\u00e4ufe immer wichtiger.\n\nIm vergangenen Quartal wurden nach Berechnungen der Marktforschungsexperten Strategy Analytics 5,7 Millionen Ger\u00e4te verschiedener Modelle der Apple Watch verkauft - 50 P",
#         "por": "A Apple apresentou na tarde desta ter\u00e7a-feira (10) a nova gera\u00e7\u00e3o de celulares da empresa. Foram confirmados os modelos iPhone 11, iPhone 11 Pro e iPhone Max -- uma mudan\u00e7a na nomenclatura do ano ano passado, eliminando os modelos com as letras \"S\" e \"R\".\n\nOs aparelhos foram confirmados em uma confer\u00eancia que incluiu tamb\u00e9m o an\u00fancio de um novo iPad e a quinta gera\u00e7\u00e3o do Apple Watch, al\u00e9m de detalhes dos servi\u00e7os Apple Arcade e Apple TV+.\n\nO corpo dos celulares \u00e9 de alum\u00ednio anodizad",
#         "ita": "Il 10 settembre attesa la presentazione dello smartphone n.11. Nello Steve Jobs Theater dell'Apple Park andr\u00e0 in scena il keynote dedicato alle novit\u00e0 di fine anno: dal Watch all'iPad, dal MacBook all'iOS 13\n\nL'attesa \u00e8 agli sgoccioli. Il 10 settembre alle ore 10 nello Steve Jobs Theater del suo quartier generale Apple presenter\u00e0 le novit\u00e0 dell'autunno, compreso il nuovo iPhone. Il motto \"By innovation only\" del keynote in arrivo, che Repubblica seguir\u00e0 in diretta, fa ben sperare gli espert",
#         "tur": "2018'in son aylar\u0131 ve 2019'un tamam\u0131 iPhone serisi i\u00e7in olduk\u00e7a s\u0131k\u0131nt\u0131l\u0131 ge\u00e7mi\u015fti. Bu d\u00f6ng\u00fcden kurtulmak i\u00e7in Apple, yeni iPhone 11 modelleriyle bu ak\u015fam sahneye \u00e7\u0131kacak.\n\nYeni modellerin en \u00e7ok merak edilen y\u00f6n\u00fc ise elbette fiyatlar\u0131. Apple her zaman \u00fcst segment fiyat politikas\u0131nda psikolojik s\u0131n\u0131rlar\u0131 belirleyen bir tav\u0131r \u00e7izdi. Bu tavr\u0131 iPhone X ile birlikte 1000 dolar baraj\u0131na sabitledi. Sonras\u0131nda gelen iPhone XS de ayn\u0131 fiyata sahip olurken Apple, iPhone 11 i",
#         "ukr": "\u0424\u043e\u0442\u043e: Apple \u043f\u0440\u0435\u0437\u0435\u043d\u0442\u0443\u0454 \u043d\u043e\u0432\u0438\u0439 iPhone (flickr.com/Andy)\n\n\u041d\u0430 \u043f\u0440\u0435\u0437\u0435\u043d\u0442\u0430\u0446\u0456\u0457 Apple \u043f\u043e\u043a\u0430\u0436\u0443\u0442\u044c \u0442\u0440\u0438 \u043c\u043e\u0434\u0435\u043b\u0456 iPhone\n\n\u0410\u043c\u0435\u0440\u0438\u043a\u0430\u043d\u0441\u044c\u043a\u0430 \u043a\u043e\u043c\u043f\u0430\u043d\u0456\u044f Apple \u043d\u0430 \u043f\u0440\u0435\u0437\u0435\u043d\u0442\u0430\u0446\u0456\u0457 10 \u0432\u0435\u0440\u0435\u0441\u043d\u044f \u0432 \u041a\u0443\u043f\u0435\u0440\u0442\u0456\u043d\u043e \u043f\u0440\u0435\u0434\u0441\u0442\u0430\u0432\u0438\u0442\u044c \u043d\u043e\u0432\u0438\u0439 iPhone. \u0420\u0411\u041a-\u0423\u043a\u0440\u0430\u0457\u043d\u0430 \u0440\u043e\u0437\u0431\u0438\u0440\u0430\u043b\u0430\u0441\u044f, \u0449\u043e \u0432\u0456\u0434\u043e\u043c\u043e \u043f\u0440\u043e \u043d\u043e\u0432\u0438\u043d\u043a\u0438 Apple, \u044f\u043a\u0456 \u043f\u0440\u0438\u0439\u0434\u0443\u0442\u044c \u043d\u0430 \u0437\u043c\u0456\u043d\u0443 iPhone Xs, iPhone Xs Max \u0438 iPhone Xr, \u0437\u0430 \u0434\u043e\u0431\u0443 \u0434\u043e "
#     },
#     "location": {
#         "type": "place",
#         "label": {
#             "eng": "Cupertino, California"
#         },
#         "country": {
#             "type": "country",
#             "label": {
#                 "eng": "United States"
#             }
#         }
#     },
#     "categories": [
#         {
#             "uri": "dmoz/Computers/Systems",
#             "label": "dmoz/Computers/Systems",
#             "wgt": 17
#         },
#         {
#             "uri": "dmoz/Computers/Systems/Apple",
#             "label": "dmoz/Computers/Systems/Apple",
#             "wgt": 21
#         },
#         {
#             "uri": "dmoz/Computers/Hardware/Retailers",
#             "label": "dmoz/Computers/Hardware/Retailers",
#             "wgt": 21
#         },
#         {
#             "uri": "news/Technology",
#             "label": "news/Technology",
#             "wgt": 82
#         }
#     ],
#     "articleCounts": {
#         "eng": 1850,
#         "spa": 509,
#         "zho": 508,
#         "rus": 231,
#         "fra": 128,
#         "deu": 227,
#         "por": 125,
#         "ita": 91,
#         "tur": 59,
#         "ukr": 48
#     },
#     "sentiment": 0.1607843137254903,
#     "wgt": 3776
# }

# %% [markdown]
# ### Retrieving a list of articles about an event
#
# In order to retrieve a list of articles that discuss a single event, you can use the `QueryEventArticlesIter` class. The class requires that you provide the `eventUri` value, which is the unique id of the event. Additionally, you can also specify additional constraints that determine which subset of articles about the event to retrieve:
#
# * `lang` - in which language should be the articles
# * `keywords` - which keywords should be mentioned in the articles
# * `conceptUri` - which concepts should be mentioned in the articles
# * `categoryUri` - which category should be assigned to the articles
# * `sourceLocationUri` - what should be the source of the publisher
# * `authorUri` - who should be the author of the articles
# * `locationUri` - which location should be mentioned in the dateline of the article
# * `dateStart` - on which date or after should the articles be published
# * `dateEnd` - before or on which date should the articles be published
# * `keywordLoc` - if keywords are set, where should we search for them (`body` (default) or `title`)
# * `startSourceRankPercentile` - what is the minimum source rank of the returned articles (0 - 90, divisible by 10)
# * `endSourceRankPercentile` - what is the maximum source rank of the returned articles (10 - 100, divisible by 10)
# * `minSentiment` - minimum sentiment of the articles (between -1 and 1)
# * `maxSentiment` - maximum sentiment of the articles (between -1 and 1)
#
# An example for the event above could be:

# %%
q = QueryEventArticlesIter(
    "eng-5059598",
    lang="eng",
    sourceLocationUri=er.getLocationUri("United states"),
    minSentiment=0.2,
    endSourceRankPercentile=30,
)
for art in q.execQuery(
    er, maxItems=2, returnInfo=ReturnInfo(articleInfo=ArticleInfoFlags(bodyLen=300))
):
    print(art)
# Out:
# {'uri': '1252630658', 'lang': 'eng', 'isDuplicate': False, 'date': '2019-09-10', 'time': '19:53:00', 'dateTime': '2019-09-10T19:53:00Z', 'dataType': 'news', 'sim': 0.772549033164978, 'url': 'https://www.tomsguide.com/news/iphone-11-pro-price-specs', 'title': 'iPhone 11 Pro Hopes to Wow Users With Triple Cameras, Better Performance', 'body': "Extra cameras, design tweaks highlight this year's high-end iPhones\n\nWith two of the new iPhones that were unveiled today (Sept. 10), Apple is going pro.\n\nThe iPhone 11 Pro and iPhone 11 Pro Max are Apple's latest high-end smartphones, replacing last year's iPhone XS and XS Max in the iPhone lineup. ...", 'source': {'uri': 'tomsguide.com', 'dataType': 'news', 'title': "Tom's Guide"}, 'authors': [], 'image': 'https://cdn.mos.cms.futurecdn.net/taYs8gxnegn5fGt8MEzywN-1200-80.jpeg', 'eventUri': 'eng-5059598', 'sentiment': 0.3647058823529412, 'wgt': 197}
# {'uri': '1253023425', 'lang': 'eng', 'isDuplicate': False, 'date': '2019-09-11', 'time': '03:54:00', 'dateTime': '2019-09-11T03:54:00Z', 'dataType': 'news', 'sim': 0.7686274647712708, 'url': 'https://www.forbes.com/sites/gordonkelly/2019/09/10/apple-iphone-11-vs-iphone-11-pro-whats-the-difference-new-iphone-upgrade/', 'title': "Apple iPhone 11 Vs iPhone 11 Pro: What's The Difference?", 'body': "For the second year in a row, Apple's most exciting new iPhone is its cheapest. The confusingly named iPhone 11 replaces the iPhone XR and, pound for pound, it blows the socks of the iPhone 11 Pro, the confusingly named successor to the iPhone XS. This is why.\n\nDisplays - HD and XDR but not ...", 'source': {'uri': 'forbes.com', 'dataType': 'news', 'title': 'Forbes'}, 'authors': [], 'image': 'https://thumbor.forbes.com/thumbor/600x300/https%3A%2F%2Fblogs-images.forbes.com%2Fgordonkelly%2Ffiles%2F2019%2F09%2FScreenshot-2019-09-10-at-22.27.17-Edited.png', 'eventUri': 'eng-5059598', 'sentiment': 0.2078431372549019, 'wgt': 196}

# %% [markdown]
# ### Searching for events using complex queries
#
# As with the article search, event search using `QueryEventsIter` also allows you just to narrow down the set of matching events, with each added filter. If you want to create a more complex query that has a Boolean OR between two different types of filters, you have to use the [Advanced Query Language](https://github.com/EventRegistry/event-registry-python/wiki/Searching-for-events#advanced-query-language).
#
# The syntax is the same as when searching for articles. An example of such a query could look like this:

# %%
qStr = """{
    "$query": {
        "$or": [
            { "locationUri": "%s" },
            { 
                "categoryUri": "%s",
                "conceptUri": "%s"
            }
        ]
    }
}""" % (
    er.getLocationUri("Washington"),
    er.getCategoryUri("politics"),
    er.getConceptUri("Trump"),
)
print(qStr)

q = QueryEventsIter.initWithComplexQuery(qStr)
for event in q.execQuery(er, sortBy="size", maxItems=1):
    print(json.dumps(event, indent=4))
# Out:
# {
#     "$query": {
#         "$or": [
#             { "locationUri": "http://en.wikipedia.org/wiki/Washington_(state)" },
#             {
#                 "categoryUri": "news/Politics",
#                 "conceptUri": "http://en.wikipedia.org/wiki/Donald_Trump"
#             }
#         ]
#     }
# }
# {
#     "uri": "eng-5028293",
#     "concepts": [
#         {
#             "uri": "http://en.wikipedia.org/wiki/Boris_Johnson",
#             "type": "person",
#             "score": 100,
#             "label": {
#                 "eng": "Boris Johnson"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Brexit",
#             "type": "wiki",
#             "score": 86,
#             "label": {
#                 "eng": "Brexit"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Parliament",
#             "type": "wiki",
#             "score": 79,
#             "label": {
#                 "eng": "Parliament"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_Kingdom",
#             "type": "loc",
#             "score": 71,
#             "label": {
#                 "eng": "United Kingdom"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "United Kingdom"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/European_Union",
#             "type": "loc",
#             "score": 66,
#             "label": {
#                 "eng": "European Union"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Prime_Minister_of_the_United_Kingdom",
#             "type": "wiki",
#             "score": 65,
#             "label": {
#                 "eng": "Prime Minister of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Elizabeth_II",
#             "type": "person",
#             "score": 55,
#             "label": {
#                 "eng": "Elizabeth II"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Parliament_of_the_United_Kingdom",
#             "type": "org",
#             "score": 50,
#             "label": {
#                 "eng": "Parliament of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Labour_Party_(UK)",
#             "type": "org",
#             "score": 39,
#             "label": {
#                 "eng": "Labour Party (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Democracy",
#             "type": "wiki",
#             "score": 33,
#             "label": {
#                 "eng": "Democracy"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/London",
#             "type": "loc",
#             "score": 33,
#             "label": {
#                 "eng": "London"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "London"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Jeremy_Corbyn",
#             "type": "person",
#             "score": 31,
#             "label": {
#                 "eng": "Jeremy Corbyn"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Prime_minister",
#             "type": "wiki",
#             "score": 30,
#             "label": {
#                 "eng": "Prime minister"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Motion_of_no_confidence",
#             "type": "wiki",
#             "score": 29,
#             "label": {
#                 "eng": "Motion of no confidence"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Conservative_Party_(UK)",
#             "type": "org",
#             "score": 25,
#             "label": {
#                 "eng": "Conservative Party (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/House_of_Commons_of_the_United_Kingdom",
#             "type": "org",
#             "score": 24,
#             "label": {
#                 "eng": "House of Commons of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Scotland",
#             "type": "loc",
#             "score": 24,
#             "label": {
#                 "eng": "Scotland"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Scotland"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Deputy_(legislator)",
#             "type": "wiki",
#             "score": 22,
#             "label": {
#                 "eng": "Deputy (legislator)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/John_Bercow",
#             "type": "person",
#             "score": 21,
#             "label": {
#                 "eng": "John Bercow"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Brexit_negotiations",
#             "type": "wiki",
#             "score": 19,
#             "label": {
#                 "eng": "Brexit negotiations"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Legislative_session",
#             "type": "wiki",
#             "score": 19,
#             "label": {
#                 "eng": "Legislative session"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Pound_sterling",
#             "type": "wiki",
#             "score": 19,
#             "label": {
#                 "eng": "Pound sterling"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/BBC",
#             "type": "org",
#             "score": 19,
#             "label": {
#                 "eng": "BBC"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Theresa_May",
#             "type": "person",
#             "score": 18,
#             "label": {
#                 "eng": "Theresa May"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Brussels",
#             "type": "loc",
#             "score": 17,
#             "label": {
#                 "eng": "Brussels"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Brussels"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Belgium"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Speech_from_the_throne",
#             "type": "wiki",
#             "score": 16,
#             "label": {
#                 "eng": "Speech from the throne"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Conservatism",
#             "type": "wiki",
#             "score": 14,
#             "label": {
#                 "eng": "Conservatism"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Coup_d'\u00e9tat",
#             "type": "wiki",
#             "score": 14,
#             "label": {
#                 "eng": "Coup d'\u00e9tat"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Twitter",
#             "type": "org",
#             "score": 14,
#             "label": {
#                 "eng": "Twitter"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Government",
#             "type": "wiki",
#             "score": 13,
#             "label": {
#                 "eng": "Government"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Member_of_parliament",
#             "type": "wiki",
#             "score": 12,
#             "label": {
#                 "eng": "Member of parliament"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Opposition_(politics)",
#             "type": "wiki",
#             "score": 12,
#             "label": {
#                 "eng": "Opposition (politics)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Government_of_the_United_Kingdom",
#             "type": "org",
#             "score": 12,
#             "label": {
#                 "eng": "Government of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_Kingdom_European_Union_membership_referendum,_2016",
#             "type": "wiki",
#             "score": 11,
#             "label": {
#                 "eng": "United Kingdom European Union membership referendum, 2016"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Constitution",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "Constitution"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Referendum",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "Referendum"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Liberal_Democrats_(UK)",
#             "type": "org",
#             "score": 9,
#             "label": {
#                 "eng": "Liberal Democrats (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/European_Council",
#             "type": "wiki",
#             "score": 9,
#             "label": {
#                 "eng": "European Council"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Northern_Ireland",
#             "type": "loc",
#             "score": 9,
#             "label": {
#                 "eng": "Northern Ireland"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Northern Ireland"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Europe",
#             "type": "loc",
#             "score": 8,
#             "label": {
#                 "eng": "Europe"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Donald_Trump",
#             "type": "person",
#             "score": 8,
#             "label": {
#                 "eng": "Donald Trump"
#             }
#         },
#         {
#             "uri": "http://zh.wikipedia.org/wiki/\u82f1\u56fd\u56fd\u4f1a",
#             "type": "org",
#             "score": 7,
#             "label": {
#                 "eng": "\u82f1\u56fd\u56fd\u4f1a"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Ireland",
#             "type": "loc",
#             "score": 7,
#             "label": {
#                 "eng": "Ireland"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Ireland"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Jo_Swinson",
#             "type": "person",
#             "score": 6,
#             "label": {
#                 "eng": "Jo Swinson"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Nicola_Sturgeon",
#             "type": "person",
#             "score": 6,
#             "label": {
#                 "eng": "Nicola Sturgeon"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Scottish_National_Party",
#             "type": "org",
#             "score": 6,
#             "label": {
#                 "eng": "Scottish National Party"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Philip_Hammond",
#             "type": "person",
#             "score": 6,
#             "label": {
#                 "eng": "Philip Hammond"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Edinburgh",
#             "type": "loc",
#             "score": 6,
#             "label": {
#                 "eng": "Edinburgh"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Edinburgh"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Dominic_Grieve",
#             "type": "person",
#             "score": 5,
#             "label": {
#                 "eng": "Dominic Grieve"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/England",
#             "type": "loc",
#             "score": 5,
#             "label": {
#                 "eng": "England"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "England"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         }
#     ],
#     "eventDate": "2019-08-27",
#     "totalArticleCount": 2800,
#     "title": {
#         "eng": "Government asks Queen to suspend Parliament",
#         "fra": "Brexit: Hugh Grant \u00e9trille Boris Johnson et lui demande d'aller \" se faire foutre \"",
#         "zho": "\u82f1\u56fd\u8131\u6b27\uff1a\u8bae\u4f1a\u88ab\u505c\u6446\u5982\u4f55\u963b\u6b62\u65e0\u534f\u8bae\u786c\u8131",
#         "por": "Brexit a f\u00f3rceps - 30/08/2019 - Opini\u00e3o - Folha",
#         "spa": "Boris Johnson planea pedir a la Reina que suspenda el Parlamento",
#         "deu": "Selbst Strassensperren sind m\u00f6glich",
#         "ara": "\u062a\u0631\u0627\u0645\u0628: \"\u0628\u0648\u0631\u064a\u0633 \u0627\u0644\u0639\u0638\u064a\u0645\" \u0647\u0648 \u0645\u0627 \u0643\u0627\u0646\u062a \u062a\u0628\u062d\u062b \u0639\u0646\u0647 \u0628\u0631\u064a\u0637\u0627\u0646\u064a\u0627",
#         "rus": "\u0411\u0438\u0442\u0432\u0430 \u0437\u0430 Brexit: \u043a\u043e\u0440\u043e\u043b\u0435\u0432\u0430 \u043f\u043e\u0434\u0434\u0435\u0440\u0436\u0430\u043b\u0430 \u0411\u043e\u0440\u0438\u0441\u0430 \u0414\u0436\u043e\u043d\u0441\u043e\u043d\u0430",
#         "tur": "Parlamentoyu tatil karar\u0131na kar\u015f\u0131 imza say\u0131s\u0131 milyonu a\u015ft\u0131",
#         "ita": "Boris Johnson ha chiesto alla Regina di sospendere il parlamento",
#         "nld": "Britse regering wil parlement in aanloop naar brexit schorsen, oppositie woedend ",
#         "cat": "L'ensurt definitiu pel Brexit? - Editorial Vicent Partal",
#         "dan": "Boris Johnson beder dronning Elizabeth suspendere parlamentet",
#         "ron": "UE, prima reac\u0163ie dup\u0103 ce regina a aprobat suspendarea Parlamentului britanic | Romania Libera",
#         "hrv": "Velika Britanija: Kraljica je odobrila suspenziju parlamenta",
#         "ukr": "\u0414\u0436\u043e\u043d\u0441\u043e\u043d \u043f\u0440\u0438\u0437\u0443\u043f\u0438\u043d\u0438\u0442\u044c \u0440\u043e\u0431\u043e\u0442\u0443 \u043f\u0430\u0440\u043b\u0430\u043c\u0435\u043d\u0442\u0443 \u043f\u0435\u0440\u0435\u0434 Brexit",
#         "srp": "\u040f\u043e\u043d\u0441\u043e\u043d \u0441\u0430\u043c\u043e\u0443\u0432\u0435\u0440\u0435\u043d, \u041c\u0430\u043a\u0440\u043e\u043d \u043d\u0435 \u043e\u0434\u0441\u0442\u0443\u043f\u0430",
#         "slv": "Britanska opozicija namerava prepre\u010diti brexit brez dogovora"
#     },
#     "summary": {
#         "eng": "The government has asked the Queen to suspend Parliament just days after MPs return to work in September - and only a few weeks before the Brexit deadline.\n\nBoris Johnson said a Queen's Speech would take place after the suspension, on 14 October, to outline his \"very exciting agenda\".\n\nBut it means the time MPs have to pass laws to stop a no-deal Brexit on 31 October would be cut.\n\nHouse of Commons Speaker John Bercow said it was a \"constitutional outrage\".\n\nThe speaker, who does not traditionall",
#         "fra": "L'acteur britannique a vivement r\u00e9agi sur Twitter \u00e0 la d\u00e9cision du Premier ministre de suspendre le Parlement jusqu'au 14 octobre.\n\nL'acteur Hugh Grant, connu pour ses r\u00f4les dans des com\u00e9dies romantiques comme Coup de foudre \u00e0 Notting Hill, s'en est violemment pris au Premier ministre britannique Boris Johnson et \u00e0 sa d\u00e9cision de suspendre le Parlement jusqu'au 14 octobre.\n\n\"Vous ne fouterez pas en l'air le futur de mes enfants\", a \u00e9crit sur son compte Twitter le com\u00e9dien. \"Vous ne d\u00e9t",
#         "zho": "\u8fd9\u662f\u5916\u90e8\u94fe\u63a5\uff0c\u6d4f\u89c8\u5668\u5c06\u6253\u5f00\u53e6\u4e00\u4e2a\u7a97\u53e3\n\n\u79bb10\u670831\u65e5\u82f1\u56fd\u8131\u6b27\u6700\u540e\u671f\u9650\u53ea\u6709\u77ed\u77ed\u4e24\u4e2a\u591a\u6708\u4e86\u3002\u8fd9\u4e00\u56f0\u6270\u82f1\u56fd3\u5e74\u591a\u7684\u653f\u6cbb\u5927\u51b3\u5b9a\uff0c\u81f3\u4eca\u4ecd\u7136\u6ca1\u6709\u6e05\u6670\u7684\u8d70\u5411\u3002\u82f1\u56fd\u80fd\u4e0e\u6b27\u76df\u8fbe\u6210\u8131\u6b27\u534f\u8bae\u5417\uff1f\u5982\u679c\u6ca1\u6709\u534f\u8bae\uff0c\u82f1\u56fd\u662f\u5426\u5c31\u6b64\u5f3a\u884c\u786c\u5206\u624b\u3002\n\n\u6b63\u662f\u5728\u5982\u6b64\u5c40\u52bf\u4e0d\u660e\u6717\u7684\u5173\u952e\u65f6\u523b\uff0c\u9996\u76f8\u9c8d\u91cc\u65af\u00b7\u7ea6\u7ff0\u900a\u4e3b\u5bfc\u7684\u653f\u5e9c\u62ff\u51fa\u4e86\u4e00\u4e2a\u9707\u60ca\u82f1\u56fd\u4e0a\u4e0b\u4e43\u81f3\u6d77\u5185\u5916\u7684\u529e\u6cd5\uff1a\u62a5\u8bf7\u5973\u738b\u4f0a\u4e3d\u838e\u767d\u4e8c\u4e16\uff0c\u8ba9\u8fc7\u5b8c\u6691",
#         "por": "Faltando apenas dois meses para o fim do prazo acordado para o brexit, a sa\u00edda do Reino Unido da Uni\u00e3o Europeia (UE), o primeiro-ministro brit\u00e2nico, Boris Johnson, deflagrou uma crise pol\u00edtica ao operar a suspens\u00e3o das atividades do Parlamento por cinco semanas.\n\nEmbora a medida esteja prevista no sistema parlamentarista do pa\u00eds, com a fun\u00e7\u00e3o de iniciar uma nova sess\u00e3o legislativa, o prazo solicitado por Johnson \u00e0 rainha -- o mais longo desde 1945 -- deixa clara a controversa inten\u00e7\u00e3o",
#         "spa": "Reino Unido. Acuerdo de la oposici\u00f3n para frenar el Brexit sin acuerdo por la v\u00eda legislativa\n\nLa Reina Isabel II podr\u00eda recibir hoy la petici\u00f3n del Gobierno de Boris Johnson de suspender el Parlamento en septiembre y hasta el pr\u00f3ximo 14 de octubre, para evitar que los diputados tengan tiempo de aprobar una pr\u00f3rroga del Brexit y lograr que la salida de la Uni\u00f3n Europea se produzca el 31 de octubre.\n\nAs\u00ed, si Johnson consigue suspender el Parlamento durante cinco semanas, bloquear\u00e1 cualqui",
#         "deu": "Einen ersten, schweren D\u00e4mpfer im Kampf gegen den kompromisslosen Kurs von Boris Johnson haben seine Gegner schon am Freitag bekommen: Das schottische Gericht, vor dem eine Gruppe von 75 Abgeordneten gegen die am Mittwoch verk\u00fcndete zeitweilige Schliessung des Parlaments geklagt hatte, hat in einer wegen Dringlichkeit vorgezogenen Anh\u00f6rung kein schnelles Urteil f\u00e4llen wollen. Der Richter sagte, er wolle erst alle Argumente h\u00f6ren; das Verfahren soll nun Mitte n\u00e4chster Woche weitergehen.\n\nDan",
#         "ara": "\u0627\u0644\u0645\u0635\u062f\u0631: \u0644\u0646\u062f\u0646 - \u0648\u0643\u0627\u0644\u0627\u062a \u0627\u0644\u062a\u0627\u0631\u064a\u062e: 29 \u0623\u063a\u0633\u0637\u0633 2019\n\n\u0641\u064a \u062e\u0637\u0648\u0629 \u062a\u0627\u0631\u064a\u062e\u064a\u0629\u060c \u0639\u0644\u0651\u0642 \u0631\u0626\u064a\u0633 \u0627\u0644\u0648\u0632\u0631\u0627\u0621 \u0627\u0644\u0628\u0631\u064a\u0637\u0627\u0646\u064a \u0628\u0648\u0631\u064a\u0633 \u062c\u0648\u0646\u0633\u0648\u0646 \u0623\u0639\u0645\u0627\u0644 \u0627\u0644\u0628\u0631\u0644\u0645\u0627\u0646 \u0645\u0646 \u0627\u0644\u0623\u0633\u0628\u0648\u0639 \u0627\u0644\u062b\u0627\u0646\u064a \u0641\u064a \u0627\u0644\u0634\u0647\u0631 \u0627\u0644\u0645\u0642\u0628\u0644 \u0648\u062d\u062a\u0649 14 \u0623\u0643\u062a\u0648\u0628\u0631\u060c \u0623\u064a \u0642\u0628\u0644 \u0623\u0633\u0628\u0648\u0639\u064a\u0646 \u0641\u0642\u0637 \u0645\u0646 \u0627\u0644\u0645\u0648\u0639\u062f \u0627\u0644\u0645\u0642\u0631\u0631 \u0644\u0628\u0631\u064a\u0643\u0633\u062a\u060c \u0648\u0647\u0648 \u0645\u0627 \u0648\u0635\u0641\u0647 \u0631\u0626\u064a\u0633 \u0645\u062c\u0644\u0633 \u0627\u0644\u0639\u0645\u0648\u0645 \u0628\u0640 \"\u0627\u0644\u0641\u0636\u064a\u062d\u0629 \u0627\u0644\u062f\u0633\u062a\u0648\u0631\u064a\u0629\"\u060c \u0641\u064a\u0645\u0627 \u0648\u0635\u0641\u0647 \u0622\u062e\u0631\u0648",
#         "rus": "\u041c\u0430\u0441\u0442\u0435\u0440\u0430 \u043d\u0430 \u0432\u0441\u0435 \u0440\u0443\u043a\u0438: \u043a\u0442\u043e \u043f\u043e\u043a\u043e\u0440\u0438\u0442 \u041a\u0430\u0437\u0430\u043d\u044c\n\n\u041f\u0440\u0435\u043c\u044c\u0435\u0440-\u043c\u0438\u043d\u0438\u0441\u0442\u0440 \u0412\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u0438 \u0411\u043e\u0440\u0438\u0441 \u0414\u0436\u043e\u043d\u0441\u043e\u043d \u0432 \u0440\u0430\u0437\u0433\u0430\u0440 \u043f\u043e\u0434\u0433\u043e\u0442\u043e\u0432\u043a\u0438 \u043a Brexit, \u043a\u043e\u0442\u043e\u0440\u044b\u0439 \u043d\u0430\u043c\u0435\u0447\u0435\u043d \u043d\u0430 31 \u043e\u043a\u0442\u044f\u0431\u0440\u044f, \u043e\u0431\u044a\u044f\u0432\u0438\u043b \u043e \u043f\u0440\u0438\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043a\u0435 \u0440\u0430\u0431\u043e\u0442\u044b \u043f\u0430\u0440\u043b\u0430\u043c\u0435\u043d\u0442\u0430 \u0434\u043e 14 \u043e\u043a\u0442\u044f\u0431\u0440\u044f.\n\n\"\u041f\u0440\u0435\u043c\u044c\u0435\u0440-\u043c\u0438\u043d\u0438\u0441\u0442\u0440 \u043f\u043e\u0433\u043e\u0432\u043e\u0440\u0438\u043b \u0441 \u0415\u0435 \u0412\u0435\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e\u043c \u043a\u043e\u0440\u043e\u043b\u0435\u0432\u043e\u0439 \u0438 \u043f\u043e\u043f\u0440\u043e\u0441\u0438\u043b \u0435\u0435 \u0437\u0430\u0432\u0435\u0440\u0448\u0438",
#         "tur": "\u0130ngiliz parlamentosunun dilek\u00e7elere ayr\u0131lm\u0131\u015f internet sitesinde, Johnson'\u0131n parlamentoyu tatil etme karar\u0131na kar\u015f\u0131 imzaya a\u00e7\u0131lan dilek\u00e7eye at\u0131lan imza say\u0131s\u0131 bir g\u00fcnden az bir s\u00fcrede 1 milyon 300 bine yakla\u015ft\u0131.\n\nDilek\u00e7ede \"50. madde s\u00fcresi yeterince uzat\u0131lmad\u0131k\u00e7a ve \u0130ngiltere'nin AB'den ayr\u0131lma karar\u0131 iptal edilmedik\u00e7e parlamento tatil edilmemeli veya da\u011f\u0131t\u0131lmamal\u0131.\" talebi yer al\u0131yor.\n\n\u0130ngiltere'de 10 bin imzay\u0131 bulan dilek\u00e7elere h\u00fck\u00fcmetin yan\u0131t vermesi ger",
#         "ita": "I partiti di opposizione, dopo una riunione tra i rispettivi leader, avevano deciso di unire le forze per trovare \"modi concreti\" con cui impedire una Brexit no-deal, scenario verso cui invece tende Johnson. Mentre i conservatori minimizzano, le opposizioni insorgono per la decisione del premier\n\nIl governo del premier britannico Boris Johnson ha chiesto a Elisabetta II di sospendere i lavori del Parlamento e ha confermato la data del 14 ottobre, come il giorno in cui \u00e8 attesto il discorso della",
#         "nld": "De Britse regering wil het parlement een aantal weken schorsen. Volgens premier Johnson is dat nodig omdat hij op 14 oktober de nieuwe plannen van zijn regering wil presenteren. De voorzitter van het Lagerhuis en de oppositie zijn woedend.\n\nJohnson zou het parlement buitenspel willen zetten om op die manier te voorkomen dat het Lagerhuis een no-deal-brexit op 31 oktober dwarsboomt. Johnson spreekt dit tegen en zegt dat er \"genoeg tijd\" overblijft om over de brexit te debatteren.\n\nAls het aan John",
#         "cat": "Ahir el nou primer ministre brit\u00e0nic, Boris Johnson, va demanar a la reina Elisabet la pr\u00f2rroga de les vacances del parlament. Fent servir arguments t\u00e8cnics, com ara la durada de les sessions la primera part de l'any, Johnson ha aconseguit que el parlament de Westminster no es puga reunir fins el 14 d'octubre. I l'eixida del Brexit sense acord, la m\u00e9s dura de totes, \u00e9s prevista el 31 del mateix mes.\n\nLa intencionalitat pol\u00edtica de la demanda \u00e9s evident: Johnson vol impedir que el parlament",
#         "dan": "Storbritanniens premierminister Boris Johnson vil g\u00e5 til dronning Elizabeth og bede hende suspendere det britiske parlament.\n\nHan \u00f8nsker, at parlamentet suspenderes i begyndelsen af september,og at dronningens \u00e5bningstale i parlementet f\u00f8rst holdes 14. oktober, bekr\u00e6fter han if\u00f8lge BBC.\n\nBoris Johnson afviser imidlertid, at han fors\u00f8ger at k\u00f8re parlamentet ud p\u00e5 et sidespor i brexit-processen, skriver nyhedsbureauet Reuters.\n\nHvis parlamentet suspenderes, vil det blive vanskeligt for bri",
#         "ron": "Guy Verhofstadt, coordonatorul Parlamentului European pe tema Brexit, a denun\u0163at, miercuri sear\u0103, decizia premierului britanic, Boris Johnson, de a suspenda Parlamentul de la Londra, afirm\u00e2nd c\u0103 este o ac\u0163iune \"sinistr\u0103\".\n\n\"Preluarea din nou a controlului asupra \u0163\u0103rii nu a p\u0103rut niciodat\u0103 mai sinistr\u0103. \u00cen calitatea de parlamentar, sunt solidar cu cei care lupt\u0103 s\u0103 le fie auzite vocile. Suprimarea dezbaterilor privind decizii profunde este improbabil s\u0103 contribuie la o rela\u0163ie viit",
#         "hrv": "Tada bi se trebao odr\u017eati kralji\u010din govor u kojemu \u0107e biti iznijeti planovi vlade za Brexit.\n\nRok za Brexit je 31. listopada.\n\nPodsjetimo, britanski premijer Boris Johnson \u017eeli ograni\u010diti mogu\u0107nost da mu parlament poremeti plan za Brexit tako \u0161to je zatra\u017eio da se skrati vrijeme zasjedanja od sada pa do planiranog izlaska iz Unije 31. listopada. To je izazvalo pomutnju me\u0111u politi\u010dkim protivnicima koji ga optu\u017euju za \"dr\u017eavni udar na britanski na\u010din\".\n\nU dosad najodva\u017enijem potezu d",
#         "ukr": "\u041f\u0440\u0435\u043c'\u0454\u0440-\u043c\u0456\u043d\u0456\u0441\u0442\u0440 \u0411\u0440\u0438\u0442\u0430\u043d\u0456\u0457 \u0411\u043e\u0440\u0438\u0441 \u0414\u0436\u043e\u043d\u0441\u043e\u043d \u043f\u0440\u0438\u0437\u0443\u043f\u0438\u043d\u0438\u0442\u044c \u0440\u043e\u0431\u043e\u0442\u0443 \u043f\u0430\u0440\u043b\u0430\u043c\u0435\u043d\u0442\u0443, \u0449\u043e\u0431 \u043d\u0435 \u0434\u0430\u0442\u0438 \u0434\u0435\u043f\u0443\u0442\u0430\u0442\u0430\u043c \u0443\u0445\u0432\u0430\u043b\u0438\u0442\u0438 \u0431\u0443\u0434\u044c-\u044f\u043a\u0456 \u0437\u0430\u043a\u043e\u043d\u0438, \u044f\u043a\u0456 \u043c\u043e\u0433\u043b\u0438 \u0431 \u043f\u0435\u0440\u0435\u0448\u043a\u043e\u0434\u0438\u0442\u0438 \u0439\u043e\u043c\u0443 \u0432\u0438\u0432\u0435\u0441\u0442\u0438 \u043a\u0440\u0430\u0457\u043d\u0443 \u0437 \u0404\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u044c\u043a\u043e\u0433\u043e \u0421\u043e\u044e\u0437\u0443 \u0431\u0435\u0437 \u0443\u0433\u043e\u0434\u0438.\n\n\u041f\u0440\u043e \u0446\u0435 \u043f\u043e\u0432\u0456\u0434\u043e\u043c\u043b\u044f\u0454 AP.\n\n\u0417\u0430\u0437\u043d\u0430\u0447\u0430\u0454\u0442\u044c\u0441\u044f, \u0449\u043e \u0432\u0456\u043d \u043c\u0430\u0454 \u043d\u0430\u043c\u0456\u0440 \u043f\u0440\u043e\u0441\u0438\u0442\u0438 \u043a\u043e\u0440\u043e\u043b\u0435\u0432\u0443 \u0404\u043b\u0438\u0437\u0430\u0432\u0435\u0442",
#         "srp": "\u041f\u0440\u0435\u043c\u0438\u0458\u0435\u0440 \u0411\u0440\u0438\u0442\u0430\u043d\u0438\u0458\u0435 \u0411\u043e\u0440\u0438\u0441 \u040f\u043e\u043d\u0441\u043e\u043d \u0438\u0437\u0433\u043b\u0435\u0434\u0430\u043e \u0458\u0435 \u0441\u0430\u043c\u043e\u0443\u0432\u0435\u0440\u0435\u043d\u043e \u043d\u0430 \u0441\u0430\u0441\u0442\u0430\u043d\u043a\u0443 \u0441\u0430 \u043f\u0440\u0435\u0434\u0441\u0435\u0434\u043d\u0438\u043a\u043e\u043c \u0424\u0440\u0430\u043d\u0446\u0443\u0441\u043a\u0435 \u0415\u043c\u0430\u043d\u0443\u0435\u043b\u043e\u043c \u041c\u0430\u043a\u0440\u043e\u043d\u043e\u043c, \u043d\u0430 \u043a\u043e\u043c \u0458\u0435 \u0437\u0430\u0442\u0440\u0430\u0436\u0438\u043e \u043d\u043e\u0432\u0435 \u043f\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u0435 \u043e \u0411\u0440\u0435\u0433\u0437\u0438\u0442\u0443.\n\n\u040f\u043e\u043d\u0441\u043e\u043d \u0458\u0435, \u043a\u0430\u043a\u043e \u043d\u0430\u0432\u043e\u0434\u0438 \u0410\u041f, \u043a\u0440\u0435\u043d\u0443\u043e \u0443 \"\u043e\u0444\u0430\u043d\u0437\u0438\u0432\u0443 \u0448\u0430\u0440\u043c\u043e\u043c\", \u043d\u0430\u0433\u043b\u0430\u0441\u0438\u0432\u0448\u0438 \u0434\u0430 \u0412\u0435\u043b\u0438\u043a\u0430 \u0411\u0440\u0438\u0442\u0430\u043d\u0438\u0458\u0430 \u0436\u0435\u043b\u0438 \u0434\u043e\u0433\u043e\u0432\u043e\u0440 \u0441\u0430 \u0415\u0432\u0440\u043e\u043f\u0441\u043a\u043e\u043c \u0443",
#         "slv": "Opozicija bo izstop brez dogovora sku\u0161ala prepre\u010diti s sprejetjem zakonodaje v parlamentu, poro\u010da britanski BBC.\n\nStranke v skupni izjavi niso pojasnile, kako in kdaj bodo sku\u0161ali po zakonodajni poti prepre\u010diti brexit brez dogovora. Poslanka zelenih Caroline Lucas je ob tem povedala, da je zakonodajna pot najvarnej\u0161a pot za odlog izstopa, ki je trenutno predviden 31. oktobra.\n\nVodja liberalnih demokratov Jo Swinson je po sre\u010danju dejala, da glasovanje o nezaupnici premierju ostaja zadnja m"
#     },
#     "location": {
#         "type": "place",
#         "label": {
#             "eng": "London"
#         },
#         "country": {
#             "type": "country",
#             "label": {
#                 "eng": "United Kingdom"
#             }
#         }
#     },
#     "categories": [
#         {
#             "uri": "dmoz/Society/Government",
#             "label": "dmoz/Society/Government",
#             "wgt": 11
#         },
#         {
#             "uri": "dmoz/Society/Politics",
#             "label": "dmoz/Society/Politics",
#             "wgt": 12
#         },
#         {
#             "uri": "dmoz/Society/Government/Parliaments_and_Legislatures",
#             "label": "dmoz/Society/Government/Parliaments and Legislatures",
#             "wgt": 24
#         },
#         {
#             "uri": "news/Politics",
#             "label": "news/Politics",
#             "wgt": 91
#         }
#     ],
#     "articleCounts": {
#         "eng": 827,
#         "fra": 341,
#         "zho": 325,
#         "por": 204,
#         "spa": 257,
#         "deu": 229,
#         "ara": 169,
#         "rus": 113,
#         "tur": 58,
#         "ita": 68,
#         "nld": 53,
#         "cat": 35,
#         "dan": 34,
#         "ron": 34,
#         "hrv": 20,
#         "ukr": 12,
#         "srp": 11,
#         "slv": 10
#     },
#     "sentiment": -0.05882352941176472,
#     "wgt": 2800
# }

# %% [markdown]
# ### Retrieving summaries of search results
#
# In addition to obtaining a list of events that match the search results, you can also obtain various summaries of search results. In order to obtain some summary about events that match your search criteria, you have to use the `QueryEvents` class. The class accepts the same filtering parameters as the `QueryEventsIter` class, but in addition also accepts the `requestedResult` parameter, which should be set to one of the following values:
#
# * `RequestEventsInfo` - returns a list of events
# * `RequestEventsUriWgtList` - returns a long list of event URIs that match search results
# * `RequestEventsTimeAggr` - retrieves a time distribution of events in search results
# * `RequestEventsKeywordAggr` - retrieves top keywords in the events that match search conditions
# * `RequestEventsLocAggr` - retrieves the locations where the events happened
# * `RequestEventsLocTimeAggr` - retrieves the locations and times when the events happened
# * `RequestEventsConceptAggr` - retrieves the top concepts mentioned in the events
# * `RequestEventsConceptGraph` - retrieves the top concepts and their co-occurrences
# * `RequestEventsSourceAggr` - retrieves the top sources in the events
# * `RequestEventsDateMentionAggr` - retrieves the top dates mentioned in the events
# * `RequestEventsCategoryAggr` - retrieves the top categories in the events

# %%
# what is being mentioned the most in the events about China and US?
q = QueryEvents(
    conceptUri=QueryItems.AND(
        [er.getConceptUri("China"), er.getConceptUri("United States")]
    ),
    requestedResult=RequestEventsConceptAggr(),
)
res = er.execQuery(q)
print(json.dumps(res, indent=4))
# Out:
# {
#     "conceptAggr": {
#         "usedResults": 14369,
#         "totalResults": 14369,
#         "results": [
#             {
#                 "uri": "http://en.wikipedia.org/wiki/United_States_dollar",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "United States dollar"
#                 },
#                 "score": 100
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Market_share",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Market share"
#                 },
#                 "score": 66.71204188481676
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Europe",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Europe"
#                 },
#                 "location": null,
#                 "score": 66.57112939416605
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Japan",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Japan"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Japan"
#                     }
#                 },
#                 "score": 55.11084517576664
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Donald_Trump",
#                 "type": "person",
#                 "label": {
#                     "eng": "Donald Trump"
#                 },
#                 "score": 51.11952131637995
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/India",
#                 "type": "loc",
#                 "label": {
#                     "eng": "India"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "India"
#                     }
#                 },
#                 "score": 46.83560209424084
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/North_America",
#                 "type": "loc",
#                 "label": {
#                     "eng": "North America"
#                 },
#                 "location": null,
#                 "score": 43.6960359012715
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Market_research",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Market research"
#                 },
#                 "score": 40.69169783096485
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Market_segmentation",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Market segmentation"
#                 },
#                 "score": 37.86566940912491
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Germany",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Germany"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Germany"
#                     }
#                 },
#                 "score": 34.84128646222887
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/United_Kingdom",
#                 "type": "loc",
#                 "label": {
#                     "eng": "United Kingdom"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 },
#                 "score": 34.57980553477935
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/South_Korea",
#                 "type": "loc",
#                 "label": {
#                     "eng": "South Korea"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "South Korea"
#                     }
#                 },
#                 "score": 34.48257292445774
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Asia-Pacific",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Asia-Pacific"
#                 },
#                 "score": 32.43231114435303
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/SWOT_analysis",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "SWOT analysis"
#                 },
#                 "score": 29.32026925953627
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Africa",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Africa"
#                 },
#                 "location": null,
#                 "score": 28.62049364248317
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Economic_growth",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Economic growth"
#                 },
#                 "score": 28.20703066566941
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/France",
#                 "type": "loc",
#                 "label": {
#                     "eng": "France"
#                 },
#                 "location": {
#                     "type": "country",
#                     "label": {
#                         "eng": "France"
#                     }
#                 },
#                 "score": 28.09663425579656
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Atmosphere_(unit)",
#                 "type": "wiki",
#                 "label": {
#                     "eng": "Atmosphere (unit)"
#                 },
#                 "score": 28.03649962602842
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Beijing",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Beijing"
#                 },
#                 "location": {
#                     "type": "place",
#                     "label": {
#                         "eng": "Beijing"
#                     },
#                     "country": {
#                         "type": "country",
#                         "label": {
#                             "eng": "China"
#                         }
#                     }
#                 },
#                 "score": 27.50097232610322
#             },
#             {
#                 "uri": "http://en.wikipedia.org/wiki/Middle_East",
#                 "type": "loc",
#                 "label": {
#                     "eng": "Middle East"
#                 },
#                 "location": null,
#                 "score": 27.44083769633508
#             }
#         ]
#     }
# }

# %%
# what are the top categories in recent events about AI?
q = QueryEvents(
    conceptUri=er.getConceptUri("artificial intelligence"),
    requestedResult=RequestEventsCategoryAggr(),
)
res = er.execQuery(q)
print(json.dumps(res, indent=4))
# Out:
# {
#     "categoryAggr": {
#         "usedResults": 3493,
#         "totalResults": 3493,
#         "results": [
#             {
#                 "uri": "news/Technology",
#                 "label": "news/Technology",
#                 "count": 1174
#             },
#             {
#                 "uri": "news/Business",
#                 "label": "news/Business",
#                 "count": 938
#             },
#             {
#                 "uri": "news/Politics",
#                 "label": "news/Politics",
#                 "count": 94
#             },
#             {
#                 "uri": "news/Arts_and_Entertainment",
#                 "label": "news/Arts and Entertainment",
#                 "count": 80
#             },
#             {
#                 "uri": "dmoz/Business/Investing",
#                 "label": "dmoz/Business/Investing",
#                 "count": 72
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising/Consulting",
#                 "label": "dmoz/Business/Marketing and Advertising/Consulting",
#                 "count": 59
#             },
#             {
#                 "uri": "dmoz/Business/Investing/Stocks_and_Bonds",
#                 "label": "dmoz/Business/Investing/Stocks and Bonds",
#                 "count": 48
#             },
#             {
#                 "uri": "dmoz/Arts/Photography/Equipment_and_Services",
#                 "label": "dmoz/Arts/Photography/Equipment and Services",
#                 "count": 46
#             },
#             {
#                 "uri": "dmoz/Shopping/Photography/Cameras_and_Camcorders",
#                 "label": "dmoz/Shopping/Photography/Cameras and Camcorders",
#                 "count": 44
#             },
#             {
#                 "uri": "dmoz/Business/Business_Services/Customer_Management",
#                 "label": "dmoz/Business/Business Services/Customer Management",
#                 "count": 43
#             },
#             {
#                 "uri": "dmoz/Computers/Robotics",
#                 "label": "dmoz/Computers/Robotics",
#                 "count": 41
#             },
#             {
#                 "uri": "news/Health",
#                 "label": "news/Health",
#                 "count": 40
#             },
#             {
#                 "uri": "news/Science",
#                 "label": "news/Science",
#                 "count": 39
#             },
#             {
#                 "uri": "dmoz/Computers/Robotics/Companies",
#                 "label": "dmoz/Computers/Robotics/Companies",
#                 "count": 36
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence",
#                 "label": "dmoz/Computers/Artificial Intelligence",
#                 "count": 36
#             },
#             {
#                 "uri": "dmoz/Computers/Security",
#                 "label": "dmoz/Computers/Security",
#                 "count": 36
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising/Micromarketing",
#                 "label": "dmoz/Business/Marketing and Advertising/Micromarketing",
#                 "count": 34
#             },
#             {
#                 "uri": "dmoz/Shopping/Photography/Used_Equipment",
#                 "label": "dmoz/Shopping/Photography/Used Equipment",
#                 "count": 32
#             },
#             {
#                 "uri": "dmoz/Computers/Internet/Searching",
#                 "label": "dmoz/Computers/Internet/Searching",
#                 "count": 31
#             },
#             {
#                 "uri": "dmoz/Games/Video_Games/Browser_Based",
#                 "label": "dmoz/Games/Video Games/Browser Based",
#                 "count": 31
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Investment_Services",
#                 "label": "dmoz/Business/Financial Services/Investment Services",
#                 "count": 27
#             },
#             {
#                 "uri": "dmoz/Society/Issues",
#                 "label": "dmoz/Society/Issues",
#                 "count": 27
#             },
#             {
#                 "uri": "dmoz/Computers/Robotics/Research",
#                 "label": "dmoz/Computers/Robotics/Research",
#                 "count": 26
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Publications",
#                 "label": "dmoz/Computers/Artificial Intelligence/Publications",
#                 "count": 25
#             },
#             {
#                 "uri": "dmoz/Business/Information_Technology",
#                 "label": "dmoz/Business/Information Technology",
#                 "count": 24
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Venture_Capital",
#                 "label": "dmoz/Business/Financial Services/Venture Capital",
#                 "count": 24
#             },
#             {
#                 "uri": "dmoz/Games/Video_Games/Game_Design",
#                 "label": "dmoz/Games/Video Games/Game Design",
#                 "count": 24
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising",
#                 "label": "dmoz/Business/Marketing and Advertising",
#                 "count": 22
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services",
#                 "label": "dmoz/Business/Financial Services",
#                 "count": 22
#             },
#             {
#                 "uri": "dmoz/Business/Investing/Guides",
#                 "label": "dmoz/Business/Investing/Guides",
#                 "count": 22
#             },
#             {
#                 "uri": "dmoz/Computers/Hardware/Components",
#                 "label": "dmoz/Computers/Hardware/Components",
#                 "count": 22
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Data_Administration",
#                 "label": "dmoz/Computers/Software/Data Administration",
#                 "count": 21
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Philosophy",
#                 "label": "dmoz/Computers/Artificial Intelligence/Philosophy",
#                 "count": 21
#             },
#             {
#                 "uri": "dmoz/Computers/Security/Biometrics",
#                 "label": "dmoz/Computers/Security/Biometrics",
#                 "count": 21
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Machine_Learning",
#                 "label": "dmoz/Computers/Artificial Intelligence/Machine Learning",
#                 "count": 20
#             },
#             {
#                 "uri": "dmoz/Business/Major_Companies",
#                 "label": "dmoz/Business/Major Companies",
#                 "count": 19
#             },
#             {
#                 "uri": "dmoz/Business/International_Business_and_Trade",
#                 "label": "dmoz/Business/International Business and Trade",
#                 "count": 18
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Economic",
#                 "label": "dmoz/Society/Issues/Economic",
#                 "count": 17
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Banking_Services",
#                 "label": "dmoz/Business/Financial Services/Banking Services",
#                 "count": 17
#             },
#             {
#                 "uri": "dmoz/Science/Instruments_and_Supplies/Laboratory_Automation_and_Robotics",
#                 "label": "dmoz/Science/Instruments and Supplies/Laboratory Automation and Robotics",
#                 "count": 17
#             },
#             {
#                 "uri": "dmoz/Games/Video_Games/Computer_Platforms",
#                 "label": "dmoz/Games/Video Games/Computer Platforms",
#                 "count": 16
#             },
#             {
#                 "uri": "dmoz/Arts/Television/Guides",
#                 "label": "dmoz/Arts/Television/Guides",
#                 "count": 15
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Information_Services",
#                 "label": "dmoz/Business/Financial Services/Information Services",
#                 "count": 15
#             },
#             {
#                 "uri": "dmoz/Business/Customer_Service/Consulting",
#                 "label": "dmoz/Business/Customer Service/Consulting",
#                 "count": 14
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Business",
#                 "label": "dmoz/Society/Issues/Business",
#                 "count": 14
#             },
#             {
#                 "uri": "dmoz/Society/Work",
#                 "label": "dmoz/Society/Work",
#                 "count": 14
#             },
#             {
#                 "uri": "dmoz/Arts/Animation/Voice_Actors",
#                 "label": "dmoz/Arts/Animation/Voice Actors",
#                 "count": 14
#             },
#             {
#                 "uri": "dmoz/Recreation/Autos/Driving_and_Safety",
#                 "label": "dmoz/Recreation/Autos/Driving and Safety",
#                 "count": 14
#             },
#             {
#                 "uri": "dmoz/Business/Industrial_Goods_and_Services/Factory_Automation",
#                 "label": "dmoz/Business/Industrial Goods and Services/Factory Automation",
#                 "count": 14
#             },
#             {
#                 "uri": "dmoz/Arts/Television/Interactive",
#                 "label": "dmoz/Arts/Television/Interactive",
#                 "count": 13
#             },
#             {
#                 "uri": "dmoz/Games/Board_Games/Developers_and_Publishers",
#                 "label": "dmoz/Games/Board Games/Developers and Publishers",
#                 "count": 13
#             },
#             {
#                 "uri": "dmoz/Arts/Video",
#                 "label": "dmoz/Arts/Video",
#                 "count": 13
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Master_Data_Management",
#                 "label": "dmoz/Computers/Software/Master Data Management",
#                 "count": 12
#             },
#             {
#                 "uri": "dmoz/Business/Chemicals/Biochemical",
#                 "label": "dmoz/Business/Chemicals/Biochemical",
#                 "count": 12
#             },
#             {
#                 "uri": "dmoz/Business/Investing/Funds",
#                 "label": "dmoz/Business/Investing/Funds",
#                 "count": 12
#             },
#             {
#                 "uri": "dmoz/Computers/Data_Communications/Telephony",
#                 "label": "dmoz/Computers/Data Communications/Telephony",
#                 "count": 12
#             },
#             {
#                 "uri": "dmoz/Society/Government/Finance",
#                 "label": "dmoz/Society/Government/Finance",
#                 "count": 12
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Academic_Departments",
#                 "label": "dmoz/Computers/Artificial Intelligence/Academic Departments",
#                 "count": 12
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Games",
#                 "label": "dmoz/Computers/Artificial Intelligence/Games",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Associations",
#                 "label": "dmoz/Computers/Artificial Intelligence/Associations",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Insurance",
#                 "label": "dmoz/Business/Financial Services/Insurance",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Networking",
#                 "label": "dmoz/Computers/Software/Networking",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Science/Technology/Space",
#                 "label": "dmoz/Science/Technology/Space",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Computers/Robotics/History",
#                 "label": "dmoz/Computers/Robotics/History",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Business/Energy",
#                 "label": "dmoz/Business/Energy",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Natural_Language",
#                 "label": "dmoz/Computers/Artificial Intelligence/Natural Language",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Business/International_Business_and_Trade/Services",
#                 "label": "dmoz/Business/International Business and Trade/Services",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Computers/Hardware",
#                 "label": "dmoz/Computers/Hardware",
#                 "count": 11
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising/Associations",
#                 "label": "dmoz/Business/Marketing and Advertising/Associations",
#                 "count": 10
#             },
#             {
#                 "uri": "news/Sports",
#                 "label": "news/Sports",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Science/Earth_Sciences/Data_Centers",
#                 "label": "dmoz/Science/Earth Sciences/Data Centers",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Computers/Hardware/Systems",
#                 "label": "dmoz/Computers/Hardware/Systems",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Arts/Television/Schedule_and_Programming",
#                 "label": "dmoz/Arts/Television/Schedule and Programming",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Business/Investing/Research_and_Analysis",
#                 "label": "dmoz/Business/Investing/Research and Analysis",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Health/Public_Health_and_Safety/Patient_Safety",
#                 "label": "dmoz/Health/Public Health and Safety/Patient Safety",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Education_and_Training",
#                 "label": "dmoz/Business/Financial Services/Education and Training",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Science/Technology/Military_Science",
#                 "label": "dmoz/Science/Technology/Military Science",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Society/Future",
#                 "label": "dmoz/Society/Future",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Computers/Speech_Technology",
#                 "label": "dmoz/Computers/Speech Technology",
#                 "count": 10
#             },
#             {
#                 "uri": "dmoz/Computers/Security/Advisories_and_Patches",
#                 "label": "dmoz/Computers/Security/Advisories and Patches",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Business/Energy/Oil_and_Gas",
#                 "label": "dmoz/Business/Energy/Oil and Gas",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Computers/Mobile_Computing",
#                 "label": "dmoz/Computers/Mobile Computing",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Business/Aerospace_and_Defense/Defense",
#                 "label": "dmoz/Business/Aerospace and Defense/Defense",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Society/Activism/Anti-Corporation",
#                 "label": "dmoz/Society/Activism/Anti-Corporation",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Computers/CAD_and_CAM/PTC_Pro_Engineer",
#                 "label": "dmoz/Computers/CAD and CAM/PTC Pro Engineer",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Business/Small_Business/Start_Up",
#                 "label": "dmoz/Business/Small Business/Start Up",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Computers/Speech_Technology/Voice_Portals",
#                 "label": "dmoz/Computers/Speech Technology/Voice Portals",
#                 "count": 9
#             },
#             {
#                 "uri": "dmoz/Computers/Security/Internet",
#                 "label": "dmoz/Computers/Security/Internet",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Science/Technology/Energy",
#                 "label": "dmoz/Science/Technology/Energy",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Business/Human_Resources",
#                 "label": "dmoz/Business/Human Resources",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Games",
#                 "label": "dmoz/Games",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Government_Operations",
#                 "label": "dmoz/Society/Issues/Government Operations",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Business/Transportation_and_Logistics/Aviation",
#                 "label": "dmoz/Business/Transportation and Logistics/Aviation",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Business",
#                 "label": "dmoz/Business",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Financial_Consultants",
#                 "label": "dmoz/Business/Financial Services/Financial Consultants",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Arts/Video/Alternative_Video",
#                 "label": "dmoz/Arts/Video/Alternative Video",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Business/Customer_Service/Software",
#                 "label": "dmoz/Business/Customer Service/Software",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Society/Work/Job_Sharing",
#                 "label": "dmoz/Society/Work/Job Sharing",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Computers/Data_Communications",
#                 "label": "dmoz/Computers/Data Communications",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Home/Personal_Finance/Insurance",
#                 "label": "dmoz/Home/Personal Finance/Insurance",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Computers/Systems/Apple",
#                 "label": "dmoz/Computers/Systems/Apple",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Society/Politics/Globalization",
#                 "label": "dmoz/Society/Politics/Globalization",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Computers/Systems",
#                 "label": "dmoz/Computers/Systems",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Business/Employment/Job_Search",
#                 "label": "dmoz/Business/Employment/Job Search",
#                 "count": 8
#             },
#             {
#                 "uri": "dmoz/Science/Astronomy/Solar_System",
#                 "label": "dmoz/Science/Astronomy/Solar System",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Computers/Home_Automation",
#                 "label": "dmoz/Computers/Home Automation",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Business/Opportunities/Inventions",
#                 "label": "dmoz/Business/Opportunities/Inventions",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Computers/Companies",
#                 "label": "dmoz/Computers/Companies",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Games/Video_Games/Recreation",
#                 "label": "dmoz/Games/Video Games/Recreation",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Business/Automotive/Electric_Vehicles",
#                 "label": "dmoz/Business/Automotive/Electric Vehicles",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Business/Transportation_and_Logistics/Maritime",
#                 "label": "dmoz/Business/Transportation and Logistics/Maritime",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Home/Personal_Finance",
#                 "label": "dmoz/Home/Personal Finance",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Society/Future/Transhumanism",
#                 "label": "dmoz/Society/Future/Transhumanism",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Computers/Speech_Technology/Telephony",
#                 "label": "dmoz/Computers/Speech Technology/Telephony",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Business/Investing/Software",
#                 "label": "dmoz/Business/Investing/Software",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Business/Transportation_and_Logistics",
#                 "label": "dmoz/Business/Transportation and Logistics",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Sports/Equestrian/Carriage_Driving",
#                 "label": "dmoz/Sports/Equestrian/Carriage Driving",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Shopping/Visual_Arts/Digital_Art",
#                 "label": "dmoz/Shopping/Visual Arts/Digital Art",
#                 "count": 7
#             },
#             {
#                 "uri": "dmoz/Science/Technology",
#                 "label": "dmoz/Science/Technology",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Business/Retail_Trade",
#                 "label": "dmoz/Business/Retail Trade",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Business/Healthcare/Marketing_and_Advertising",
#                 "label": "dmoz/Business/Healthcare/Marketing and Advertising",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Recreation/Autos/Magazines_and_E-zines",
#                 "label": "dmoz/Recreation/Autos/Magazines and E-zines",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Society/Law/Law_Enforcement",
#                 "label": "dmoz/Society/Law/Law Enforcement",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Shopping/Toys_and_Games/Trading_Cards",
#                 "label": "dmoz/Shopping/Toys and Games/Trading Cards",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Business/Healthcare/Healthcare_Management",
#                 "label": "dmoz/Business/Healthcare/Healthcare Management",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Computers/Programming/Software_Testing",
#                 "label": "dmoz/Computers/Programming/Software Testing",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Business/Investing/Socially_Responsible",
#                 "label": "dmoz/Business/Investing/Socially Responsible",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Arts/Television/Commercials",
#                 "label": "dmoz/Arts/Television/Commercials",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Computers/Internet/On_the_Web",
#                 "label": "dmoz/Computers/Internet/On the Web",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Business/Major_Companies/Company_Rankings",
#                 "label": "dmoz/Business/Major Companies/Company Rankings",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Science/Research_Groups_and_Centers",
#                 "label": "dmoz/Science/Research Groups and Centers",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Vision",
#                 "label": "dmoz/Computers/Artificial Intelligence/Vision",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Human_Resources",
#                 "label": "dmoz/Computers/Software/Human Resources",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Investment_Banks",
#                 "label": "dmoz/Business/Financial Services/Investment Banks",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Health/Public_Health_and_Safety/Organizations",
#                 "label": "dmoz/Health/Public Health and Safety/Organizations",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Shopping/Consumer_Electronics/Audio",
#                 "label": "dmoz/Shopping/Consumer Electronics/Audio",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Computers/Mobile_Computing/Wireless_Data",
#                 "label": "dmoz/Computers/Mobile Computing/Wireless Data",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Business/Major_Companies/Publicly_Traded",
#                 "label": "dmoz/Business/Major Companies/Publicly Traded",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Arts/Bodyart/Bodypainting",
#                 "label": "dmoz/Arts/Bodyart/Bodypainting",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Society/Philosophy/Analytic_Philosophy",
#                 "label": "dmoz/Society/Philosophy/Analytic Philosophy",
#                 "count": 6
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Global",
#                 "label": "dmoz/Society/Issues/Global",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Computers/Speech_Technology/Research",
#                 "label": "dmoz/Computers/Speech Technology/Research",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Games/Video_Games/Console_Platforms",
#                 "label": "dmoz/Games/Video Games/Console Platforms",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Transportation",
#                 "label": "dmoz/Society/Issues/Transportation",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Science/Technology/Aerospace",
#                 "label": "dmoz/Science/Technology/Aerospace",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Science/Environment/Employment",
#                 "label": "dmoz/Science/Environment/Employment",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Health/Public_Health_and_Safety/Community_Health",
#                 "label": "dmoz/Health/Public Health and Safety/Community Health",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Labor",
#                 "label": "dmoz/Society/Issues/Labor",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Recreation/Picture_Ratings",
#                 "label": "dmoz/Recreation/Picture Ratings",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Health/Conditions_and_Diseases/Cardiovascular_Disorders",
#                 "label": "dmoz/Health/Conditions and Diseases/Cardiovascular Disorders",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising/Internet_Marketing",
#                 "label": "dmoz/Business/Marketing and Advertising/Internet Marketing",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Customer_Service",
#                 "label": "dmoz/Business/Customer Service",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Small_Business",
#                 "label": "dmoz/Business/Small Business",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Health/Conditions_and_Diseases",
#                 "label": "dmoz/Health/Conditions and Diseases",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Shopping/Toys_and_Games/Games",
#                 "label": "dmoz/Shopping/Toys and Games/Games",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Health/Mental_Health/Organizations",
#                 "label": "dmoz/Health/Mental Health/Organizations",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Fraud",
#                 "label": "dmoz/Society/Issues/Fraud",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Health/Mental_Health/Policy_and_Advocacy",
#                 "label": "dmoz/Health/Mental Health/Policy and Advocacy",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Mining_and_Drilling/Conferences",
#                 "label": "dmoz/Business/Mining and Drilling/Conferences",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Energy/Renewable",
#                 "label": "dmoz/Business/Energy/Renewable",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Computers/Computer_Science/Theoretical",
#                 "label": "dmoz/Computers/Computer Science/Theoretical",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Electronics_and_Electrical/Transformers_and_Inductors",
#                 "label": "dmoz/Business/Electronics and Electrical/Transformers and Inductors",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Games/Online",
#                 "label": "dmoz/Games/Online",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Computers/Algorithms",
#                 "label": "dmoz/Computers/Algorithms",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Society/Activism",
#                 "label": "dmoz/Society/Activism",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Information_Technology/Marketing_and_Advertising",
#                 "label": "dmoz/Business/Information Technology/Marketing and Advertising",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Investing/Day_Trading",
#                 "label": "dmoz/Business/Investing/Day Trading",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Holding_Companies",
#                 "label": "dmoz/Business/Financial Services/Holding Companies",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Food_and_Related_Products/Snack_Foods",
#                 "label": "dmoz/Business/Food and Related Products/Snack Foods",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Human_Resources/Employee_Relations",
#                 "label": "dmoz/Business/Human Resources/Employee Relations",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Accounting/Associations",
#                 "label": "dmoz/Business/Accounting/Associations",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Computers/Computer_Science/Research_Institutes",
#                 "label": "dmoz/Computers/Computer Science/Research Institutes",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Aerospace_and_Defense/Space",
#                 "label": "dmoz/Business/Aerospace and Defense/Space",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Intelligence/Neural_Networks",
#                 "label": "dmoz/Computers/Artificial Intelligence/Neural Networks",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Human_Resources/Employment",
#                 "label": "dmoz/Business/Human Resources/Employment",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/International_Business_and_Trade/Import_and_Export",
#                 "label": "dmoz/Business/International Business and Trade/Import and Export",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Online_Training",
#                 "label": "dmoz/Computers/Software/Online Training",
#                 "count": 5
#             },
#             {
#                 "uri": "dmoz/Business/Management/Software",
#                 "label": "dmoz/Business/Management/Software",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Arts/Music/Awards",
#                 "label": "dmoz/Arts/Music/Awards",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Social_Sciences/Economics",
#                 "label": "dmoz/Science/Social Sciences/Economics",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Financial_Services/Merchant_Services",
#                 "label": "dmoz/Business/Financial Services/Merchant Services",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Education_and_Training/Driving",
#                 "label": "dmoz/Business/Education and Training/Driving",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Electronics_and_Electrical/Electromechanical",
#                 "label": "dmoz/Business/Electronics and Electrical/Electromechanical",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Workflow",
#                 "label": "dmoz/Computers/Software/Workflow",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Environment/Water_Resources",
#                 "label": "dmoz/Science/Environment/Water Resources",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Recreation/Autos/Image_Galleries",
#                 "label": "dmoz/Recreation/Autos/Image Galleries",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Electronics_and_Electrical/Safety_and_Compliance_Testing",
#                 "label": "dmoz/Business/Electronics and Electrical/Safety and Compliance Testing",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Information_Technology/Associations",
#                 "label": "dmoz/Business/Information Technology/Associations",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Health/Conditions_and_Diseases/Genitourinary_Disorders",
#                 "label": "dmoz/Health/Conditions and Diseases/Genitourinary Disorders",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Computer_Science",
#                 "label": "dmoz/Computers/Computer Science",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Philanthropy/Social_Enterprise",
#                 "label": "dmoz/Society/Philanthropy/Social Enterprise",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Disabled/Assistive_Technology",
#                 "label": "dmoz/Society/Disabled/Assistive Technology",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Supercomputing",
#                 "label": "dmoz/Computers/Supercomputing",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Health/Public_Health_and_Safety/Policy_and_Regulation",
#                 "label": "dmoz/Health/Public Health and Safety/Policy and Regulation",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Agriculture/Organizations",
#                 "label": "dmoz/Science/Agriculture/Organizations",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising/Salesmanship",
#                 "label": "dmoz/Business/Marketing and Advertising/Salesmanship",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Business",
#                 "label": "dmoz/Computers/Software/Business",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Human_Rights_and_Liberties",
#                 "label": "dmoz/Society/Issues/Human Rights and Liberties",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Biology/Neurobiology",
#                 "label": "dmoz/Science/Biology/Neurobiology",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Environment/Carbon_Cycle",
#                 "label": "dmoz/Science/Environment/Carbon Cycle",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Management/Supply_Chain",
#                 "label": "dmoz/Business/Management/Supply Chain",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Future/Predictions",
#                 "label": "dmoz/Society/Future/Predictions",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Shopping/Photography",
#                 "label": "dmoz/Shopping/Photography",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Arts/Entertainment/Online_Media",
#                 "label": "dmoz/Arts/Entertainment/Online Media",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Recreation/Collecting/Patches",
#                 "label": "dmoz/Recreation/Collecting/Patches",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Arts/Music/Trading",
#                 "label": "dmoz/Arts/Music/Trading",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Education",
#                 "label": "dmoz/Society/Issues/Education",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Shopping/Photography/Services",
#                 "label": "dmoz/Shopping/Photography/Services",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Physics/Quantum_Mechanics",
#                 "label": "dmoz/Science/Physics/Quantum Mechanics",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Business_Services/Government_Contracting",
#                 "label": "dmoz/Business/Business Services/Government Contracting",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Terrorism",
#                 "label": "dmoz/Society/Issues/Terrorism",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Hardware/Retailers",
#                 "label": "dmoz/Computers/Hardware/Retailers",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Social_Sciences/Urban_and_Regional_Planning",
#                 "label": "dmoz/Science/Social Sciences/Urban and Regional Planning",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Home/Home_Improvement/Automation",
#                 "label": "dmoz/Home/Home Improvement/Automation",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Environment/Air_Quality",
#                 "label": "dmoz/Science/Environment/Air Quality",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Home/Personal_Finance/Investing",
#                 "label": "dmoz/Home/Personal Finance/Investing",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Recreation/Audio",
#                 "label": "dmoz/Recreation/Audio",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Speech_Technology/Resellers",
#                 "label": "dmoz/Computers/Speech Technology/Resellers",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Security/FAQs,_Help,_and_Tutorials",
#                 "label": "dmoz/Computers/Security/FAQs, Help, and Tutorials",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Accounting/Employment",
#                 "label": "dmoz/Business/Accounting/Employment",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Government/Multilateral",
#                 "label": "dmoz/Society/Government/Multilateral",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Government",
#                 "label": "dmoz/Society/Government",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Sports/Motorsports",
#                 "label": "dmoz/Sports/Motorsports",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Shopping/Classifieds/Automotive",
#                 "label": "dmoz/Shopping/Classifieds/Automotive",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Politics/Campaigns_and_Elections",
#                 "label": "dmoz/Society/Politics/Campaigns and Elections",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Construction_and_Maintenance/Residential_Housing",
#                 "label": "dmoz/Business/Construction and Maintenance/Residential Housing",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers",
#                 "label": "dmoz/Computers",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Law/Legal_Information",
#                 "label": "dmoz/Society/Law/Legal Information",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Sports/Officiating",
#                 "label": "dmoz/Sports/Officiating",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Warfare_and_Conflict",
#                 "label": "dmoz/Society/Issues/Warfare and Conflict",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Transportation_and_Logistics/Trucking",
#                 "label": "dmoz/Business/Transportation and Logistics/Trucking",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Computers/Data_Communications/Installation",
#                 "label": "dmoz/Computers/Data Communications/Installation",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Technology/Invention_and_Innovation",
#                 "label": "dmoz/Science/Technology/Invention and Innovation",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Science/Technology/Conferences_and_Events",
#                 "label": "dmoz/Science/Technology/Conferences and Events",
#                 "count": 4
#             },
#             {
#                 "uri": "dmoz/Business/Management/Education_and_Training",
#                 "label": "dmoz/Business/Management/Education and Training",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Health/Pharmacy/Drugs_and_Medications",
#                 "label": "dmoz/Health/Pharmacy/Drugs and Medications",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Business/Small_Business/Consulting",
#                 "label": "dmoz/Business/Small Business/Consulting",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Health/Medicine",
#                 "label": "dmoz/Health/Medicine",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Games/Roleplaying",
#                 "label": "dmoz/Games/Roleplaying",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Databases",
#                 "label": "dmoz/Computers/Software/Databases",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Health/Home_Health",
#                 "label": "dmoz/Health/Home Health",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Health/Medicine/Facilities",
#                 "label": "dmoz/Health/Medicine/Facilities",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Arts/Television",
#                 "label": "dmoz/Arts/Television",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Business/Food_and_Related_Products/Consulting",
#                 "label": "dmoz/Business/Food and Related Products/Consulting",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Business/Arts_and_Entertainment/Beauty_Pageants",
#                 "label": "dmoz/Business/Arts and Entertainment/Beauty Pageants",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Office_Suites",
#                 "label": "dmoz/Computers/Software/Office Suites",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Business/Management/Communication_Skills",
#                 "label": "dmoz/Business/Management/Communication Skills",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Health/Alternative/Coaching",
#                 "label": "dmoz/Health/Alternative/Coaching",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Housing",
#                 "label": "dmoz/Society/Issues/Housing",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Business/Real_Estate/Residential",
#                 "label": "dmoz/Business/Real Estate/Residential",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising/Market_Research",
#                 "label": "dmoz/Business/Marketing and Advertising/Market Research",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Business/Accounting/Education_and_Training",
#                 "label": "dmoz/Business/Accounting/Education and Training",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Health/Women's_Health/Organizations",
#                 "label": "dmoz/Health/Women's Health/Organizations",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Health/Women's_Health/Smoking",
#                 "label": "dmoz/Health/Women's Health/Smoking",
#                 "count": 3
#             },
#             {
#                 "uri": "dmoz/Society/Activism/Consumer",
# ...
#             {
#                 "uri": "dmoz/Science/Social_Sciences/Demography_and_Population_Studies",
#                 "label": "dmoz/Science/Social Sciences/Demography and Population Studies",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Shopping/Sports/Gaelic",
#                 "label": "dmoz/Shopping/Sports/Gaelic",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Theme_Parks/Legoland",
#                 "label": "dmoz/Recreation/Theme Parks/Legoland",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Robotics/Building",
#                 "label": "dmoz/Computers/Robotics/Building",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Guns/Airguns",
#                 "label": "dmoz/Recreation/Guns/Airguns",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Roads_and_Highways/Oceania",
#                 "label": "dmoz/Recreation/Roads and Highways/Oceania",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Roads_and_Highways",
#                 "label": "dmoz/Recreation/Roads and Highways",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Chemicals/Catalysts_and_Adsorbents",
#                 "label": "dmoz/Business/Chemicals/Catalysts and Adsorbents",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Pets/Animal_Assisted_Therapy",
#                 "label": "dmoz/Recreation/Pets/Animal Assisted Therapy",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Disabled/Service_Animals",
#                 "label": "dmoz/Society/Disabled/Service Animals",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Pets/Dogs",
#                 "label": "dmoz/Recreation/Pets/Dogs",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Social_Sciences/Political_Science",
#                 "label": "dmoz/Science/Social Sciences/Political Science",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Aging",
#                 "label": "dmoz/Health/Aging",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Aging/Education",
#                 "label": "dmoz/Health/Aging/Education",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Lifestyle_Choices",
#                 "label": "dmoz/Society/Lifestyle Choices",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Business_Services/AudioVisual",
#                 "label": "dmoz/Business/Business Services/AudioVisual",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Arts/Education/Language_Arts",
#                 "label": "dmoz/Arts/Education/Language Arts",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Arts/Education",
#                 "label": "dmoz/Arts/Education",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Food_and_Related_Products/Fats_and_Oils",
#                 "label": "dmoz/Business/Food and Related Products/Fats and Oils",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Law/Products",
#                 "label": "dmoz/Society/Law/Products",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Birding/Asia",
#                 "label": "dmoz/Recreation/Birding/Asia",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Shopping/Health/Mental_Health",
#                 "label": "dmoz/Shopping/Health/Mental Health",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Mental_Health/Disorders",
#                 "label": "dmoz/Health/Mental Health/Disorders",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Mental_Health",
#                 "label": "dmoz/Health/Mental Health",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Energy/Electricity",
#                 "label": "dmoz/Business/Energy/Electricity",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Math/Number_Theory",
#                 "label": "dmoz/Science/Math/Number Theory",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Backup",
#                 "label": "dmoz/Computers/Software/Backup",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Dentistry/Endodontics",
#                 "label": "dmoz/Health/Dentistry/Endodontics",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Arts/Movies/Awards",
#                 "label": "dmoz/Arts/Movies/Awards",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Collecting/Glassware",
#                 "label": "dmoz/Recreation/Collecting/Glassware",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Arts/Crafts/Glass",
#                 "label": "dmoz/Arts/Crafts/Glass",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Alternative/Apitherapy",
#                 "label": "dmoz/Health/Alternative/Apitherapy",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Shopping/Food/Sweeteners",
#                 "label": "dmoz/Shopping/Food/Sweeteners",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Agriculture/Animals",
#                 "label": "dmoz/Science/Agriculture/Animals",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Systems/Handhelds",
#                 "label": "dmoz/Computers/Systems/Handhelds",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Fitness/Advice_and_Guides",
#                 "label": "dmoz/Health/Fitness/Advice and Guides",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Fitness",
#                 "label": "dmoz/Health/Fitness",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Sports/Strength_Sports/Tug-of-War",
#                 "label": "dmoz/Sports/Strength Sports/Tug-of-War",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Astronomy/Stars",
#                 "label": "dmoz/Science/Astronomy/Stars",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Home/Personal_Finance/Money_Management",
#                 "label": "dmoz/Home/Personal Finance/Money Management",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Electronics_and_Electrical/Power_Supplies",
#                 "label": "dmoz/Business/Electronics and Electrical/Power Supplies",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Autos/Enthusiasts",
#                 "label": "dmoz/Recreation/Autos/Enthusiasts",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Hardware/Historical",
#                 "label": "dmoz/Computers/Hardware/Historical",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Roads_and_Highways/Signs_and_Signals",
#                 "label": "dmoz/Recreation/Roads and Highways/Signs and Signals",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Medicine/Medical_Specialties",
#                 "label": "dmoz/Health/Medicine/Medical Specialties",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Climbing/Ice_Climbing",
#                 "label": "dmoz/Recreation/Climbing/Ice Climbing",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Immigration",
#                 "label": "dmoz/Society/Issues/Immigration",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Games/Dice/Spill_and_Spell",
#                 "label": "dmoz/Games/Dice/Spill and Spell",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Arts/Writers_Resources/Software",
#                 "label": "dmoz/Arts/Writers Resources/Software",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Arts/Writers_Resources/Style_Guides",
#                 "label": "dmoz/Arts/Writers Resources/Style Guides",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Sports/Boxing",
#                 "label": "dmoz/Sports/Boxing",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Telecommunications/Regulation",
#                 "label": "dmoz/Business/Telecommunications/Regulation",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Religion_and_Spirituality/Religious_Texts",
#                 "label": "dmoz/Society/Religion and Spirituality/Religious Texts",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Information_Retrieval",
#                 "label": "dmoz/Computers/Software/Information Retrieval",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Transportation_and_Logistics/Fleet_Maintenance",
#                 "label": "dmoz/Business/Transportation and Logistics/Fleet Maintenance",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Marketing_and_Advertising/Direct_Marketing",
#                 "label": "dmoz/Business/Marketing and Advertising/Direct Marketing",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Home/Personal_Finance/Software",
#                 "label": "dmoz/Home/Personal Finance/Software",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Health/Teen_Health/Drugs_and_Alcohol",
#                 "label": "dmoz/Health/Teen Health/Drugs and Alcohol",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Issues/Crime_and_Justice",
#                 "label": "dmoz/Society/Issues/Crime and Justice",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Agriculture/Crop_Plants",
#                 "label": "dmoz/Science/Agriculture/Crop Plants",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Shopping/Food/Beverages",
#                 "label": "dmoz/Shopping/Food/Beverages",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Artificial_Life",
#                 "label": "dmoz/Computers/Artificial Life",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Virtual_Reality/Multi-User_Systems",
#                 "label": "dmoz/Computers/Virtual Reality/Multi-User Systems",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Travel/Travelogues",
#                 "label": "dmoz/Recreation/Travel/Travelogues",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Agriculture_and_Forestry/Cooperatives",
#                 "label": "dmoz/Business/Agriculture and Forestry/Cooperatives",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Sports/Team_Spirit/Fight_Songs",
#                 "label": "dmoz/Sports/Team Spirit/Fight Songs",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Roads_and_Highways/Photography",
#                 "label": "dmoz/Recreation/Roads and Highways/Photography",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Recreation/Roads_and_Highways/Periodicals",
#                 "label": "dmoz/Recreation/Roads and Highways/Periodicals",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Human_Resources/Compensation_and_Benefits",
#                 "label": "dmoz/Business/Human Resources/Compensation and Benefits",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Shopping/Consumer_Electronics/Language_Translators",
#                 "label": "dmoz/Shopping/Consumer Electronics/Language Translators",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Globalization",
#                 "label": "dmoz/Computers/Software/Globalization",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Physics",
#                 "label": "dmoz/Science/Physics",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Paranormal/Bermuda_Triangle",
#                 "label": "dmoz/Society/Paranormal/Bermuda Triangle",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Management/Strategy_and_Forecasting",
#                 "label": "dmoz/Business/Management/Strategy and Forecasting",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Software/Simulation",
#                 "label": "dmoz/Science/Software/Simulation",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Software/Device_Drivers",
#                 "label": "dmoz/Computers/Software/Device Drivers",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Earth_Sciences/Natural_Disasters_and_Hazards",
#                 "label": "dmoz/Science/Earth Sciences/Natural Disasters and Hazards",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Telecommunications/Software",
#                 "label": "dmoz/Business/Telecommunications/Software",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Telecommunications/Carriers",
#                 "label": "dmoz/Business/Telecommunications/Carriers",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Business/Healthcare",
#                 "label": "dmoz/Business/Healthcare",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Science/Research_Groups_and_Centers/Corporate_Research",
#                 "label": "dmoz/Science/Research Groups and Centers/Corporate Research",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Disabled/Employment",
#                 "label": "dmoz/Society/Disabled/Employment",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/CAD_and_CAM/Viewers",
#                 "label": "dmoz/Computers/CAD and CAM/Viewers",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Computers/Software/File_Management",
#                 "label": "dmoz/Computers/Software/File Management",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Law/Organizations",
#                 "label": "dmoz/Society/Law/Organizations",
#                 "count": 1
#             },
#             {
#                 "uri": "dmoz/Society/Law/Employment",
#                 "label": "dmoz/Society/Law/Employment",
#                 "count": 1
#             }
#         ]
#     }
# }
